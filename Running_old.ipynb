# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackkerrison/Jack_lob/blob/main/Running_old.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Section 1: Environment Setup and Imports
# Install necessary packages
# %pip install arch --upgrade
# %pip install pathos
# !pip install bintrees
# %pip install yfinance
# %pip install sortedcontainers

# Import necessary modules
import sys
import logging
import psutil
from pathos.multiprocessing import ProcessingPool as Pool
import numpy as np
import pandas as pd
from collections import deque
import time
from sortedcontainers import SortedDict
import random
from arch import arch_model
from io import StringIO
import threading
import tracemalloc
import gc
import yfinance as yf
import matplotlib.pyplot as plt
from sortedcontainers import SortedDict
import seaborn as sns

# Adjust the CPU monitoring logic
MAX_CPU_PERCENT = 95  # Allow higher CPU usage before pausing
MAX_MEMORY_PERCENT = 90  # Allow higher memory usage
CHECK_INTERVAL = 5  # Check every 5 seconds

def monitor_resources():
    while True:
        cpu_percent = psutil.cpu_percent(interval=1)
        memory_percent = psutil.virtual_memory().percent

        if cpu_percent > MAX_CPU_PERCENT:
            logging.warning(f"High CPU usage: {cpu_percent}%. Pausing execution.")
            time.sleep(1)  # Shorter pause

        if memory_percent > MAX_MEMORY_PERCENT:
            logging.warning(f"High Memory usage: {memory_percent}%. Collecting garbage.")
            gc.collect()
            time.sleep(1)  # Shorter pause

        time.sleep(CHECK_INTERVAL)

# Start monitoring system resources in a separate thread
monitor_thread = threading.Thread(target=monitor_resources, daemon=True)
monitor_thread.start()
# Out:
# Collecting arch
#   Downloading arch-7.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from arch) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from arch) (1.13.1)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from arch) (2.1.4)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.12->arch) (1.16.0)
# Downloading arch-7.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: arch
# Successfully installed arch-7.0.0
# Collecting pathos
#   Downloading pathos-0.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting ppft>=1.7.6.8 (from pathos)
#   Downloading ppft-1.7.6.8-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.3.8 (from pathos)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.4 (from pathos)
#   Downloading pox-0.3.4-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.16 (from pathos)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Downloading pathos-0.3.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 1.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.1 MB/s eta 0:00:00
# Downloading pox-0.3.4-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.6.8-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: ppft, pox, dill, multiprocess, pathos
# Successfully installed dill-0.3.8 multiprocess-0.70.16 pathos-0.3.2 pox-0.3.4 ppft-1.7.6.8
# Collecting bintrees
#   Downloading bintrees-2.2.0.zip (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bintrees
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for bintrees (setup.py) ... error
#   ERROR: Failed building wheel for bintrees
#   Running setup.py clean for bintrees
# Failed to build bintrees
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (bintrees)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (2.4.0)

# %%
# Data Fetching and Preparation
try:
    # Fetch MSFT data for the specified date range
    msft_data = yf.download('MSFT', start='2023-05-01', end='2023-07-01', interval='60m', progress=False)
    initial_rows = msft_data.shape[0]

    # Handle missing data for 'Adj Close' and 'Volume'
    if msft_data.isnull().sum().sum() > 0:
        msft_data['Adj Close'] = msft_data['Adj Close'].fillna(method='ffill').fillna(method='bfill')
        msft_data['Volume'] = msft_data['Volume'].fillna(msft_data['Volume'].rolling(window=5, min_periods=1).mean())

    dropped_rows = initial_rows - msft_data.shape[0]
    print(f"Dropped {dropped_rows} rows due to missing data. ({(dropped_rows / initial_rows) * 100:.2f}% of the data)")
    print("Preview of the fetched data:")
    print(msft_data.head())

except Exception as e:
    print(f"Error fetching data: {e}")

# Rolling window for volatility calculation
rolling_window = 10
initial_volatility = msft_data['Adj Close'].rolling(window=rolling_window).std().dropna()

# Calculate Returns and GARCH Model Fitting
try:
    returns = msft_data['Adj Close'].pct_change().dropna()
    egarch_fitted = arch_model(returns * 100, vol='EGarch', p=1, q=1, o=1, dist='t').fit(disp='off')
    volatility = (egarch_fitted.conditional_volatility / 100).round(2)

    # Smooth transition of volatility
    if not initial_volatility.empty:
        volatility.iloc[:len(initial_volatility)] = initial_volatility.values
    # Plot the conditional volatility
    volatility.plot(title='Conditional Volatility from EGARCH Model', figsize=(10, 6))
    plt.show()

except Exception as e:
    print(f"Error in GARCH model fitting: {e}")

# Adjusted liquidity calculation
def time_weighted_liquidity(volume, timestamp):
    typical_liquidity_factor = np.random.uniform(0.7, 1.2)  # Tighter liquidity bounds
    if timestamp.hour < 10:
        return volume * typical_liquidity_factor * np.random.uniform(1.1, 1.4)  # Early morning liquidity bump
    elif timestamp.hour >= 15:
        return volume * typical_liquidity_factor * np.random.uniform(1.2, 1.5)  # Higher liquidity at close
    else:
        return volume * typical_liquidity_factor * np.random.uniform(0.8, 1.1)  # Lower liquidity midday

# Correct dynamic liquidity adjustment function without 'self'
def dynamic_liquidity(volume, executed_order_size, base_liquidity):
    remaining_liquidity = base_liquidity - (executed_order_size * 0.15)  # Higher reduction for large orders
    return max(remaining_liquidity, volume * 0.3)  # Ensure liquidity doesn't fall below a threshold

# Align Data
aligned_data = pd.concat([msft_data['Adj Close'], msft_data['Volume'], volatility, msft_data['High'], msft_data['Low']], axis=1).ffill().bfill()
aligned_data.columns = ['Adj Close', 'Volume', 'Volatility', 'High', 'Low']

# Adjusted volume calculation based on realistic values
volume_multiplier = np.random.uniform(0.7, 1.3, len(aligned_data))  # More realistic range
typical_daily_volume = 20000000  # MSFT typical daily volume
hourly_volume = typical_daily_volume / 7  # Assuming 7 hours of trading in a day
aligned_data['Adjusted_Volume'] = (aligned_data['Volume'] / aligned_data['Volume'].max()) * hourly_volume * volume_multiplier

# Adjusted volume calculation based on realistic values
volume_multiplier = np.random.uniform(0.7, 1.3, len(aligned_data))  # More realistic range
typical_daily_volume = 20000000  # MSFT typical daily volume
hourly_volume = typical_daily_volume / 7  # Assuming 7 hours of trading in a day
aligned_data['Adjusted_Volume'] = (aligned_data['Volume'] / aligned_data['Volume'].max()) * hourly_volume * volume_multiplier

# Initial Liquidity Calculation
aligned_data['Liquidity'] = aligned_data.apply(lambda row: time_weighted_liquidity(row['Adjusted_Volume'], row.name), axis=1)

# Now apply dynamic liquidity adjustment after creating the initial Liquidity column
aligned_data['Liquidity'] = aligned_data.apply(lambda row: dynamic_liquidity(row['Adjusted_Volume'], 100000, row['Liquidity']), axis=1)

# Print volume and liquidity for verification
print("Sample Adjusted Volumes and Liquidity:")
print(aligned_data[['Adjusted_Volume', 'Liquidity']].head())

# Recalibrating spread to reflect MSFT’s tight bid-ask spreads
def dynamic_spread(adj_close, volatility, liquidity, base_spread_factor=0.0001, volatility_multiplier=0.2):
    base_spread = adj_close * base_spread_factor * (1 + volatility * volatility_multiplier)
    liquidity_adjustment = 1 + np.random.uniform(0.01, 0.02)  # Narrower spread fluctuation
    spread = base_spread * liquidity_adjustment
    return np.clip(spread, adj_close * 0.0001, adj_close * 0.0004).round(4)  # Tighter spread range

# Apply the updated spread calculation
aligned_data['Spread'] = aligned_data.apply(
    lambda row: dynamic_spread(row['Adj Close'], row['Volatility'], row['Liquidity']), axis=1)

def market_response(price, order_size, daily_volume, liquidity, volatility, market_conditions='stable'):
    # Increase price response for large orders and during volatile market conditions
    market_impact_factor = np.random.uniform(0.01, 0.05) if market_conditions == 'volatile' else np.random.uniform(0.005, 0.015)
    impact = price * (1 + market_impact_factor * (order_size / liquidity))  # Increased sensitivity based on liquidity
    return np.clip(impact, price * 0.98, price * 1.02).round(2)

# Use this function in VWAP and TWAP executions
aligned_data['Mid_Price'] = aligned_data.apply(lambda row: market_response(row['Adj Close'], row['Volume'], 20000000, row['Liquidity'], row['Volatility'], 'stable'), axis=1)

# VWAP Calculation
def calculate_vwap(prices, volumes):
    cumulative_price_volume = np.cumsum(prices * volumes)
    cumulative_volume = np.cumsum(volumes)
    vwap = cumulative_price_volume / cumulative_volume
    return vwap.round(2)

aligned_data['VWAP'] = calculate_vwap(aligned_data['Adj Close'], aligned_data['Volume'])

# Calculate Typical Price and TWAP
aligned_data['Typical Price'] = ((aligned_data['Adj Close'] + aligned_data['High'] + aligned_data['Low']) / 3).round(2)

# Refined TWAP Calculation using exponentially weighted moving average (EWMA)
def calculate_twap(prices, alpha=0.05):
    # Further reduce alpha for a smoother TWAP
    return prices.ewm(alpha=alpha, adjust=False).mean().round(2)

aligned_data['TWAP'] = calculate_twap(aligned_data['Typical Price'])

# Generate bid/ask prices for different levels
num_levels = 10
level_multipliers = np.exp(-np.arange(num_levels) / 2)  # Steeper decay for higher levels

# Distribute bid/ask liquidity across levels with realistic differences
def distribute_liquidity_across_levels(mid_price, liquidity, num_levels=10):
    level_multipliers = np.exp(-np.arange(num_levels) / 2)  # Steeper decay for higher levels
    total_liquidity = liquidity * level_multipliers / level_multipliers.sum()
    return total_liquidity

# Modify bid/ask prices with more variability and progressive spreads
level_variability = np.random.uniform(0.995, 1.010, size=(len(aligned_data), num_levels))

# Adjust bid/ask prices using increasing spread for each level with a larger step change
bid_prices = np.zeros((len(aligned_data), num_levels))
ask_prices = np.zeros((len(aligned_data), num_levels))

# Larger step for spread modification at each level, incorporating liquidity sensitivity
for i in range(num_levels):
    # Increase spread significantly for deeper levels
    spread_multiplier = 1 + i * 0.5  # Adjust this factor to increase/decrease spread growth
    liquidity_impact = aligned_data['Liquidity'].values / aligned_data['Liquidity'].mean()  # Adjust based on liquidity

    bid_prices[:, i] = aligned_data['Mid_Price'].values - (aligned_data['Spread'].values * spread_multiplier * liquidity_impact) * level_variability[:, i]
    ask_prices[:, i] = aligned_data['Mid_Price'].values + (aligned_data['Spread'].values * spread_multiplier * liquidity_impact) * level_variability[:, i]

# Round the prices
bid_prices = np.round(bid_prices, 2)
ask_prices = np.round(ask_prices, 2)

# Store bid/ask prices in DataFrames
df_bid_prices = pd.DataFrame(bid_prices, index=aligned_data.index, columns=[f'Bid_Price_{i+1}' for i in range(num_levels)])
df_ask_prices = pd.DataFrame(ask_prices, index=aligned_data.index, columns=[f'Ask_Price_{i+1}' for i in range(num_levels)])

# Combine the bid/ask price levels back into aligned_data
aligned_data = pd.concat([aligned_data, df_bid_prices, df_ask_prices], axis=1)

# Print bid and ask prices for verification
print("Sample Bid Prices at different levels:")
print(df_bid_prices.head())
print("Sample Ask Prices at different levels:")
print(df_ask_prices.head())

# Display order book summary with adjusted format
pd.options.display.float_format = '{:.2f}'.format
print("Order book summary:\n", aligned_data.describe().transpose())
# Out:
# WARNING:root:High CPU usage: 100.0%. Pausing execution.
# Dropped 0 rows due to missing data. (0.00% of the data)
# Preview of the fetched data:
#                            Open        High         Low       Close  \
# Datetime
# 2023-05-01 09:30:00  306.970001  308.600006  306.170013  306.315002
# 2023-05-01 10:30:00  306.299988  307.552704  305.769989  306.299988
# 2023-05-01 11:30:00  306.329987  307.459991  306.100006  307.100006
# 2023-05-01 12:30:00  307.100006  308.049988  307.100006  307.584991
# 2023-05-01 13:30:00  307.619995  307.980011  306.399994  306.549988
#
#                       Adj Close   Volume
# Datetime
# 2023-05-01 09:30:00  306.315002  4971460
# 2023-05-01 10:30:00  306.299988  3529718
# 2023-05-01 11:30:00  307.100006  1811533
# 2023-05-01 12:30:00  307.584991  1998664
# 2023-05-01 13:30:00  306.549988  1522938
# /usr/local/lib/python3.10/dist-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Sample Adjusted Volumes and Liquidity:
#                      Adjusted_Volume      Liquidity
# Datetime
# 2023-05-01 09:30:00    728863.790257  993821.682666
# 2023-05-01 10:30:00    603268.291507  592381.403965
# 2023-05-01 11:30:00    366028.802662  332126.674081
# 2023-05-01 12:30:00    298597.638309  192652.841784
# 2023-05-01 13:30:00    299785.592335  298030.290938
# Sample Bid Prices at different levels:
#                      Bid_Price_1  Bid_Price_2  Bid_Price_3  Bid_Price_4  \
# Datetime
# 2023-05-01 09:30:00       312.37       312.34       312.30       312.27
# 2023-05-01 10:30:00       312.39       312.37       312.35       312.33
# 2023-05-01 11:30:00       313.22       313.20       313.19       313.18
# 2023-05-01 12:30:00       313.73       313.72       313.71       313.71
# 2023-05-01 13:30:00       312.66       312.65       312.64       312.63
#
#                      Bid_Price_5  Bid_Price_6  Bid_Price_7  Bid_Price_8  \
# Datetime
# 2023-05-01 09:30:00       312.23       312.20       312.16       312.12
# 2023-05-01 10:30:00       312.31       312.29       312.26       312.24
# 2023-05-01 11:30:00       313.17       313.16       313.15       313.13
# 2023-05-01 12:30:00       313.70       313.69       313.69       313.68
# 2023-05-01 13:30:00       312.62       312.61       312.60       312.59
#
#                      Bid_Price_9  Bid_Price_10
# Datetime
# 2023-05-01 09:30:00       312.09        312.06
# 2023-05-01 10:30:00       312.22        312.20
# 2023-05-01 11:30:00       313.12        313.11
# 2023-05-01 12:30:00       313.67        313.66
# 2023-05-01 13:30:00       312.58        312.57
# Sample Ask Prices at different levels:
#                      Ask_Price_1  Ask_Price_2  Ask_Price_3  Ask_Price_4  \
# Datetime
# 2023-05-01 09:30:00       312.51       312.54       312.58       312.61
# 2023-05-01 10:30:00       312.47       312.49       312.51       312.53
# 2023-05-01 11:30:00       313.26       313.28       313.29       313.30
# 2023-05-01 12:30:00       313.75       313.76       313.77       313.77
# 2023-05-01 13:30:00       312.70       312.71       312.72       312.73
#
#                      Ask_Price_5  Ask_Price_6  Ask_Price_7  Ask_Price_8  \
# Datetime
# 2023-05-01 09:30:00       312.65       312.68       312.72       312.76
# 2023-05-01 10:30:00       312.55       312.57       312.60       312.62
# 2023-05-01 11:30:00       313.31       313.32       313.33       313.35
# 2023-05-01 12:30:00       313.78       313.79       313.79       313.80
# 2023-05-01 13:30:00       312.74       312.75       312.76       312.77
#
#                      Ask_Price_9  Ask_Price_10
# Datetime
# 2023-05-01 09:30:00       312.79        312.82
# 2023-05-01 10:30:00       312.64        312.66
# 2023-05-01 11:30:00       313.36        313.37
# 2023-05-01 12:30:00       313.81        313.82
# 2023-05-01 13:30:00       312.78        312.79
# Order book summary:
#                   count       mean        std        min        25%        50%  \
# Adj Close       301.00     324.28      12.37     303.75     311.50     326.81
# Volume          301.00 3019221.65 1778438.89 1140403.00 1961121.00 2518807.00
# Volatility      301.00       1.85       1.09       0.08       1.16       1.58
# High            301.00     325.24      12.47     305.17     312.13     328.15
# Low             301.00     323.27      12.22     303.40     310.66     325.60
# Adjusted_Volume 301.00  507500.50  311084.32  158261.91  309288.38  416542.98
# Liquidity       301.00  521046.78  420146.44  106486.84  271498.66  392068.86
# Spread          301.00       0.05       0.01       0.03       0.04       0.04
# Mid_Price       301.00     330.76      12.61     309.82     317.73     333.35
# VWAP            301.00     314.79       6.55     305.72     307.90     315.27
# Typical Price   301.00     324.26      12.34     304.55     311.47     326.97
# TWAP            301.00     322.40      11.72     306.23     308.86     326.31
# Bid_Price_1     301.00     330.72      12.61     309.76     317.70     333.31
# Bid_Price_2     301.00     330.70      12.61     309.73     317.68     333.29
# Bid_Price_3     301.00     330.67      12.60     309.70     317.66     333.26
# Bid_Price_4     301.00     330.65      12.60     309.67     317.65     333.24
# Bid_Price_5     301.00     330.63      12.60     309.63     317.63     333.22
# Bid_Price_6     301.00     330.60      12.60     309.61     317.61     333.20
# Bid_Price_7     301.00     330.58      12.60     309.57     317.60     333.18
# Bid_Price_8     301.00     330.56      12.59     309.54     317.58     333.16
# Bid_Price_9     301.00     330.54      12.59     309.51     317.56     333.14
# Bid_Price_10    301.00     330.51      12.59     309.48     317.55     333.12
# Ask_Price_1     301.00     330.81      12.62     309.88     317.76     333.39
# Ask_Price_2     301.00     330.83      12.62     309.91     317.78     333.41
# Ask_Price_3     301.00     330.86      12.62     309.94     317.80     333.44
# Ask_Price_4     301.00     330.88      12.63     309.97     317.81     333.46
# Ask_Price_5     301.00     330.90      12.63     310.01     317.83     333.48
# Ask_Price_6     301.00     330.92      12.63     310.03     317.85     333.50
# Ask_Price_7     301.00     330.95      12.63     310.07     317.86     333.52
# Ask_Price_8     301.00     330.97      12.64     310.10     317.90     333.54
# Ask_Price_9     301.00     330.99      12.64     310.13     317.95     333.56
# Ask_Price_10    301.00     331.02      12.64     310.16     318.00     333.58
#
#                        75%         max
# Adj Close           334.53      348.73
# Volume          3320773.00 16931400.00
# Volatility            2.18        5.88
# High                335.78      351.47
# Low                 333.45      347.40
# Adjusted_Volume  596735.35  2213497.20
# Liquidity        602631.48  3004872.17
# Spread                0.05        0.07
# Mid_Price           341.22      355.70
# VWAP                320.58      324.74
# Typical Price       334.60      348.46
# TWAP                333.02      338.97
# Bid_Price_1         341.19      355.62
# Bid_Price_2         341.17      355.59
# Bid_Price_3         341.16      355.55
# Bid_Price_4         341.14      355.51
# Bid_Price_5         341.12      355.47
# Bid_Price_6         341.11      355.44
# Bid_Price_7         341.09      355.40
# Bid_Price_8         341.08      355.36
# Bid_Price_9         341.06      355.32
# Bid_Price_10        341.05      355.29
# Ask_Price_1         341.24      355.78
# Ask_Price_2         341.26      355.81
# Ask_Price_3         341.27      355.85
# Ask_Price_4         341.28      355.89
# Ask_Price_5         341.30      355.93
# Ask_Price_6         341.31      355.96
# Ask_Price_7         341.33      356.00
# Ask_Price_8         341.36      356.04
# Ask_Price_9         341.37      356.09
# Ask_Price_10        341.38      356.22

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the index is a datetime object
aligned_data.index = pd.to_datetime(aligned_data.index)

# Grouping the data by time-of-day to observe intraday patterns
aligned_data['Time_of_Day'] = aligned_data.index.time

# Convert Time_of_Day to a string representation of time (HH:MM)
aligned_data['Time_of_Day'] = aligned_data['Time_of_Day'].apply(lambda x: x.strftime('%H:%M'))

# Set the style and palette for the plots
sns.set(style="whitegrid")
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10

# Create a figure with multiple subplots
fig, axes = plt.subplots(5, 3, figsize=(18, 20))  # Adjusted to fit 15 plots (5 rows, 3 columns)

# 1. Spread over the day
sns.lineplot(x='Time_of_Day', y='Spread', data=aligned_data, ax=axes[0, 0], color='red')
axes[0, 0].set_title('Intraday Seasonality of Spread')
axes[0, 0].set_xlabel('Time of Day')
axes[0, 0].set_ylabel('Spread')

# 2. Volume over the day
sns.lineplot(x='Time_of_Day', y='Volume', data=aligned_data, ax=axes[0, 1], color='blue')
axes[0, 1].set_title('Intraday Seasonality of Volume')
axes[0, 1].set_xlabel('Time of Day')
axes[0, 1].set_ylabel('Volume')

# 3. Volatility over the day
sns.lineplot(x='Time_of_Day', y='Volatility', data=aligned_data, ax=axes[0, 2], color='green')
axes[0, 2].set_title('Intraday Seasonality of Volatility')
axes[0, 2].set_xlabel('Time of Day')
axes[0, 2].set_ylabel('Volatility')

# Order Imbalance Calculation
bid_volumes = aligned_data[[f'Bid_Price_{i+1}' for i in range(10)]].sum(axis=1)
ask_volumes = aligned_data[[f'Ask_Price_{i+1}' for i in range(10)]].sum(axis=1)
# Apply smoothing and clipping to the order imbalance calculation
aligned_data['Order_Imbalance'] = (bid_volumes - ask_volumes).rolling(window=5).mean().fillna(method='bfill')
aligned_data['Order_Imbalance'] = aligned_data['Order_Imbalance'].clip(lower=-5000, upper=5000)
sns.lineplot(x=aligned_data.index, y=aligned_data['Order_Imbalance'], ax=axes[1, 0], color='blue')
axes[1, 0].set_title('Order Imbalance Over Time')
axes[1, 0].set_xlabel('Time')
axes[1, 0].set_ylabel('Amplified Order Imbalance')

# 5. Price vs Adjusted Volume (Decoupled)
sns.scatterplot(x=aligned_data['Mid_Price'], y=aligned_data['Adjusted_Volume'], ax=axes[1, 1], color='magenta', alpha=0.6)
axes[1, 1].set_title('Price vs. Adjusted Volume (Decoupled)')
axes[1, 1].set_xlabel('Mid Price')
axes[1, 1].set_ylabel('Adjusted Volume')

# 6. Volatility vs Spread Scatter Plot
sns.scatterplot(x=aligned_data['Volatility'], y=aligned_data['Spread'], ax=axes[1, 2], color='red', alpha=0.6)
axes[1, 2].set_title('Volatility vs. Spread')
axes[1, 2].set_xlabel('Volatility')
axes[1, 2].set_ylabel('Spread')

# 7. Adjusted Close Prices Over Time
sns.lineplot(x=aligned_data.index, y='Adj Close', data=aligned_data, ax=axes[2, 0], color='blue')
axes[2, 0].set_title('Adjusted Close Prices')
axes[2, 0].set_xlabel('Time')
axes[2, 0].set_ylabel('Price')

# 8. Spread Over Time
sns.lineplot(x=aligned_data.index, y='Spread', data=aligned_data, ax=axes[2, 1], color='red')
axes[2, 1].set_title('Spread Over Time')
axes[2, 1].set_xlabel('Time')
axes[2, 1].set_ylabel('Spread')

# 9. VWAP vs TWAP
sns.lineplot(x=aligned_data.index, y='VWAP', data=aligned_data, ax=axes[2, 2], color='purple', label='VWAP')
sns.lineplot(x=aligned_data.index, y='TWAP', data=aligned_data, ax=axes[2, 2], color='orange', label='TWAP')
axes[2, 2].set_title('VWAP vs. TWAP')
axes[2, 2].set_xlabel('Time')
axes[2, 2].set_ylabel('Price')
axes[2, 2].legend()

# 10. Bid Price 1 Over Time
sns.lineplot(x=aligned_data.index, y='Bid_Price_1', data=aligned_data, ax=axes[3, 0], color='blue')
axes[3, 0].set_title('Bid Price 1 Over Time')
axes[3, 0].set_xlabel('Time')
axes[3, 0].set_ylabel('Price')

# 11. Ask Price 1 Over Time
sns.lineplot(x=aligned_data.index, y='Ask_Price_1', data=aligned_data, ax=axes[3, 1], color='red')
axes[3, 1].set_title('Ask Price 1 Over Time')
axes[3, 1].set_xlabel('Time')
axes[3, 1].set_ylabel('Price')

# 12. Bid-Ask Spread Over Time
bid_ask_spread = aligned_data['Ask_Price_1'] - aligned_data['Bid_Price_1']
sns.lineplot(x=aligned_data.index, y=bid_ask_spread, ax=axes[3, 2], color='black')
axes[3, 2].set_title('Bid-Ask Spread Over Time')
axes[3, 2].set_xlabel('Time')
axes[3, 2].set_ylabel('Spread')

# 13. Total Volume (Bid + Ask) Over Time
# Calculate Total Volume (Bid + Ask)
aligned_data['Total_Volume'] = aligned_data[[f'Bid_Price_{i+1}' for i in range(10)]].sum(axis=1) + aligned_data[[f'Ask_Price_{i+1}' for i in range(10)]].sum(axis=1)
aligned_data['Smoothed_Total_Volume'] = aligned_data['Total_Volume'].rolling(window=5).mean()
sns.lineplot(x=aligned_data.index, y=aligned_data['Smoothed_Total_Volume'], ax=axes[4, 0], color='magenta')
axes[4, 0].set_xticklabels(axes[4, 0].get_xticklabels(), rotation=45)
axes[4, 0].set_title('Total Volume Over Time')
axes[4, 0].set_xlabel('Time')
axes[4, 0].set_ylabel('Volume')

# 14. Distribution of Mid Prices
sns.histplot(aligned_data['Mid_Price'], bins=30, kde=False, color='grey', ax=axes[4, 1], edgecolor='black')
axes[4, 1].set_title('Distribution of Mid Prices')
axes[4, 1].set_xlabel('Mid Price')
axes[4, 1].set_ylabel('Frequency')

# 15. Volatility Over Time
sns.lineplot(x=aligned_data.index, y='Volatility', data=aligned_data, ax=axes[4, 2], color='green')
axes[4, 2].set_title('Volatility Over Time')
axes[4, 2].set_xlabel('Time')
axes[4, 2].set_ylabel('Volatility')

# Rotating x-axis labels for all subplots that require it
for ax in axes.flat:  # This iterates through each subplot in the figure
    if len(ax.get_xticklabels()) > 0:  # Check if the subplot has x-axis labels
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Adjust layout and show all plots
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-3-a10d383b43d1>:45: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aligned_data['Order_Imbalance'] = (bid_volumes - ask_volumes).rolling(window=5).mean().fillna(method='bfill')
# <ipython-input-3-a10d383b43d1>:108: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[4, 0].set_xticklabels(axes[4, 0].get_xticklabels(), rotation=45)
# <ipython-input-3-a10d383b43d1>:128: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# WARNING:root:High CPU usage: 100.0%. Pausing execution.
# WARNING:root:High CPU usage: 100.0%. Pausing execution.
# WARNING:root:High CPU usage: 100.0%. Pausing execution.

# %%
class Order:
    def __init__(self, price, quantity, tid):
        self.price = round(price, 2)  # Ensure prices are rounded to 2 decimal places
        self.quantity = quantity
        self.tid = tid

class OrderBook:
    def __init__(self, transaction_cost=0.001):
        self.bids = SortedDict(lambda x: -x)  # Sorted descending
        self.asks = SortedDict()  # Sorted ascending
        self.trades = []
        self.transaction_cost = transaction_cost
        self.liquidity_fluctuation_factor = 0.1
        self.external_order_probability = 0.2
        self.mean_reversion_strength = 0.1

        # Initialize the order book with market maker orders and simulate continuous order flow
        self.reset_order_book()

    def reset_order_book(self):
        self.mid_price = 335  # You may set this to any realistic initial value or calculate it dynamically
        self._generate_market_maker_orders()  # Generate the initial market maker orders
        #self._simulate_continuous_order_flow()  # Start the continuous order flow simulation

    # Keep this function inside the OrderBook class
    def _calculate_slippage(self, executed_qty, liquidity, market_conditions='stable'):
        # Increase slippage for larger trades
        base_slippage = 0.01 if market_conditions == 'volatile' else 0.005
        slippage = base_slippage * np.log(1 + (executed_qty / liquidity))
        return slippage

    def _process_market_order(self, order):
        opposite_side = self.asks if order['side'] == 'bid' else self.bids
        remaining_qty = order['qty']
        total_cost = 0
        executed_volume = 0
        slippage_total = 0  # Initialize slippage total

        if not opposite_side:
            print("No available liquidity on the opposite side.")
            return 0, 0, 0, 0  # Early exit if no liquidity

        initial_price = next(iter(opposite_side))

        print(f"Processing market order: {order['qty']} shares on side {order['side']} at target price {initial_price}.")

        while remaining_qty > 0 and opposite_side:
            best_price = next(iter(opposite_side))
            best_order = opposite_side[best_price][0]
            trade_qty = min(best_order.quantity, remaining_qty)
            liquidity = sum(order.quantity for order in opposite_side[best_price])

            # Calculate slippage dynamically based on trade size, liquidity, and market conditions
            slippage = self._calculate_slippage(trade_qty, liquidity, 'volatile')  # Correctly call slippage with 'self'
            slippage_total += slippage * trade_qty  # Accumulate total slippage

            # Adjust the executed price based on slippage
            executed_price = round(best_price * (1 + slippage), 2)

            print(f"Matching order: Price {best_price}, Qty {trade_qty}, Executed price: {executed_price}, Liquidity: {liquidity}")

            # Append trade to trade history
            self.trades.append({'price': executed_price, 'qty': trade_qty})
            remaining_qty -= trade_qty
            best_order.quantity -= trade_qty
            executed_volume += trade_qty  # Accumulate executed volume
            total_cost += trade_qty * executed_price  # Accumulate total cost

            # Remove the best order if fully filled
            if best_order.quantity == 0:
                opposite_side[best_price].popleft()
                if not opposite_side[best_price]:
                    del opposite_side[best_price]

            # Stop if no more orders are available on the opposite side
            if not opposite_side:
                break

        # Calculate average price and other metrics
        avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
        market_impact = max(0.001, np.random.uniform(0.001, 0.005) * (executed_volume / liquidity) * (1 + slippage))
        slippage_percentage = max(0.0001, np.random.uniform(0.0001, 0.001) * (executed_volume / liquidity))  # Correct slippage with executed_volume

        return executed_volume, avg_price, slippage_percentage, market_impact

    # Replace the previous order book generation method with this
    def _generate_market_maker_orders(self):
        spread = 0.25
        liquidity_range = (1000, 5000)
        for i in range(15):
            bid_price = self.mid_price - i * spread
            ask_price = self.mid_price + i * spread
            self.bids[bid_price] = deque([Order(bid_price, np.random.randint(*liquidity_range), f'bid-{i}')])
            self.asks[ask_price] = deque([Order(ask_price, np.random.randint(*liquidity_range), f'ask-{i}')])

    def calculate_vwap(self, trades):
        if not trades:
            return 0
        prices = np.array([trade['price'] for trade in trades])
        quantities = np.array([trade['qty'] for trade in trades])
        cumulative_price_volume = np.cumsum(prices * quantities)
        cumulative_volume = np.cumsum(quantities)
        vwap = cumulative_price_volume / cumulative_volume
        vwap_value = round(vwap[-1], 2)

        # Add logging
        print(f"VWAP Calculation: {vwap_value}, based on {len(trades)} trades.")

        return vwap_value

    def calculate_twap(self, trades):
        if not trades:
            return 0
        times = np.linspace(1, len(trades), len(trades))  # Time intervals, starting from 1
        weighted_prices = [trade['price'] for trade in trades]

        # Ensure no division by zero occurs if weights (times) are all zero
        if np.sum(times) == 0:
            return 0
        twap = np.average(weighted_prices, weights=times)
        twap_value = round(twap, 2)

        # Add logging
        print(f"TWAP Calculation: {twap_value}, based on {len(trades)} trades.")

        return twap_value

    def process_order(self, order):
        # Introduce randomness to simulate other market participants
        if np.random.rand() < self.external_order_probability:
            self._generate_external_order()

        if order['type'] == 'limit':
            self._process_limit_order(order)
        elif order['type'] == 'market':
            # Process the market order
            executed_volume, avg_price, slippage_percentage, market_impact = self._process_market_order(order)

            # Calculate VWAP and TWAP after processing the order
            vwap_value = self.calculate_vwap(self.trades)
            twap_value = self.calculate_twap(self.trades)

            # Add detailed logging of the execution
            total_order_qty = order['qty']
            remaining_qty = total_order_qty - executed_volume

            # Log the execution details with remaining quantity
            print(f"Order: {total_order_qty} shares; Executed: {executed_volume}, Remaining: {remaining_qty}")
            print(f"Average Price: {avg_price:.2f}, Slippage: {slippage_percentage:.2f}%, Market Impact: {market_impact:.4f}")
            print(f"VWAP: {vwap_value}, TWAP: {twap_value}")
        else:
            print(f"Unknown order type: {order['type']}")

    def _process_limit_order(self, order):
        side = self.bids if order['side'] == 'bid' else self.asks
        opposite = self.asks if order['side'] == 'bid' else self.bids
        price = round(order['price'], 2)  # Ensure prices are rounded
        qty = order['qty']

        # Add a print statement at the start of limit order processing for visibility
        print(f"Processing limit order: {qty} shares on side {order['side']} at price {price}.")

        # Attempt to match against opposite orders
        while qty > 0 and opposite:
            best_price = opposite.peekitem(0)[0]  # Get the best price from the opposite side

            if (order['side'] == 'bid' and price >= best_price) or (order['side'] == 'ask' and price <= best_price):
                best_orders = opposite[best_price]  # Get the best orders at the best price
                while qty > 0 and best_orders:
                    best_order = best_orders[0]
                    trade_qty = min(qty, best_order.quantity)  # Determine the trade quantity
                    executed_price = round(best_price * (1 + self.transaction_cost * (-1 if order['side'] == 'bid' else 1)), 2)  # Adjust price with transaction cost

                    # Append trade details to the trade history
                    self.trades.append({'price': executed_price, 'qty': trade_qty})
                    qty -= trade_qty  # Reduce the remaining quantity to be matched
                    best_order.quantity -= trade_qty  # Reduce the quantity of the matched order

                    # Log executed and remaining quantities
                    print(f"Order: {order['qty']} shares; Executed: {order['qty'] - qty}, Remaining: {qty}")

                    # Remove the order if fully executed
                    if best_order.quantity == 0:
                        best_orders.popleft()
                    if not best_orders:
                        del opposite[best_price]
            else:
                break  # Exit the loop if no more matching is possible

        # Add the remaining quantity to the book if it's not fully matched
        if qty > 0:
            if price in side:
                side[price].append(Order(price, qty, order['tid']))
            else:
                side[price] = deque([Order(price, qty, order['tid'])])

    def _fluctuate_liquidity(self, side):
        # Apply random adjustments to the remaining liquidity in the order book
        for price, orders in list(side.items()):
            for order in orders:
                # Adjust the quantity slightly to simulate changing liquidity
                fluctuation_factor = np.random.uniform(0.8, 1.2)  # Small random variation in liquidity
                order.quantity = max(1, int(order.quantity * fluctuation_factor))  # Ensure the quantity is at least 1

        # Optionally, you could remove prices with extremely low liquidity
        for price in list(side.keys()):
            if sum(order.quantity for order in side[price]) <= 1:  # If liquidity is very low, remove the price level
                del side[price]

    def _generate_external_order(self):
        side = 'bid' if np.random.rand() > 0.5 else 'ask'
        price = self._get_random_price(side)
        qty = np.random.randint(500, 2000)  # Larger random orders
        order = {
            'type': 'limit',
            'side': side,
            'price': price,
            'qty': qty,
            'tid': 'external'
        }
        self.process_order(order)

    # Add this new function within the OrderBook class
    def _generate_incoming_order(self):
        side = 'bid' if np.random.rand() > 0.5 else 'ask'
        price = self._get_random_price(side)
        qty = np.random.randint(500, 2000)
        order_type = np.random.choice(['limit', 'market'])
        order = {
            'type': order_type,
            'side': side,
            'price': price,
            'qty': qty,
            'tid': 'external'
        }
        self.process_order(order)

    def _simulate_continuous_order_flow(self):
        while True:
            if np.random.rand() < self.external_order_probability:
                self._generate_incoming_order()
                self._adjust_liquidity()
            time.sleep(np.random.uniform(0.1, 1.0))  # Adjust the timing to simulate realistic order flow

    def _ensure_residual_liquidity(self, side):
        # Make sure there is a minimum liquidity at each price level
        for price, orders in side.items():
            total_quantity = sum(order.quantity for order in orders)
            if total_quantity < 100:  # Arbitrary threshold for residual liquidity
                orders[-1].quantity += 100  # Ensure at least 100 units remain at each price level

    def _get_mid_price(self):
        return (min(self.asks.keys()) + max(self.bids.keys())) / 2 if self.asks and self.bids else 100.0

    def _initialize_market_maker(self):
        # Generate market maker orders
        self._generate_market_maker_orders()

        # Start simulating continuous order flow
        self._simulate_continuous_order_flow()

    def _simulate_market_impact(self, side, qty_remaining):
        # Apply more aggressive market impact based on trade size
        impact_factor = 0.01  # Higher impact factor for more realistic price adjustments
        for price, orders in list(side.items()):
            adjusted_price = price * (1 + impact_factor * (qty_remaining / sum(order.quantity for order in orders)) ** 2)  # More sensitive impact
            if adjusted_price != price:
                side[round(adjusted_price, 2)] = side.pop(price)

    def _mean_reversion(self):
        for side in [self.bids, self.asks]:
            for price in list(side.keys()):
                reverted_price = price * (1 - self.mean_reversion_strength * 0.5)
                if reverted_price in side:
                    side[reverted_price].extend(side[price])
                else:
                    side[reverted_price] = side[price]
                del side[price]

    def _get_random_price(self, side):
        # Assume realistic prices are around the mid-price range of the data, e.g., 300-350.
        realistic_price_range = (300, 350)

        if side == 'bid' and self.bids:
            return round(max(self.bids.keys()) * np.random.uniform(0.99, 1.01), 2)
        elif side == 'ask' and self.asks:
            return round(min(self.asks.keys()) * np.random.uniform(0.99, 1.01), 2)
        else:
            mid_price = np.random.uniform(*realistic_price_range)
            return round(mid_price * np.random.uniform(0.99, 1.01), 2)

    def _adjust_liquidity(self):
        for price in list(self.bids.keys()):
            for order in self.bids[price]:
                order.quantity = max(200, int(order.quantity * np.random.uniform(0.8, 1.2)))
        for price in list(self.asks.keys()):
            for order in self.asks[price]:
                order.quantity = max(200, int(order.quantity * np.random.uniform(0.8, 1.2)))

    def print_book(self, levels=5):
        print("\nOrder Book Snapshot:")
        print("Asks:")
        for price, orders in list(self.asks.items())[:levels]:
            total_qty = sum(order.quantity for order in orders)
            print(f"Price: {price:.2f}, Quantity: {total_qty}")
        print("Bids:")
        for price, orders in list(self.bids.items())[:levels]:
            total_qty = sum(order.quantity for order in orders)
            print(f"Price: {price:.2f}, Quantity: {total_qty}")

    def print_trades(self):
        print("\nTrades:")
        for trade in self.trades:
            print(f"Traded {trade['qty']} @ {trade['price']:.2f}")

# %%
# Function to check the current state of the order book
def check_order_book_state(lob):
    print("[DEBUG] Checking order book state...")

    print("[DEBUG] Bids in the order book (Top 5 Levels):")
    for price, orders in list(lob.bids.items())[:5]:  # Print the top 5 levels of bids
        total_qty = sum(order.quantity for order in orders)
        print(f"Price: {price:.2f}, Total Quantity: {total_qty}")

    print("[DEBUG] Asks in the order book (Top 5 Levels):")
    for price, orders in list(lob.asks.items())[:5]:  # Print the top 5 levels of asks
        total_qty = sum(order.quantity for order in orders)
        print(f"Price: {price:.2f}, Total Quantity: {total_qty}")

# Function to populate order book
def populate_order_book(lob, aligned_data):
    print("\n[DEBUG] Populating the order book with initial data...")

    for index, row in aligned_data.iterrows():
        mid_price = row['Mid_Price']  # Use the calculated mid_price

        # Get the liquidity value from the aligned data
        liquidity = row['Liquidity'] / 10  # Use realistic liquidity

        # Dynamically determine the maximum number of price levels
        max_levels = min(10, len([col for col in row.index if col.startswith('Bid_Price_')]))

        # Loop over only the available levels
        for level in range(1, max_levels + 1):
            bid_order = {
                'type': 'limit',
                'side': 'bid',
                'instrument': 'MSFT',
                'qty': round(liquidity * np.random.uniform(0.8, 1.2)),  # Use liquidity for MSFT
                'price': round(row[f'Bid_Price_{level}'], 2),
                'tid': f"bid-{index}-{level}"
            }
            ask_order = {
                'type': 'limit',
                'side': 'ask',
                'instrument': 'MSFT',
                'qty': round(liquidity * np.random.uniform(0.8, 1.2)),  # Use liquidity for MSFT
                'price': round(row[f'Ask_Price_{level}'], 2),
                'tid': f"ask-{index}-{level}"
            }

            lob.process_order(bid_order)
            lob.process_order(ask_order)

    print("\n[DEBUG] Initial Order Book Snapshot (Top 5 Levels):")
    lob.print_book(levels=5)  # Show the top 5 levels

def execute_vwap_order_with_shares(lob, total_shares):
    executed_volume, total_cost = 0, 0
    transaction_cost_total = 0
    remaining_shares = total_shares
    lob.trades.clear()

    # Lists to store data for plotting
    vwap_prices, vwap_volumes, vwap_slippage, vwap_market_impact = [], [], [], []

    print(f"\n[DEBUG] VWAP function started to buy {total_shares} shares.", flush=True)
    lob.print_book(levels=5)  # Print the top 5 levels of the order book before execution

    while remaining_shares > 0:
        print(f"\n[DEBUG] VWAP loop - remaining shares: {remaining_shares}.", flush=True)
        price_range = sorted([p for p in lob.asks.keys() if p > 0])[:5]

        if not price_range:  # Halt if no valid prices remain
            print(f"[DEBUG] VWAP halted: No valid prices in the order book.", flush=True)
            break

        target_price = np.random.choice(price_range)
        liquidity = sum(order.quantity for order in lob.asks[target_price])

        print(f"\n[DEBUG] VWAP selecting target price: ${target_price:.2f}, liquidity: {liquidity}", flush=True)

        current_order_qty = min(remaining_shares, liquidity)

        if current_order_qty <= 0:
            print(f"[DEBUG] VWAP halted: Insufficient liquidity to buy at price {target_price}.", flush=True)
            break

        print(f"VWAP: Buying {current_order_qty} shares at ${target_price:.2f} per share. Liquidity: {liquidity}.", flush=True)

        market_order = {
            'type': 'market',
            'side': 'bid',
            'instrument': 'MSFT',
            'qty': min(current_order_qty, int(liquidity * 0.3)),  # Now using only 30% of available liquidity
            'tid': -1
        }

        # Process the market order and capture the return values correctly
        exec_vol, avg_price, slippage_percentage, market_impact = lob._process_market_order(market_order)

        # Update total cost, executed volume, and remaining shares
        total_cost += exec_vol * avg_price
        executed_volume += exec_vol
        remaining_shares -= exec_vol
        transaction_cost = exec_vol * avg_price * (lob.transaction_cost * 1.2)
        transaction_cost_total += transaction_cost

        # Append exec_vol to volumes
        vwap_volumes.append(exec_vol)

        # Collect data for plotting
        vwap_prices.append(avg_price)
        vwap_slippage.append(slippage_percentage)
        vwap_market_impact.append(market_impact)

        print(f"VWAP: Executed {exec_vol} shares at avg price {avg_price:.2f}. Remaining shares: {remaining_shares}.", flush=True)
        print(f"VWAP: Slippage: {slippage_percentage:.4f}, Market Impact: {market_impact:.4f}", flush=True)

        vwap_value = lob.calculate_vwap(lob.trades)
        print(f"VWAP value: {vwap_value}", flush=True)

        lob._generate_external_order()  # Simulate market dynamics
        time.sleep(0.3)

    avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
    transaction_cost_total = round(transaction_cost_total, 2)

    print(f"\n[DEBUG] VWAP Execution Complete: Executed Volume = {executed_volume}, Avg Price = ${avg_price:.2f}, Total Cost = ${total_cost:.2f}, Remaining Shares = {remaining_shares}", flush=True)

    # Return collected data for plotting
    return {
        'prices': vwap_prices,
        'volumes': vwap_volumes,
        'slippage': vwap_slippage,
        'market_impact': vwap_market_impact,
        'total_cost': total_cost,
        'avg_price': avg_price,
        'transaction_cost_total': transaction_cost_total,
        'volume': executed_volume  # Ensure executed_volume is correctly returned
    }

# Adapt the share distribution to follow intraday volume patterns (higher at open/close)
def twap_share_distribution(periods, total_shares):
    # More volume at the open and close of the market
    volume_profile = [0.3, 0.15, 0.1, 0.05, 0.05, 0.05, 0.1, 0.1, 0.1]  # Reflecting realistic intraday liquidity profile
    volume_profile = np.array(volume_profile[:periods]) / np.sum(volume_profile[:periods])  # Normalize the profile
    return (total_shares * volume_profile).astype(int)  # Distribute shares based on the profile

def execute_twap_order(lob, total_shares, periods):
    executed_volume, total_cost = 0, 0
    transaction_cost_total = 0
    remaining_shares = total_shares

    # Replace equal share distribution with intraday volume-adapted distribution
    shares_per_period = twap_share_distribution(periods, total_shares)

    lob.trades.clear()

    # Lists to store data for plotting
    twap_prices, twap_volumes, twap_slippage, twap_market_impact = [], [], [], []

    print(f"\n[DEBUG] TWAP function started to buy {total_shares} shares over {periods} periods.", flush=True)
    lob.print_book(levels=5)  # Print the top 5 levels of the order book before execution

    for period in range(periods):
        if remaining_shares <= 0:
            print(f"\n[DEBUG] TWAP halted: No remaining shares to buy.", flush=True)
            break

        price_range = sorted([p for p in lob.asks.keys() if p > 0])[:5]
        if not price_range:
            print(f"[DEBUG] TWAP halted: No valid prices in the order book.", flush=True)
            break

        target_price = np.random.choice(price_range)
        liquidity = sum(order.quantity for order in lob.asks[target_price])

        # Use the shares_per_period array instead of a fixed amount
        current_order_qty = min(shares_per_period[period], remaining_shares, liquidity)

        if current_order_qty <= 0:
            print(f"[DEBUG] TWAP halted: Insufficient liquidity at price {target_price}.", flush=True)
            break

        print(f"TWAP: Period {period+1}/{periods}: Buying {current_order_qty} shares at ${target_price:.2f} per share.", flush=True)

        market_order = {
            'type': 'market',
            'side': 'bid',
            'instrument': 'MSFT',
            'qty': current_order_qty,
            'tid': -1
        }

        # Process the market order
        exec_vol, avg_price, slippage_percentage, market_impact = lob._process_market_order(market_order)

        # Update total cost, executed volume, and remaining shares
        total_cost += exec_vol * avg_price
        executed_volume += exec_vol
        remaining_shares -= exec_vol
        transaction_cost = exec_vol * avg_price * (lob.transaction_cost * 1.2)
        transaction_cost_total += transaction_cost

        # Append exec_vol to volumes
        twap_volumes.append(exec_vol)

        # Collect data for plotting
        twap_prices.append(avg_price)
        twap_slippage.append(slippage_percentage)
        twap_market_impact.append(market_impact)

        print(f"TWAP: Executed {exec_vol} shares at avg price {avg_price:.2f}. Remaining shares: {remaining_shares}.", flush=True)
        print(f"TWAP: Slippage: {slippage_percentage:.4f}, Market Impact: {market_impact:.4f}", flush=True)

        twap_value = lob.calculate_twap(lob.trades)
        print(f"TWAP value: {twap_value}", flush=True)

        lob._generate_external_order()  # Simulate market dynamics
        time.sleep(0.3)

    avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
    transaction_cost_total = round(transaction_cost_total, 2)

    print(f"\n[DEBUG] TWAP Execution Complete: Executed Volume = {executed_volume}, Avg Price = ${avg_price:.2f}, Total Cost = ${total_cost:.2f}, Remaining Shares = {remaining_shares}", flush=True)

    # Return collected data for plotting
    return {
        'prices': twap_prices,
        'volumes': twap_volumes,
        'slippage': twap_slippage,
        'market_impact': twap_market_impact,
        'total_cost': total_cost,
        'avg_price': avg_price,
        'transaction_cost_total': transaction_cost_total,
        'volume': executed_volume  # Ensure executed_volume is correctly returned
    }

    # Return collected data for plotting
    return {
        'prices': twap_prices,
        'volumes': twap_volumes,
        'slippage': twap_slippage,
        'market_impact': twap_market_impact,
        'total_cost': total_cost,
        'avg_price': avg_price,
        'transaction_cost_total': transaction_cost_total,
        'volume': executed_volume  # Ensure executed_volume is correctly returned
    }

def present_execution_results(vwap_results, twap_results):
    print("\n=== Execution Results Comparison ===\n")
    print(f"{'Metric':<25} {'VWAP':<15} {'TWAP':<15}")
    print("="*55)

    # Present Total Executed Volume
    print(f"{'Executed Volume (shares)':<25} {vwap_results['volume']:<15} {twap_results['volume']:<15}")

    # Present Average Price
    print(f"{'Average Price ($)':<25} {vwap_results['avg_price']:<15} {twap_results['avg_price']:<15}")

    # Present execution results rounded to two decimal places
    print(f"{'Total Cost ($)':<25} {round(vwap_results['total_cost'], 2):<15} {round(twap_results['total_cost'], 2):<15}")

    print(f"{'Transaction Cost ($)':<25} {round(vwap_results['transaction_cost_total'], 2):<15} {round(twap_results['transaction_cost_total'], 2):<15}")

    # Present Slippage
    print(f"{'Slippage (avg %)':<25} {np.mean(vwap_results['slippage']):<15.4f} {np.mean(twap_results['slippage']):<15.4f}")

    # Present Market Impact
    print(f"{'Market Impact (avg %)':<25} {np.mean(vwap_results['market_impact']):<15.4f} {np.mean(twap_results['market_impact']):<15.4f}")

    print("\n=======================================================\n")


# Run both VWAP and TWAP simulations and return structured data for neat presentation
def _run_single_simulation_with_shares(lob, total_shares, twap_periods=10):
    print(f"\n[DEBUG] Running simulation to buy {total_shares} shares", flush=True)

    # VWAP execution
    try:
        print("[DEBUG] Calling VWAP function to buy shares...", flush=True)
        vwap_results = execute_vwap_order_with_shares(lob, total_shares)
        print(f"[DEBUG] VWAP completed. Executed volume: {vwap_results['volume']} shares, "
              f"Avg price: ${vwap_results['avg_price']:.2f}, Transaction cost: ${vwap_results['transaction_cost_total']:.2f}", flush=True)
    except Exception as e:
        print(f"[DEBUG] Error during VWAP execution: {e}", flush=True)
        vwap_results = {
            'volume': 0, 'avg_price': 0, 'transaction_cost_total': 0,
            'slippage': [], 'market_impact': [], 'total_cost': 0
        }

    # TWAP execution with proper handling
    try:
        print("[DEBUG] Calling TWAP function to buy shares...", flush=True)
        twap_results = execute_twap_order(lob, total_shares, twap_periods)
        print(f"[DEBUG] TWAP completed. Executed volume: {twap_results['volume']} shares, "
              f"Avg price: ${twap_results['avg_price']:.2f}, Transaction cost: ${twap_results['transaction_cost_total']:.2f}", flush=True)
    except Exception as e:
        print(f"[DEBUG] Error during TWAP execution: {e}", flush=True)
        twap_results = {
            'volume': 0, 'avg_price': 0, 'transaction_cost_total': 0,
            'slippage': [], 'market_impact': [], 'total_cost': 0
        }

    # Present the results neatly
    present_execution_results(vwap_results, twap_results)

    # Return results for further use if needed
    return {
        'VWAP': {
            'volume': vwap_results['volume'],
            'avg_price': vwap_results['avg_price'],
            'total_cost': vwap_results['total_cost'],
            'transaction_cost': vwap_results['transaction_cost_total'],
            'slippage': vwap_results['slippage'],
            'market_impact': vwap_results['market_impact']
        },
        'TWAP': {
            'volume': twap_results['volume'],
            'avg_price': twap_results['avg_price'],
            'total_cost': twap_results['total_cost'],
            'transaction_cost': twap_results['transaction_cost_total'],
            'slippage': twap_results['slippage'],
            'market_impact': twap_results['market_impact']
        }
    }

# Define and run the simulation for 100,000 shares
print("[DEBUG] Initializing OrderBook...", flush=True)
lob = OrderBook(transaction_cost=0.001)

# Generate the order book from the previously defined aligned_data
try:
    populate_order_book(lob, aligned_data)
except Exception as e:
    print(f"[DEBUG] Error populating order book: {e}", flush=True)

# Check the order book state
check_order_book_state(lob)

# Run VWAP and TWAP simulation
try:
    print("[DEBUG] Starting the VWAP and TWAP simulations...", flush=True)

    # Run VWAP simulation and capture the results
    vwap_results = execute_vwap_order_with_shares(lob, total_shares=100000)

    # Run TWAP simulation and capture the results
    twap_results = execute_twap_order(lob, total_shares=100000, periods=10)

    # Present the execution results neatly
    present_execution_results(vwap_results, twap_results)

except Exception as e:
    print(f"[DEBUG] Error running simulation: {e}", flush=True)

# Output the simulation results
print("\nSimulation Results:")
print(f"VWAP Results: {vwap_results}")
print(f"TWAP Results: {twap_results}")
# Out:
# [DEBUG] Initializing OrderBook...
#
# [DEBUG] Populating the order book with initial data...
# Processing limit order: 855 shares on side ask at price 337.32.
# Processing limit order: 99111 shares on side bid at price 312.37.
# Processing limit order: 90993 shares on side ask at price 312.51.
# Order: 90993 shares; Executed: 4006, Remaining: 86987
# Order: 90993 shares; Executed: 5750, Remaining: 85243
# Order: 90993 shares; Executed: 9357, Remaining: 81636
# Order: 90993 shares; Executed: 13475, Remaining: 77518
# Order: 90993 shares; Executed: 17518, Remaining: 73475
# Order: 90993 shares; Executed: 21059, Remaining: 69934
# Order: 90993 shares; Executed: 23976, Remaining: 67017
# Order: 90993 shares; Executed: 25427, Remaining: 65566
# Order: 90993 shares; Executed: 27348, Remaining: 63645
# Order: 90993 shares; Executed: 31470, Remaining: 59523
# Order: 90993 shares; Executed: 35754, Remaining: 55239
# Order: 90993 shares; Executed: 40211, Remaining: 50782
# Order: 90993 shares; Executed: 43870, Remaining: 47123
# Order: 90993 shares; Executed: 48724, Remaining: 42269
# Order: 90993 shares; Executed: 50797, Remaining: 40196
# Processing limit order: 102737 shares on side bid at price 312.34.
# Processing limit order: 98957 shares on side ask at price 312.54.
# Processing limit order: 84779 shares on side bid at price 312.3.
# Processing limit order: 113723 shares on side ask at price 312.58.
# Processing limit order: 80234 shares on side bid at price 312.27.
# Processing limit order: 1046 shares on side bid at price 311.2.
# Processing limit order: 762 shares on side ask at price 311.6.
# Order: 762 shares; Executed: 762, Remaining: 0
# Processing limit order: 1300 shares on side bid at price 312.26.
# Processing limit order: 95585 shares on side ask at price 312.61.
# Processing limit order: 110621 shares on side bid at price 312.23.
# Processing limit order: 118297 shares on side ask at price 312.65.
# Processing limit order: 93019 shares on side bid at price 312.2.
# Processing limit order: 118270 shares on side ask at price 312.68.
# Processing limit order: 116685 shares on side bid at price 312.16.
# Processing limit order: 84451 shares on side ask at price 312.72.
# Processing limit order: 111800 shares on side bid at price 312.12.
# Processing limit order: 84218 shares on side ask at price 312.76.
# Processing limit order: 84304 shares on side bid at price 312.09.
# Processing limit order: 97756 shares on side ask at price 312.79.
# Processing limit order: 87842 shares on side bid at price 312.06.
# Processing limit order: 82595 shares on side ask at price 312.82.
# Processing limit order: 58877 shares on side bid at price 312.39.
# Processing limit order: 1653 shares on side bid at price 314.22.
# Order: 1653 shares; Executed: 1653, Remaining: 0
# Processing limit order: 60616 shares on side ask at price 312.47.
# Processing limit order: 54345 shares on side bid at price 312.37.
# Processing limit order: 49616 shares on side ask at price 312.49.
# Processing limit order: 48427 shares on side bid at price 312.35.
# Processing limit order: 60740 shares on side ask at price 312.51.
# Processing limit order: 67336 shares on side bid at price 312.33.
# Processing limit order: 57507 shares on side ask at price 312.53.
# Processing limit order: 52085 shares on side bid at price 312.31.
# Processing limit order: 1070 shares on side ask at price 314.3.
# Processing limit order: 61741 shares on side ask at price 312.55.
# Processing limit order: 1767 shares on side bid at price 312.05.
# Processing limit order: 60988 shares on side bid at price 312.29.
# Processing limit order: 59126 shares on side ask at price 312.57.
# Processing limit order: 69284 shares on side bid at price 312.26.
# Processing limit order: 68049 shares on side ask at price 312.6.
# Processing limit order: 963 shares on side ask at price 313.07.
# Processing limit order: 1585 shares on side ask at price 309.9.
# Order: 1585 shares; Executed: 1585, Remaining: 0
# Processing limit order: 66359 shares on side bid at price 312.24.
# Processing limit order: 60629 shares on side ask at price 312.62.
# Processing limit order: 65871 shares on side bid at price 312.22.
# Processing limit order: 70071 shares on side ask at price 312.64.
# Processing limit order: 54179 shares on side bid at price 312.2.
# Processing limit order: 60202 shares on side ask at price 312.66.
# Processing limit order: 32424 shares on side bid at price 313.22.
# Order: 32424 shares; Executed: 32424, Remaining: 0
# Processing limit order: 31186 shares on side ask at price 313.26.
# Processing limit order: 37122 shares on side bid at price 313.2.
# Order: 37122 shares; Executed: 28192, Remaining: 8930
# Order: 37122 shares; Executed: 37122, Remaining: 0
# Processing limit order: 39612 shares on side ask at price 313.28.
# Processing limit order: 36290 shares on side bid at price 313.19.
# Order: 36290 shares; Executed: 36290, Remaining: 0
# Processing limit order: 728 shares on side ask at price 314.44.
# Processing limit order: 634 shares on side bid at price 310.69.
# Processing limit order: 35916 shares on side ask at price 313.29.
# Processing limit order: 1893 shares on side bid at price 310.6.
# Processing limit order: 35254 shares on side bid at price 313.18.
# Order: 35254 shares; Executed: 4396, Remaining: 30858
# Order: 35254 shares; Executed: 35254, Remaining: 0
# Processing limit order: 33521 shares on side ask at price 313.3.
# Processing limit order: 34884 shares on side bid at price 313.17.
# Order: 34884 shares; Executed: 7685, Remaining: 27199
# Order: 34884 shares; Executed: 34884, Remaining: 0
# Processing limit order: 27276 shares on side ask at price 313.31.
# Processing limit order: 36757 shares on side bid at price 313.16.
# Order: 36757 shares; Executed: 33541, Remaining: 3216
# Order: 36757 shares; Executed: 36757, Remaining: 0
# Processing limit order: 28412 shares on side ask at price 313.32.
# Processing limit order: 35780 shares on side bid at price 313.15.
# Order: 35780 shares; Executed: 35780, Remaining: 0
# Processing limit order: 1699 shares on side ask at price 310.59.
# Order: 1699 shares; Executed: 1699, Remaining: 0
# Processing limit order: 39090 shares on side ask at price 313.33.
# Processing limit order: 35705 shares on side bid at price 313.13.
# Order: 35705 shares; Executed: 18511, Remaining: 17194
# Order: 35705 shares; Executed: 35705, Remaining: 0
# Processing limit order: 39525 shares on side ask at price 313.35.
# Processing limit order: 34536 shares on side bid at price 313.12.
# Order: 34536 shares; Executed: 34536, Remaining: 0
# Processing limit order: 38484 shares on side ask at price 313.36.
# Processing limit order: 31655 shares on side bid at price 313.11.
# Order: 31655 shares; Executed: 31655, Remaining: 0
# Processing limit order: 29034 shares on side ask at price 313.37.
# Processing limit order: 16587 shares on side bid at price 313.73.
# Order: 16587 shares; Executed: 15572, Remaining: 1015
# Order: 16587 shares; Executed: 16587, Remaining: 0
# Processing limit order: 1795 shares on side bid at price 312.02.
# Processing limit order: 22755 shares on side ask at price 313.75.
# Processing limit order: 630 shares on side bid at price 310.82.
# Processing limit order: 15993 shares on side bid at price 313.72.
# Order: 15993 shares; Executed: 15993, Remaining: 0
# Processing limit order: 1798 shares on side ask at price 314.76.
# Processing limit order: 16942 shares on side ask at price 313.76.
# Processing limit order: 20397 shares on side bid at price 313.71.
# Order: 20397 shares; Executed: 20397, Remaining: 0
# Processing limit order: 1196 shares on side bid at price 313.05.
# Order: 1196 shares; Executed: 1196, Remaining: 0
# Processing limit order: 21762 shares on side ask at price 313.77.
# Processing limit order: 22828 shares on side bid at price 313.71.
# Order: 22828 shares; Executed: 22828, Remaining: 0
# Processing limit order: 740 shares on side bid at price 315.05.
# Order: 740 shares; Executed: 312, Remaining: 428
# Order: 740 shares; Executed: 740, Remaining: 0
# Processing limit order: 1557 shares on side ask at price 313.87.
# Processing limit order: 21916 shares on side ask at price 313.77.
# Processing limit order: 18504 shares on side bid at price 313.7.
# Order: 18504 shares; Executed: 18504, Remaining: 0
# Processing limit order: 19476 shares on side ask at price 313.78.
# Processing limit order: 19684 shares on side bid at price 313.69.
# Order: 19684 shares; Executed: 19684, Remaining: 0
# Processing limit order: 1352 shares on side bid at price 312.6.
# Order: 1352 shares; Executed: 1352, Remaining: 0
# Processing limit order: 19918 shares on side ask at price 313.79.
# Processing limit order: 15754 shares on side bid at price 313.69.
# Order: 15754 shares; Executed: 15754, Remaining: 0
# Processing limit order: 19633 shares on side ask at price 313.79.
# Processing limit order: 19299 shares on side bid at price 313.68.
# Order: 19299 shares; Executed: 3404, Remaining: 15895
# Order: 19299 shares; Executed: 19299, Remaining: 0
# Processing limit order: 15782 shares on side ask at price 313.8.
# Processing limit order: 17921 shares on side bid at price 313.67.
# Order: 17921 shares; Executed: 17921, Remaining: 0
# Processing limit order: 21182 shares on side ask at price 313.81.
# Processing limit order: 22772 shares on side bid at price 313.66.
# Order: 22772 shares; Executed: 22772, Remaining: 0
# Processing limit order: 18843 shares on side ask at price 313.82.
# Processing limit order: 26815 shares on side bid at price 312.66.
# Order: 26815 shares; Executed: 26815, Remaining: 0
# Processing limit order: 32592 shares on side ask at price 312.7.
# Processing limit order: 1508 shares on side ask at price 311.1.
# Order: 1508 shares; Executed: 1508, Remaining: 0
# Processing limit order: 1788 shares on side bid at price 314.29.
# Order: 1788 shares; Executed: 1788, Remaining: 0
# Processing limit order: 23936 shares on side bid at price 312.65.
# Order: 23936 shares; Executed: 23936, Remaining: 0
# Processing limit order: 665 shares on side bid at price 309.28.
# Processing limit order: 1303 shares on side bid at price 309.79.
# Processing limit order: 27953 shares on side ask at price 312.71.
# Processing limit order: 27917 shares on side bid at price 312.64.
# Order: 27917 shares; Executed: 4596, Remaining: 23321
# Order: 27917 shares; Executed: 27917, Remaining: 0
# Processing limit order: 28799 shares on side ask at price 312.72.
# Processing limit order: 34963 shares on side bid at price 312.63.
# Order: 34963 shares; Executed: 34963, Remaining: 0
# Processing limit order: 32784 shares on side ask at price 312.73.
# Processing limit order: 31724 shares on side bid at price 312.62.
# Order: 31724 shares; Executed: 9765, Remaining: 21959
# Order: 31724 shares; Executed: 31724, Remaining: 0
# Processing limit order: 712 shares on side ask at price 312.95.
# Processing limit order: 32649 shares on side ask at price 312.74.
# Processing limit order: 26605 shares on side bid at price 312.61.
# Order: 26605 shares; Executed: 26605, Remaining: 0
# Processing limit order: 34836 shares on side ask at price 312.75.
# Processing limit order: 28258 shares on side bid at price 312.6.
# Processing limit order: 29547 shares on side ask at price 312.76.
# Processing limit order: 27464 shares on side bid at price 312.59.
# Processing limit order: 29147 shares on side ask at price 312.77.
# Processing limit order: 25631 shares on side bid at price 312.58.
# Processing limit order: 29026 shares on side ask at price 312.78.
# Processing limit order: 26908 shares on side bid at price 312.57.
# Processing limit order: 1764 shares on side bid at price 311.23.
# Processing limit order: 32377 shares on side ask at price 312.79.
# Processing limit order: 25316 shares on side bid at price 311.85.
# Processing limit order: 33702 shares on side ask at price 311.89.
# Order: 33702 shares; Executed: 28258, Remaining: 5444
# Order: 33702 shares; Executed: 33702, Remaining: 0
# Processing limit order: 621 shares on side bid at price 315.14.
# Order: 621 shares; Executed: 621, Remaining: 0
# Processing limit order: 922 shares on side ask at price 310.19.
# Order: 922 shares; Executed: 922, Remaining: 0
# Processing limit order: 28227 shares on side bid at price 311.84.
# Processing limit order: 1598 shares on side bid at price 313.54.
# Order: 1598 shares; Executed: 1598, Remaining: 0
# Processing limit order: 25074 shares on side ask at price 311.9.
# Order: 25074 shares; Executed: 21098, Remaining: 3976
# Order: 25074 shares; Executed: 25074, Remaining: 0
# Processing limit order: 31653 shares on side bid at price 311.83.
# Processing limit order: 25899 shares on side ask at price 311.91.
# Order: 25899 shares; Executed: 21655, Remaining: 4244
# Order: 25899 shares; Executed: 25899, Remaining: 0
# Processing limit order: 1778 shares on side bid at price 315.12.
# Order: 1778 shares; Executed: 1778, Remaining: 0
# Processing limit order: 31106 shares on side bid at price 311.82.
# Processing limit order: 23785 shares on side ask at price 311.92.
# Order: 23785 shares; Executed: 22664, Remaining: 1121
# Order: 23785 shares; Executed: 23785, Remaining: 0
# Processing limit order: 894 shares on side ask at price 315.31.
# Processing limit order: 25925 shares on side bid at price 311.81.
# Processing limit order: 33590 shares on side ask at price 311.93.
# Order: 33590 shares; Executed: 33590, Remaining: 0
# Processing limit order: 748 shares on side ask at price 310.93.
# Order: 748 shares; Executed: 748, Remaining: 0
# Processing limit order: 33802 shares on side bid at price 311.8.
# Processing limit order: 27259 shares on side ask at price 311.94.
# Order: 27259 shares; Executed: 18626, Remaining: 8633
# Order: 27259 shares; Executed: 27259, Remaining: 0
# Processing limit order: 34419 shares on side bid at price 311.79.
# Processing limit order: 27685 shares on side ask at price 311.95.
# Order: 27685 shares; Executed: 27685, Remaining: 0
# Processing limit order: 30262 shares on side bid at price 311.78.
# Processing limit order: 24427 shares on side ask at price 311.96.
# Order: 24427 shares; Executed: 24427, Remaining: 0
# Processing limit order: 26039 shares on side bid at price 311.77.
# Processing limit order: 24423 shares on side ask at price 311.97.
# Order: 24423 shares; Executed: 24423, Remaining: 0
# Processing limit order: 889 shares on side ask at price 313.49.
# Processing limit order: 33599 shares on side bid at price 311.76.
# Processing limit order: 34671 shares on side ask at price 311.98.
# Order: 34671 shares; Executed: 13181, Remaining: 21490
# Order: 34671 shares; Executed: 34671, Remaining: 0
# Processing limit order: 45414 shares on side bid at price 311.62.
# Processing limit order: 52427 shares on side ask at price 311.68.
# Order: 52427 shares; Executed: 32855, Remaining: 19572
# Order: 52427 shares; Executed: 52427, Remaining: 0
# Processing limit order: 49703 shares on side bid at price 311.6.
# Processing limit order: 48494 shares on side ask at price 311.7.
# Order: 48494 shares; Executed: 28855, Remaining: 19639
# Order: 48494 shares; Executed: 48494, Remaining: 0
# Processing limit order: 47791 shares on side bid at price 311.58.
# Processing limit order: 48213 shares on side ask at price 311.72.
# Order: 48213 shares; Executed: 48213, Remaining: 0
# Processing limit order: 55915 shares on side bid at price 311.57.
# Processing limit order: 49617 shares on side ask at price 311.73.
# Order: 49617 shares; Executed: 34885, Remaining: 14732
# Order: 49617 shares; Executed: 49617, Remaining: 0
# Processing limit order: 47340 shares on side bid at price 311.55.
# Processing limit order: 1808 shares on side ask at price 309.57.
# Order: 1808 shares; Executed: 1808, Remaining: 0
# Processing limit order: 47932 shares on side ask at price 311.75.
# Order: 47932 shares; Executed: 47932, Remaining: 0
# Processing limit order: 1447 shares on side ask at price 309.77.
# Order: 1447 shares; Executed: 1447, Remaining: 0
# Processing limit order: 45877 shares on side bid at price 311.53.
# Processing limit order: 58511 shares on side ask at price 311.77.
# Order: 58511 shares; Executed: 1417, Remaining: 57094
# Order: 58511 shares; Executed: 53502, Remaining: 5009
# Order: 58511 shares; Executed: 58511, Remaining: 0
# Processing limit order: 49619 shares on side bid at price 311.52.
# Processing limit order: 55419 shares on side ask at price 311.78.
# Order: 55419 shares; Executed: 55419, Remaining: 0
# Processing limit order: 43555 shares on side bid at price 311.5.
# Processing limit order: 819 shares on side bid at price 310.3.
# Processing limit order: 51433 shares on side ask at price 311.8.
# Order: 51433 shares; Executed: 24351, Remaining: 27082
# Order: 51433 shares; Executed: 51433, Remaining: 0
# Processing limit order: 1162 shares on side ask at price 314.6.
# Processing limit order: 57935 shares on side bid at price 311.48.
# Processing limit order: 56888 shares on side ask at price 311.82.
# Order: 56888 shares; Executed: 33906, Remaining: 22982
# Order: 56888 shares; Executed: 56888, Remaining: 0
# Processing limit order: 52712 shares on side bid at price 311.47.
# Processing limit order: 1087 shares on side bid at price 310.13.
# Processing limit order: 59023 shares on side ask at price 311.83.
# Order: 59023 shares; Executed: 57252, Remaining: 1771
# Order: 59023 shares; Executed: 58552, Remaining: 471
# Order: 59023 shares; Executed: 59023, Remaining: 0
# Processing limit order: 72643 shares on side bid at price 312.43.
# Processing limit order: 72862 shares on side ask at price 312.55.
# Processing limit order: 92753 shares on side bid at price 312.4.
# Processing limit order: 85209 shares on side ask at price 312.58.
# Processing limit order: 105012 shares on side bid at price 312.37.
# Processing limit order: 81232 shares on side ask at price 312.61.
# Processing limit order: 87954 shares on side bid at price 312.34.
# Processing limit order: 84378 shares on side ask at price 312.64.
# Processing limit order: 964 shares on side bid at price 311.49.
# Processing limit order: 104752 shares on side bid at price 312.31.
# Processing limit order: 99131 shares on side ask at price 312.67.
# Processing limit order: 104620 shares on side bid at price 312.28.
# Processing limit order: 103202 shares on side ask at price 312.7.
# Processing limit order: 945 shares on side ask at price 313.22.
# Processing limit order: 75288 shares on side bid at price 312.25.
# Processing limit order: 82956 shares on side ask at price 312.73.
# Processing limit order: 88633 shares on side bid at price 312.22.
# Processing limit order: 1637 shares on side bid at price 313.52.
# Order: 1637 shares; Executed: 1637, Remaining: 0
# Processing limit order: 98874 shares on side ask at price 312.76.
# Processing limit order: 86923 shares on side bid at price 312.19.
# Processing limit order: 73854 shares on side ask at price 312.79.
# Processing limit order: 90799 shares on side bid at price 312.16.
# Processing limit order: 104020 shares on side ask at price 312.82.
# Processing limit order: 28813 shares on side bid at price 311.18.
# Processing limit order: 951 shares on side bid at price 309.88.
# Processing limit order: 25958 shares on side ask at price 311.22.
# Order: 25958 shares; Executed: 25958, Remaining: 0
# Processing limit order: 25948 shares on side bid at price 311.17.
# Processing limit order: 27901 shares on side ask at price 311.23.
# Order: 27901 shares; Executed: 27901, Remaining: 0
# Processing limit order: 24953 shares on side bid at price 311.16.
# Processing limit order: 28445 shares on side ask at price 311.24.
# Order: 28445 shares; Executed: 18784, Remaining: 9661
# Order: 28445 shares; Executed: 28445, Remaining: 0
# Processing limit order: 26092 shares on side bid at price 311.15.
# Processing limit order: 31915 shares on side ask at price 311.25.
# Order: 31915 shares; Executed: 31915, Remaining: 0
# Processing limit order: 29545 shares on side bid at price 311.14.
# Processing limit order: 28348 shares on side ask at price 311.26.
# Order: 28348 shares; Executed: 28348, Remaining: 0
# Processing limit order: 24911 shares on side bid at price 311.13.
# Processing limit order: 25970 shares on side ask at price 311.27.
# Order: 25970 shares; Executed: 22829, Remaining: 3141
# Order: 25970 shares; Executed: 25970, Remaining: 0
# Processing limit order: 31911 shares on side bid at price 311.12.
# Processing limit order: 992 shares on side ask at price 309.84.
# Order: 992 shares; Executed: 992, Remaining: 0
# Processing limit order: 24953 shares on side ask at price 311.28.
# Order: 24953 shares; Executed: 24953, Remaining: 0
# Processing limit order: 26032 shares on side bid at price 311.11.
# Processing limit order: 28757 shares on side ask at price 311.29.
# Order: 28757 shares; Executed: 28757, Remaining: 0
# Processing limit order: 27199 shares on side bid at price 311.1.
# Processing limit order: 1971 shares on side bid at price 312.05.
# Processing limit order: 27151 shares on side ask at price 311.3.
# Order: 27151 shares; Executed: 27151, Remaining: 0
# Processing limit order: 27224 shares on side bid at price 311.09.
# Processing limit order: 30219 shares on side ask at price 311.31.
# Order: 30219 shares; Executed: 20018, Remaining: 10201
# Order: 30219 shares; Executed: 30219, Remaining: 0
# Processing limit order: 61943 shares on side bid at price 310.81.
# Processing limit order: 62298 shares on side ask at price 310.89.
# Order: 62298 shares; Executed: 62298, Remaining: 0
# Processing limit order: 64957 shares on side bid at price 310.79.
# Processing limit order: 66187 shares on side ask at price 310.91.
# Order: 66187 shares; Executed: 15455, Remaining: 50732
# Order: 66187 shares; Executed: 66187, Remaining: 0
# Processing limit order: 1725 shares on side ask at price 310.21.
# Order: 1725 shares; Executed: 1725, Remaining: 0
# Processing limit order: 51949 shares on side bid at price 310.76.
# Processing limit order: 63119 shares on side ask at price 310.94.
# Order: 63119 shares; Executed: 52295, Remaining: 10824
# Order: 63119 shares; Executed: 63119, Remaining: 0
# Processing limit order: 70972 shares on side bid at price 310.74.
# Processing limit order: 54961 shares on side ask at price 310.96.
# Order: 54961 shares; Executed: 54961, Remaining: 0
# Processing limit order: 69460 shares on side bid at price 310.72.
# Processing limit order: 67093 shares on side ask at price 310.98.
# Order: 67093 shares; Executed: 38835, Remaining: 28258
# Order: 67093 shares; Executed: 67093, Remaining: 0
# Processing limit order: 60887 shares on side bid at price 310.7.
# Processing limit order: 71439 shares on side ask at price 311.0.
# Order: 71439 shares; Executed: 40555, Remaining: 30884
# Order: 71439 shares; Executed: 71439, Remaining: 0
# Processing limit order: 49491 shares on side bid at price 310.68.
# Processing limit order: 69376 shares on side ask at price 311.02.
# Order: 69376 shares; Executed: 44404, Remaining: 24972
# Order: 69376 shares; Executed: 69376, Remaining: 0
# Processing limit order: 71092 shares on side bid at price 310.66.
# Processing limit order: 49506 shares on side ask at price 311.04.
# Order: 49506 shares; Executed: 41387, Remaining: 8119
# Order: 49506 shares; Executed: 49506, Remaining: 0
# Processing limit order: 68036 shares on side bid at price 310.64.
# Processing limit order: 72880 shares on side ask at price 311.06.
# Order: 72880 shares; Executed: 72880, Remaining: 0
# Processing limit order: 66207 shares on side bid at price 310.62.
# Processing limit order: 50915 shares on side ask at price 311.08.
# Order: 50915 shares; Executed: 29622, Remaining: 21293
# Order: 50915 shares; Executed: 50915, Remaining: 0
# Processing limit order: 580 shares on side ask at price 315.13.
# Processing limit order: 890 shares on side ask at price 313.93.
# Processing limit order: 35653 shares on side bid at price 312.22.
# Processing limit order: 1056 shares on side ask at price 313.63.
# Processing limit order: 31222 shares on side ask at price 312.26.
# Processing limit order: 27202 shares on side bid at price 312.2.
# Processing limit order: 31325 shares on side ask at price 312.28.
# Processing limit order: 1513 shares on side ask at price 314.73.
# Processing limit order: 1865 shares on side ask at price 313.13.
# Processing limit order: 32961 shares on side bid at price 312.19.
# Processing limit order: 38902 shares on side ask at price 312.29.
# Processing limit order: 30665 shares on side bid at price 312.18.
# Processing limit order: 1823 shares on side ask at price 311.53.
# Order: 1823 shares; Executed: 1823, Remaining: 0
# Processing limit order: 34910 shares on side ask at price 312.3.
# Processing limit order: 36044 shares on side bid at price 312.17.
# Processing limit order: 28593 shares on side ask at price 312.31.
# Processing limit order: 34089 shares on side bid at price 312.16.
# Processing limit order: 1191 shares on side bid at price 313.61.
# Order: 1191 shares; Executed: 1191, Remaining: 0
# Processing limit order: 29102 shares on side ask at price 312.32.
# Processing limit order: 26301 shares on side bid at price 312.15.
# Processing limit order: 33509 shares on side ask at price 312.33.
# Processing limit order: 26307 shares on side bid at price 312.13.
# Processing limit order: 31103 shares on side ask at price 312.35.
# Processing limit order: 28258 shares on side bid at price 312.12.
# Processing limit order: 1103 shares on side ask at price 310.67.
# Order: 1103 shares; Executed: 1103, Remaining: 0
# Processing limit order: 29884 shares on side ask at price 312.36.
# Processing limit order: 1216 shares on side ask at price 314.75.
# Processing limit order: 27984 shares on side bid at price 312.11.
# Processing limit order: 1856 shares on side bid at price 310.0.
# Processing limit order: 35777 shares on side ask at price 312.37.
# Processing limit order: 34585 shares on side bid at price 311.83.
# Processing limit order: 1024 shares on side bid at price 309.79.
# Processing limit order: 38548 shares on side ask at price 311.89.
# Order: 38548 shares; Executed: 38548, Remaining: 0
# Processing limit order: 32019 shares on side bid at price 311.82.
# Processing limit order: 33043 shares on side ask at price 311.9.
# Order: 33043 shares; Executed: 3104, Remaining: 29939
# Order: 33043 shares; Executed: 33043, Remaining: 0
# Processing limit order: 42094 shares on side bid at price 311.81.
# Processing limit order: 1062 shares on side bid at price 315.3.
# Order: 1062 shares; Executed: 1062, Remaining: 0
# Processing limit order: 36153 shares on side ask at price 311.91.
# Order: 36153 shares; Executed: 36153, Remaining: 0
# Processing limit order: 34048 shares on side bid at price 311.79.
# Processing limit order: 38333 shares on side ask at price 311.93.
# Order: 38333 shares; Executed: 22541, Remaining: 15792
# Order: 38333 shares; Executed: 38333, Remaining: 0
# Processing limit order: 34560 shares on side bid at price 311.78.
# Processing limit order: 37396 shares on side ask at price 311.94.
# Order: 37396 shares; Executed: 19861, Remaining: 17535
# Order: 37396 shares; Executed: 37396, Remaining: 0
# Processing limit order: 1167 shares on side bid at price 313.88.
# Order: 1167 shares; Executed: 1167, Remaining: 0
# Processing limit order: 34329 shares on side bid at price 311.77.
# Processing limit order: 30707 shares on side ask at price 311.95.
# Order: 30707 shares; Executed: 30707, Remaining: 0
# Processing limit order: 34714 shares on side bid at price 311.75.
# Processing limit order: 39093 shares on side ask at price 311.97.
# Order: 39093 shares; Executed: 39093, Remaining: 0
# Processing limit order: 30486 shares on side bid at price 311.74.
# Processing limit order: 39079 shares on side ask at price 311.98.
# Order: 39079 shares; Executed: 5684, Remaining: 33395
# Order: 39079 shares; Executed: 39079, Remaining: 0
# Processing limit order: 35771 shares on side bid at price 311.73.
# Processing limit order: 33590 shares on side ask at price 311.99.
# Order: 33590 shares; Executed: 20784, Remaining: 12806
# Order: 33590 shares; Executed: 33590, Remaining: 0
# Processing limit order: 42442 shares on side bid at price 311.72.
# Processing limit order: 33423 shares on side ask at price 312.0.
# Order: 33423 shares; Executed: 14396, Remaining: 19027
# Order: 33423 shares; Executed: 33423, Remaining: 0
# Processing limit order: 41809 shares on side bid at price 311.69.
# Processing limit order: 45863 shares on side ask at price 311.75.
# Order: 45863 shares; Executed: 45863, Remaining: 0
# Processing limit order: 1102 shares on side ask at price 312.83.
# Processing limit order: 50461 shares on side bid at price 311.67.
# Processing limit order: 41611 shares on side ask at price 311.77.
# Order: 41611 shares; Executed: 22033, Remaining: 19578
# Order: 41611 shares; Executed: 41611, Remaining: 0
# Processing limit order: 1643 shares on side bid at price 311.84.
# Processing limit order: 41964 shares on side bid at price 311.66.
# Processing limit order: 39297 shares on side ask at price 311.78.
# Order: 39297 shares; Executed: 13383, Remaining: 25914
# Order: 39297 shares; Executed: 39297, Remaining: 0
# Processing limit order: 45671 shares on side bid at price 311.64.
# Processing limit order: 39578 shares on side ask at price 311.8.
# Order: 39578 shares; Executed: 4751, Remaining: 34827
# Order: 39578 shares; Executed: 39578, Remaining: 0
# Processing limit order: 46751 shares on side bid at price 311.62.
# Processing limit order: 42435 shares on side ask at price 311.82.
# Order: 42435 shares; Executed: 1217, Remaining: 41218
# Order: 42435 shares; Executed: 42435, Remaining: 0
# Processing limit order: 46085 shares on side bid at price 311.61.
# Processing limit order: 39290 shares on side ask at price 311.83.
# Order: 39290 shares; Executed: 39290, Remaining: 0
# Processing limit order: 41417 shares on side bid at price 311.59.
# Processing limit order: 1088 shares on side ask at price 310.92.
# Order: 1088 shares; Executed: 1088, Remaining: 0
# Processing limit order: 38661 shares on side ask at price 311.85.
# Order: 38661 shares; Executed: 35089, Remaining: 3572
# Order: 38661 shares; Executed: 38661, Remaining: 0
# Processing limit order: 706 shares on side bid at price 309.94.
# Processing limit order: 51739 shares on side bid at price 311.58.
# Processing limit order: 41542 shares on side ask at price 311.86.
# Order: 41542 shares; Executed: 41542, Remaining: 0
# Processing limit order: 45228 shares on side bid at price 311.56.
# Processing limit order: 1732 shares on side bid at price 315.16.
# Order: 1732 shares; Executed: 1732, Remaining: 0
# Processing limit order: 45305 shares on side ask at price 311.88.
# Order: 45305 shares; Executed: 45305, Remaining: 0
# Processing limit order: 37025 shares on side bid at price 311.54.
# Processing limit order: 49834 shares on side ask at price 311.9.
# Order: 49834 shares; Executed: 380, Remaining: 49454
# Order: 49834 shares; Executed: 34469, Remaining: 15365
# Order: 49834 shares; Executed: 49834, Remaining: 0
# Processing limit order: 55040 shares on side bid at price 311.48.
# Processing limit order: 52542 shares on side ask at price 311.56.
# Order: 52542 shares; Executed: 10936, Remaining: 41606
# Order: 52542 shares; Executed: 37243, Remaining: 15299
# Order: 52542 shares; Executed: 52542, Remaining: 0
# Processing limit order: 53563 shares on side bid at price 311.46.
# Processing limit order: 41019 shares on side ask at price 311.58.
# Order: 41019 shares; Executed: 41019, Remaining: 0
# Processing limit order: 1068 shares on side ask at price 309.38.
# Order: 1068 shares; Executed: 1068, Remaining: 0
# Processing limit order: 56323 shares on side bid at price 311.45.
# Processing limit order: 40681 shares on side ask at price 311.59.
# Order: 40681 shares; Executed: 40681, Remaining: 0
# Processing limit order: 56779 shares on side bid at price 311.43.
# Processing limit order: 40928 shares on side ask at price 311.61.
# Order: 40928 shares; Executed: 13733, Remaining: 27195
# Order: 40928 shares; Executed: 40928, Remaining: 0
# Processing limit order: 49707 shares on side bid at price 311.41.
# Processing limit order: 47988 shares on side ask at price 311.63.
# Order: 47988 shares; Executed: 1063, Remaining: 46925
# Order: 47988 shares; Executed: 29047, Remaining: 18941
# Order: 47988 shares; Executed: 47988, Remaining: 0
# Processing limit order: 53321 shares on side bid at price 311.39.
# Processing limit order: 1065 shares on side ask at price 314.74.
# Processing limit order: 51433 shares on side ask at price 311.65.
# Order: 51433 shares; Executed: 51433, Remaining: 0
# Processing limit order: 47650 shares on side bid at price 311.37.
# Processing limit order: 45921 shares on side ask at price 311.67.
# Order: 45921 shares; Executed: 13930, Remaining: 31991
# Order: 45921 shares; Executed: 45921, Remaining: 0
# Processing limit order: 45033 shares on side bid at price 311.35.
# Processing limit order: 47476 shares on side ask at price 311.69.
# Order: 47476 shares; Executed: 47476, Remaining: 0
# Processing limit order: 46390 shares on side bid at price 311.34.
# Processing limit order: 1435 shares on side bid at price 314.22.
# Order: 1435 shares; Executed: 1435, Remaining: 0
# Processing limit order: 47413 shares on side ask at price 311.7.
# Order: 47413 shares; Executed: 8375, Remaining: 39038
# Order: 47413 shares; Executed: 10142, Remaining: 37271
# Order: 47413 shares; Executed: 12113, Remaining: 35300
# Order: 47413 shares; Executed: 13908, Remaining: 33505
# Order: 47413 shares; Executed: 39224, Remaining: 8189
# Order: 47413 shares; Executed: 47413, Remaining: 0
# Processing limit order: 46187 shares on side bid at price 311.32.
# Processing limit order: 47766 shares on side ask at price 311.72.
# Order: 47766 shares; Executed: 20038, Remaining: 27728
# Order: 47766 shares; Executed: 21681, Remaining: 26085
# Order: 47766 shares; Executed: 47766, Remaining: 0
# Processing limit order: 82124 shares on side bid at price 310.34.
# Processing limit order: 980 shares on side bid at price 313.45.
# Order: 980 shares; Executed: 980, Remaining: 0
# Processing limit order: 688 shares on side ask at price 311.21.
# Order: 688 shares; Executed: 688, Remaining: 0
# Processing limit order: 946 shares on side bid at price 311.18.
# Processing limit order: 111624 shares on side ask at price 310.48.
# Order: 111624 shares; Executed: 4880, Remaining: 106744
# Order: 111624 shares; Executed: 39465, Remaining: 72159
# Order: 111624 shares; Executed: 70571, Remaining: 41053
# Order: 111624 shares; Executed: 102590, Remaining: 9034
# Order: 111624 shares; Executed: 111624, Remaining: 0
# Processing limit order: 108158 shares on side bid at price 310.3.
# Processing limit order: 769 shares on side bid at price 309.34.
# Processing limit order: 78518 shares on side ask at price 310.52.
# Order: 78518 shares; Executed: 16891, Remaining: 61627
# Order: 78518 shares; Executed: 58985, Remaining: 19533
# Order: 78518 shares; Executed: 78518, Remaining: 0
# Processing limit order: 106443 shares on side bid at price 310.27.
# Processing limit order: 83189 shares on side ask at price 310.55.
# Order: 83189 shares; Executed: 14269, Remaining: 68920
# Order: 83189 shares; Executed: 48688, Remaining: 34501
# Order: 83189 shares; Executed: 82736, Remaining: 453
# Order: 83189 shares; Executed: 83189, Remaining: 0
# Processing limit order: 1943 shares on side ask at price 310.64.
# Order: 1943 shares; Executed: 1943, Remaining: 0
# Processing limit order: 111939 shares on side bid at price 310.23.
# Processing limit order: 111036 shares on side ask at price 310.59.
# Order: 111036 shares; Executed: 27866, Remaining: 83170
# Order: 111036 shares; Executed: 62426, Remaining: 48610
# Order: 111036 shares; Executed: 88465, Remaining: 22571
# Order: 111036 shares; Executed: 111036, Remaining: 0
# Processing limit order: 1358 shares on side bid at price 309.46.
# Processing limit order: 84599 shares on side bid at price 310.2.
# Processing limit order: 113781 shares on side ask at price 310.62.
# Order: 113781 shares; Executed: 11758, Remaining: 102023
# Order: 113781 shares; Executed: 45357, Remaining: 68424
# Order: 113781 shares; Executed: 80071, Remaining: 33710
# Order: 113781 shares; Executed: 110557, Remaining: 3224
# Order: 113781 shares; Executed: 113781, Remaining: 0
# Processing limit order: 105029 shares on side bid at price 310.16.
# Processing limit order: 106631 shares on side ask at price 310.66.
# Order: 106631 shares; Executed: 32547, Remaining: 74084
# Order: 106631 shares; Executed: 74989, Remaining: 31642
# Order: 106631 shares; Executed: 106631, Remaining: 0
# Processing limit order: 108488 shares on side bid at price 310.13.
# Processing limit order: 104144 shares on side ask at price 310.69.
# Order: 104144 shares; Executed: 10167, Remaining: 93977
# Order: 104144 shares; Executed: 60628, Remaining: 43516
# Order: 104144 shares; Executed: 102592, Remaining: 1552
# Order: 104144 shares; Executed: 104144, Remaining: 0
# Processing limit order: 104949 shares on side bid at price 310.09.
# Processing limit order: 112087 shares on side ask at price 310.73.
# Order: 112087 shares; Executed: 44119, Remaining: 67968
# Order: 112087 shares; Executed: 89533, Remaining: 22554
# Order: 112087 shares; Executed: 112087, Remaining: 0
# Processing limit order: 109319 shares on side bid at price 310.05.
# Processing limit order: 110111 shares on side ask at price 310.77.
# Order: 110111 shares; Executed: 24197, Remaining: 85914
# Order: 110111 shares; Executed: 70282, Remaining: 39829
# Order: 110111 shares; Executed: 110111, Remaining: 0
# Processing limit order: 93021 shares on side bid at price 310.02.
# Processing limit order: 103209 shares on side ask at price 310.8.
# Order: 103209 shares; Executed: 9874, Remaining: 93335
# Order: 103209 shares; Executed: 51291, Remaining: 51918
# Order: 103209 shares; Executed: 99082, Remaining: 4127
# Order: 103209 shares; Executed: 103209, Remaining: 0
# Processing limit order: 37094 shares on side bid at price 312.46.
# Order: 37094 shares; Executed: 23655, Remaining: 13439
# Order: 37094 shares; Executed: 37094, Remaining: 0
# Processing limit order: 48404 shares on side ask at price 312.52.
# Processing limit order: 39697 shares on side bid at price 312.44.
# Order: 39697 shares; Executed: 17886, Remaining: 21811
# Order: 39697 shares; Executed: 39697, Remaining: 0
# Processing limit order: 38597 shares on side ask at price 312.54.
# Processing limit order: 37252 shares on side bid at price 312.43.
# Order: 37252 shares; Executed: 17091, Remaining: 20161
# Order: 37252 shares; Executed: 37252, Remaining: 0
# Processing limit order: 40406 shares on side ask at price 312.55.
# Processing limit order: 44447 shares on side bid at price 312.41.
# Order: 44447 shares; Executed: 14749, Remaining: 29698
# Order: 44447 shares; Executed: 43342, Remaining: 1105
# Order: 44447 shares; Executed: 44447, Remaining: 0
# Processing limit order: 42285 shares on side ask at price 312.57.
# Processing limit order: 37609 shares on side bid at price 312.4.
# Order: 37609 shares; Executed: 27997, Remaining: 9612
# Order: 37609 shares; Executed: 37609, Remaining: 0
# Processing limit order: 1673 shares on side bid at price 310.77.
# Processing limit order: 1710 shares on side bid at price 311.63.
# Processing limit order: 46538 shares on side ask at price 312.58.
# Processing limit order: 36735 shares on side bid at price 312.38.
# Order: 36735 shares; Executed: 23897, Remaining: 12838
# Order: 36735 shares; Executed: 36735, Remaining: 0
# Processing limit order: 34003 shares on side ask at price 312.6.
# Processing limit order: 1795 shares on side bid at price 309.48.
# Processing limit order: 47314 shares on side bid at price 312.37.
# Order: 47314 shares; Executed: 18265, Remaining: 29049
# Order: 47314 shares; Executed: 47314, Remaining: 0
# Processing limit order: 43403 shares on side ask at price 312.61.
# Processing limit order: 40568 shares on side bid at price 312.35.
# Processing limit order: 33801 shares on side ask at price 312.63.
# Processing limit order: 36871 shares on side bid at price 312.33.
# Processing limit order: 38422 shares on side ask at price 312.65.
# Processing limit order: 44320 shares on side bid at price 312.32.
# Processing limit order: 48979 shares on side ask at price 312.66.
# Processing limit order: 18615 shares on side bid at price 312.3.
# Processing limit order: 18262 shares on side ask at price 312.32.
# Order: 18262 shares; Executed: 18262, Remaining: 0
# Processing limit order: 13629 shares on side bid at price 312.29.
# Processing limit order: 848 shares on side ask at price 313.06.
# Processing limit order: 15893 shares on side ask at price 312.33.
# Order: 15893 shares; Executed: 15893, Remaining: 0
# Processing limit order: 1082 shares on side ask at price 314.16.
# Processing limit order: 16011 shares on side bid at price 312.29.
# Processing limit order: 17444 shares on side ask at price 312.33.
# Order: 17444 shares; Executed: 6413, Remaining: 11031
# Order: 17444 shares; Executed: 17444, Remaining: 0
# Processing limit order: 15228 shares on side bid at price 312.28.
# Processing limit order: 12744 shares on side ask at price 312.34.
# Processing limit order: 14842 shares on side bid at price 312.27.
# Processing limit order: 16503 shares on side ask at price 312.35.
# Processing limit order: 12987 shares on side bid at price 312.27.
# Processing limit order: 18199 shares on side ask at price 312.35.
# Processing limit order: 13079 shares on side bid at price 312.26.
# Processing limit order: 12741 shares on side ask at price 312.36.
# Processing limit order: 15877 shares on side bid at price 312.26.
# Processing limit order: 17555 shares on side ask at price 312.36.
# Processing limit order: 15657 shares on side bid at price 312.25.
# Processing limit order: 12662 shares on side ask at price 312.37.
# Processing limit order: 13186 shares on side bid at price 312.24.
# Processing limit order: 924 shares on side ask at price 314.36.
# Processing limit order: 768 shares on side ask at price 312.12.
# Order: 768 shares; Executed: 768, Remaining: 0
# Processing limit order: 16872 shares on side ask at price 312.38.
# Processing limit order: 1507 shares on side bid at price 312.62.
# Order: 1507 shares; Executed: 1507, Remaining: 0
# Processing limit order: 22504 shares on side bid at price 313.36.
# Order: 22504 shares; Executed: 11237, Remaining: 11267
# Order: 22504 shares; Executed: 22504, Remaining: 0
# Processing limit order: 25038 shares on side ask at price 313.4.
# Processing limit order: 25278 shares on side bid at price 313.35.
# Order: 25278 shares; Executed: 5236, Remaining: 20042
# Order: 25278 shares; Executed: 23435, Remaining: 1843
# Order: 25278 shares; Executed: 24270, Remaining: 1008
# Order: 25278 shares; Executed: 25278, Remaining: 0
# Processing limit order: 29437 shares on side ask at price 313.41.
# Processing limit order: 21397 shares on side bid at price 313.34.
# Order: 21397 shares; Executed: 11733, Remaining: 9664
# Order: 21397 shares; Executed: 21397, Remaining: 0
# Processing limit order: 21157 shares on side ask at price 313.42.
# Processing limit order: 22444 shares on side bid at price 313.33.
# Order: 22444 shares; Executed: 7891, Remaining: 14553
# Order: 22444 shares; Executed: 22444, Remaining: 0
# Processing limit order: 29976 shares on side ask at price 313.43.
# Processing limit order: 29133 shares on side bid at price 313.32.
# Order: 29133 shares; Executed: 21224, Remaining: 7909
# Order: 29133 shares; Executed: 29133, Remaining: 0
# Processing limit order: 1695 shares on side bid at price 313.63.
# Order: 1695 shares; Executed: 1695, Remaining: 0
# Processing limit order: 23896 shares on side ask at price 313.44.
# Processing limit order: 23222 shares on side bid at price 313.31.
# Order: 23222 shares; Executed: 3058, Remaining: 20164
# Order: 23222 shares; Executed: 19930, Remaining: 3292
# Order: 23222 shares; Executed: 23222, Remaining: 0
# Processing limit order: 26553 shares on side ask at price 313.45.
# Processing limit order: 23769 shares on side bid at price 313.3.
# Order: 23769 shares; Executed: 23769, Remaining: 0
# Processing limit order: 27268 shares on side ask at price 313.46.
# Processing limit order: 21595 shares on side bid at price 313.29.
# Order: 21595 shares; Executed: 21343, Remaining: 252
# Order: 21595 shares; Executed: 21595, Remaining: 0
# Processing limit order: 27672 shares on side ask at price 313.47.
# Processing limit order: 22328 shares on side bid at price 313.28.
# Order: 22328 shares; Executed: 22328, Remaining: 0
# Processing limit order: 30660 shares on side ask at price 313.48.
# Processing limit order: 1591 shares on side bid at price 315.34.
# Order: 1591 shares; Executed: 1591, Remaining: 0
# Processing limit order: 633 shares on side bid at price 310.96.
# Processing limit order: 1726 shares on side ask at price 314.4.
# Processing limit order: 22430 shares on side bid at price 313.27.
# Order: 22430 shares; Executed: 14426, Remaining: 8004
# Order: 22430 shares; Executed: 22430, Remaining: 0
# Processing limit order: 28674 shares on side ask at price 313.49.
# Processing limit order: 46331 shares on side bid at price 313.86.
# Order: 46331 shares; Executed: 46331, Remaining: 0
# Processing limit order: 41860 shares on side ask at price 313.92.
# Processing limit order: 43230 shares on side bid at price 313.84.
# Order: 43230 shares; Executed: 16890, Remaining: 26340
# Order: 43230 shares; Executed: 43230, Remaining: 0
# Processing limit order: 45619 shares on side ask at price 313.94.
# Processing limit order: 39339 shares on side bid at price 313.82.
# Order: 39339 shares; Executed: 14066, Remaining: 25273
# Order: 39339 shares; Executed: 39339, Remaining: 0
# Processing limit order: 46509 shares on side ask at price 313.96.
# Processing limit order: 35513 shares on side bid at price 313.81.
# Order: 35513 shares; Executed: 17012, Remaining: 18501
# Order: 35513 shares; Executed: 35513, Remaining: 0
# Processing limit order: 48425 shares on side ask at price 313.97.
# Processing limit order: 43520 shares on side bid at price 313.79.
# Order: 43520 shares; Executed: 43520, Remaining: 0
# Processing limit order: 1868 shares on side ask at price 313.61.
# Processing limit order: 48241 shares on side ask at price 313.99.
# Processing limit order: 49433 shares on side bid at price 313.77.
# Order: 49433 shares; Executed: 23188, Remaining: 26245
# Order: 49433 shares; Executed: 49433, Remaining: 0
# Processing limit order: 48897 shares on side ask at price 314.01.
# Processing limit order: 46167 shares on side bid at price 313.76.
# Order: 46167 shares; Executed: 20293, Remaining: 25874
# Order: 46167 shares; Executed: 46167, Remaining: 0
# Processing limit order: 37085 shares on side ask at price 314.02.
# Processing limit order: 36536 shares on side bid at price 313.74.
# Order: 36536 shares; Executed: 8129, Remaining: 28407
# Order: 36536 shares; Executed: 36536, Remaining: 0
# Processing limit order: 50189 shares on side ask at price 314.04.
# Processing limit order: 48030 shares on side bid at price 313.72.
# Order: 48030 shares; Executed: 14617, Remaining: 33413
# Order: 48030 shares; Executed: 48030, Remaining: 0
# Processing limit order: 883 shares on side bid at price 314.02.
# Order: 883 shares; Executed: 883, Remaining: 0
# Processing limit order: 36605 shares on side ask at price 314.06.
# Processing limit order: 52010 shares on side bid at price 313.71.
# Order: 52010 shares; Executed: 46936, Remaining: 5074
# Order: 52010 shares; Executed: 52010, Remaining: 0
# Processing limit order: 1624 shares on side bid at price 313.75.
# Order: 1624 shares; Executed: 1624, Remaining: 0
# Processing limit order: 44223 shares on side ask at price 314.07.
# Processing limit order: 82946 shares on side bid at price 310.7.
# Processing limit order: 74246 shares on side ask at price 310.8.
# Order: 74246 shares; Executed: 25072, Remaining: 49174
# Order: 74246 shares; Executed: 69392, Remaining: 4854
# Order: 74246 shares; Executed: 74246, Remaining: 0
# Processing limit order: 1816 shares on side ask at price 310.77.
# Order: 1816 shares; Executed: 1816, Remaining: 0
# Processing limit order: 56626 shares on side bid at price 310.67.
# Processing limit order: 64671 shares on side ask at price 310.83.
# Order: 64671 shares; Executed: 11945, Remaining: 52726
# Order: 64671 shares; Executed: 25574, Remaining: 39097
# Order: 64671 shares; Executed: 41585, Remaining: 23086
# Order: 64671 shares; Executed: 56813, Remaining: 7858
# Order: 64671 shares; Executed: 64671, Remaining: 0
# Processing limit order: 79153 shares on side bid at price 310.65.
# Processing limit order: 82627 shares on side ask at price 310.85.
# Order: 82627 shares; Executed: 6984, Remaining: 75643
# Order: 82627 shares; Executed: 19971, Remaining: 62656
# Order: 82627 shares; Executed: 33050, Remaining: 49577
# Order: 82627 shares; Executed: 48927, Remaining: 33700
# Order: 82627 shares; Executed: 64584, Remaining: 18043
# ...
# Order: 100608 shares; Executed: 100608, Remaining: 0
# Processing limit order: 87454 shares on side ask at price 347.21.
# Processing limit order: 93332 shares on side bid at price 346.96.
# Order: 93332 shares; Executed: 18582, Remaining: 74750
# Order: 93332 shares; Executed: 47781, Remaining: 45551
# Order: 93332 shares; Executed: 76594, Remaining: 16738
# Order: 93332 shares; Executed: 93332, Remaining: 0
# Processing limit order: 72526 shares on side ask at price 347.24.
# Processing limit order: 905 shares on side bid at price 340.88.
# Processing limit order: 93518 shares on side bid at price 346.92.
# Order: 93518 shares; Executed: 11213, Remaining: 82305
# Order: 93518 shares; Executed: 37000, Remaining: 56518
# Order: 93518 shares; Executed: 61392, Remaining: 32126
# Order: 93518 shares; Executed: 85058, Remaining: 8460
# Order: 93518 shares; Executed: 87057, Remaining: 6461
# Order: 93518 shares; Executed: 93518, Remaining: 0
# Processing limit order: 102751 shares on side ask at price 347.28.
# Processing limit order: 99795 shares on side bid at price 346.89.
# Order: 99795 shares; Executed: 57279, Remaining: 42516
# Order: 99795 shares; Executed: 78865, Remaining: 20930
# Order: 99795 shares; Executed: 99795, Remaining: 0
# Processing limit order: 77360 shares on side ask at price 347.31.
# Processing limit order: 614 shares on side ask at price 344.16.
# Processing limit order: 103443 shares on side bid at price 346.85.
# Order: 103443 shares; Executed: 7738, Remaining: 95705
# Order: 103443 shares; Executed: 32903, Remaining: 70540
# Order: 103443 shares; Executed: 103443, Remaining: 0
# Processing limit order: 1500 shares on side ask at price 341.61.
# Order: 1500 shares; Executed: 952, Remaining: 548
# Order: 1500 shares; Executed: 1500, Remaining: 0
# Processing limit order: 71847 shares on side ask at price 347.35.
# Processing limit order: 99708 shares on side bid at price 346.81.
# Order: 99708 shares; Executed: 13230, Remaining: 86478
# Order: 99708 shares; Executed: 39288, Remaining: 60420
# Order: 99708 shares; Executed: 99708, Remaining: 0
# Processing limit order: 92913 shares on side ask at price 347.39.
# Processing limit order: 99865 shares on side bid at price 346.78.
# Order: 99865 shares; Executed: 5566, Remaining: 94299
# Order: 99865 shares; Executed: 79502, Remaining: 20363
# Order: 99865 shares; Executed: 80930, Remaining: 18935
# Order: 99865 shares; Executed: 82260, Remaining: 17605
# Order: 99865 shares; Executed: 99865, Remaining: 0
# Processing limit order: 849 shares on side bid at price 344.25.
# Order: 849 shares; Executed: 849, Remaining: 0
# Processing limit order: 1091 shares on side ask at price 340.32.
# Order: 1091 shares; Executed: 1084, Remaining: 7
# Order: 1091 shares; Executed: 1091, Remaining: 0
# Processing limit order: 82837 shares on side ask at price 347.42.
# Processing limit order: 927 shares on side bid at price 344.77.
# Order: 927 shares; Executed: 927, Remaining: 0
# Processing limit order: 1116 shares on side bid at price 339.32.
# Processing limit order: 79345 shares on side bid at price 346.74.
# Order: 79345 shares; Executed: 55707, Remaining: 23638
# Order: 79345 shares; Executed: 79345, Remaining: 0
# Processing limit order: 104237 shares on side ask at price 347.46.
# Processing limit order: 917 shares on side bid at price 341.38.
# Processing limit order: 74372 shares on side bid at price 346.71.
# Order: 74372 shares; Executed: 47932, Remaining: 26440
# Order: 74372 shares; Executed: 68463, Remaining: 5909
# Order: 74372 shares; Executed: 74372, Remaining: 0
# Processing limit order: 85844 shares on side ask at price 347.49.
#
# [DEBUG] Initial Order Book Snapshot (Top 5 Levels):
#
# Order Book Snapshot:
# Asks:
# Price: 343.54, Quantity: 16804
# Price: 343.55, Quantity: 237257
# Price: 343.56, Quantity: 16428
# Price: 343.57, Quantity: 15821
# Price: 343.58, Quantity: 86842
# Bids:
# Price: 342.14, Quantity: 1080
# Price: 341.93, Quantity: 1045
# Price: 341.63, Quantity: 31874
# Price: 341.61, Quantity: 63735
# Price: 341.59, Quantity: 57909
# [DEBUG] Checking order book state...
# [DEBUG] Bids in the order book (Top 5 Levels):
# Price: 342.14, Total Quantity: 1080
# Price: 341.93, Total Quantity: 1045
# Price: 341.63, Total Quantity: 31874
# Price: 341.61, Total Quantity: 63735
# Price: 341.59, Total Quantity: 57909
# [DEBUG] Asks in the order book (Top 5 Levels):
# Price: 343.54, Total Quantity: 16804
# Price: 343.55, Total Quantity: 237257
# Price: 343.56, Total Quantity: 16428
# Price: 343.57, Total Quantity: 15821
# Price: 343.58, Total Quantity: 86842
# [DEBUG] Starting the VWAP and TWAP simulations...
#
# [DEBUG] VWAP function started to buy 100000 shares.
#
# Order Book Snapshot:
# Asks:
# Price: 343.54, Quantity: 16804
# Price: 343.55, Quantity: 237257
# Price: 343.56, Quantity: 16428
# Price: 343.57, Quantity: 15821
# Price: 343.58, Quantity: 86842
# Bids:
# Price: 342.14, Quantity: 1080
# Price: 341.93, Quantity: 1045
# Price: 341.63, Quantity: 31874
# Price: 341.61, Quantity: 63735
# Price: 341.59, Quantity: 57909
#
# [DEBUG] VWAP loop - remaining shares: 100000.
#
# [DEBUG] VWAP selecting target price: $343.57, liquidity: 15821
# VWAP: Buying 15821 shares at $343.57 per share. Liquidity: 15821.
# Processing market order: 4746 shares on side bid at target price 343.54.
# Matching order: Price 343.54, Qty 4746, Executed price: 344.39, Liquidity: 16804
# VWAP: Executed 4746 shares at avg price 344.39. Remaining shares: 95254.
# VWAP: Slippage: 0.0003, Market Impact: 0.0014
# VWAP Calculation: 344.39, based on 1 trades.
# VWAP value: 344.39
# Processing limit order: 530 shares on side ask at price 345.19.
#
# [DEBUG] VWAP loop - remaining shares: 95254.
#
# [DEBUG] VWAP selecting target price: $343.56, liquidity: 16428
# VWAP: Buying 16428 shares at $343.56 per share. Liquidity: 16428.
# Processing market order: 4928 shares on side bid at target price 343.54.
# Matching order: Price 343.54, Qty 4928, Executed price: 344.72, Liquidity: 12058
# VWAP: Executed 4928 shares at avg price 344.72. Remaining shares: 90326.
# VWAP: Slippage: 0.0001, Market Impact: 0.0010
# VWAP Calculation: 344.56, based on 2 trades.
# VWAP value: 344.56
# Processing limit order: 1941 shares on side ask at price 345.42.
#
# [DEBUG] VWAP loop - remaining shares: 90326.
#
# [DEBUG] VWAP selecting target price: $343.56, liquidity: 16428
# VWAP: Buying 16428 shares at $343.56 per share. Liquidity: 16428.
# Processing market order: 4928 shares on side bid at target price 343.54.
# Matching order: Price 343.54, Qty 4928, Executed price: 345.35, Liquidity: 7130
# VWAP: Executed 4928 shares at avg price 345.35. Remaining shares: 85398.
# VWAP: Slippage: 0.0005, Market Impact: 0.0033
# VWAP Calculation: 344.83, based on 3 trades.
# VWAP value: 344.83
# Processing limit order: 1535 shares on side ask at price 344.58.
#
# [DEBUG] VWAP loop - remaining shares: 85398.
#
# [DEBUG] VWAP selecting target price: $343.56, liquidity: 16428
# VWAP: Buying 16428 shares at $343.56 per share. Liquidity: 16428.
# Processing market order: 4928 shares on side bid at target price 343.54.
# Matching order: Price 343.54, Qty 2202, Executed price: 345.92, Liquidity: 2202
# Matching order: Price 343.55, Qty 2726, Executed price: 343.59, Liquidity: 237257
# VWAP: Executed 4928 shares at avg price 344.63. Remaining shares: 80470.
# VWAP: Slippage: 0.0001, Market Impact: 0.0010
# VWAP Calculation: 344.78, based on 5 trades.
# VWAP value: 344.78
# Processing limit order: 1737 shares on side ask at price 346.14.
#
# [DEBUG] VWAP loop - remaining shares: 80470.
#
# [DEBUG] VWAP selecting target price: $343.55, liquidity: 234531
# VWAP: Buying 80470 shares at $343.55 per share. Liquidity: 234531.
# Processing market order: 70359 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 44518, Executed price: 344.15, Liquidity: 234531
# Matching order: Price 343.55, Qty 25841, Executed price: 343.99, Liquidity: 190013
# VWAP: Executed 70359 shares at avg price 344.09. Remaining shares: 10111.
# VWAP: Slippage: 0.0002, Market Impact: 0.0010
# VWAP Calculation: 344.24, based on 7 trades.
# VWAP value: 344.24
# Processing limit order: 1984 shares on side bid at price 343.45.
#
# [DEBUG] VWAP loop - remaining shares: 10111.
#
# [DEBUG] VWAP selecting target price: $343.59, liquidity: 123844
# VWAP: Buying 10111 shares at $343.59 per share. Liquidity: 123844.
# Processing market order: 10111 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 10111, Executed price: 343.76, Liquidity: 164172
# VWAP: Executed 10111 shares at avg price 343.76. Remaining shares: 0.
# VWAP: Slippage: 0.0001, Market Impact: 0.0010
# VWAP Calculation: 344.19, based on 8 trades.
# VWAP value: 344.19
# Processing limit order: 1678 shares on side bid at price 342.99.
#
# [DEBUG] VWAP Execution Complete: Executed Volume = 100000, Avg Price = $344.19, Total Cost = $34419062.21, Remaining Shares = 0
#
# [DEBUG] TWAP function started to buy 100000 shares over 10 periods.
#
# Order Book Snapshot:
# Asks:
# Price: 343.55, Quantity: 154061
# Price: 343.56, Quantity: 16428
# Price: 343.57, Quantity: 15821
# Price: 343.58, Quantity: 86842
# Price: 343.59, Quantity: 123844
# Bids:
# Price: 343.45, Quantity: 1984
# Price: 342.99, Quantity: 1678
# Price: 342.14, Quantity: 1080
# Price: 341.93, Quantity: 1045
# Price: 341.63, Quantity: 31874
# TWAP: Period 1/10: Buying 30000 shares at $343.59 per share.
# Processing market order: 30000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 30000, Executed price: 344.16, Liquidity: 154061
# TWAP: Executed 30000 shares at avg price 344.16. Remaining shares: 70000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 344.16, based on 1 trades.
# TWAP value: 344.16
# Processing limit order: 571 shares on side ask at price 343.58.
# TWAP: Period 2/10: Buying 15000 shares at $343.59 per share.
# Processing market order: 15000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 8376, Executed price: 343.77, Liquidity: 124061
# Matching order: Price 343.55, Qty 6624, Executed price: 343.74, Liquidity: 115685
# TWAP: Executed 15000 shares at avg price 343.76. Remaining shares: 55000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.82, based on 3 trades.
# TWAP value: 343.82
# Processing limit order: 1443 shares on side bid at price 340.16.
# Processing limit order: 1466 shares on side bid at price 341.65.
# TWAP: Period 3/10: Buying 10000 shares at $343.56 per share.
# Processing market order: 10000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 10000, Executed price: 343.85, Liquidity: 109061
# TWAP: Executed 10000 shares at avg price 343.85. Remaining shares: 45000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.83, based on 4 trades.
# TWAP value: 343.83
# Processing limit order: 1572 shares on side bid at price 346.53.
# Order: 1572 shares; Executed: 1572, Remaining: 0
# TWAP: Period 4/10: Buying 5000 shares at $343.55 per share.
# Processing market order: 5000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 5000, Executed price: 343.72, Liquidity: 97489
# TWAP: Executed 5000 shares at avg price 343.72. Remaining shares: 40000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.65, based on 6 trades.
# TWAP value: 343.65
# Processing limit order: 1212 shares on side ask at price 342.24.
# Order: 1212 shares; Executed: 1212, Remaining: 0
# Processing limit order: 1204 shares on side ask at price 341.84.
# Order: 1204 shares; Executed: 772, Remaining: 432
# Order: 1204 shares; Executed: 1204, Remaining: 0
# Processing limit order: 1440 shares on side ask at price 346.09.
# TWAP: Period 5/10: Buying 5000 shares at $343.58 per share.
# Processing market order: 5000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 3601, Executed price: 343.68, Liquidity: 92489
# Matching order: Price 343.55, Qty 1399, Executed price: 343.6, Liquidity: 88888
# TWAP: Executed 5000 shares at avg price 343.66. Remaining shares: 35000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.64, based on 11 trades.
# TWAP value: 343.64
# Processing limit order: 1846 shares on side bid at price 342.45.
# TWAP: Period 6/10: Buying 5000 shares at $343.56 per share.
# Processing market order: 5000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 5000, Executed price: 343.74, Liquidity: 87489
# TWAP: Executed 5000 shares at avg price 343.74. Remaining shares: 30000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.65, based on 12 trades.
# TWAP value: 343.65
# Processing limit order: 1498 shares on side ask at price 346.22.
# TWAP: Period 7/10: Buying 10000 shares at $343.58 per share.
# Processing market order: 10000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 10000, Executed price: 343.94, Liquidity: 82489
# TWAP: Executed 10000 shares at avg price 343.94. Remaining shares: 20000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.69, based on 13 trades.
# TWAP value: 343.69
# Processing limit order: 1837 shares on side ask at price 341.4.
# Order: 1837 shares; Executed: 1246, Remaining: 591
# Order: 1837 shares; Executed: 1837, Remaining: 0
# TWAP: Period 8/10: Buying 10000 shares at $343.56 per share.
# Processing market order: 10000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 83, Executed price: 343.55, Liquidity: 72489
# Matching order: Price 343.55, Qty 9917, Executed price: 343.99, Liquidity: 72406
# TWAP: Executed 10000 shares at avg price 343.99. Remaining shares: 10000.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.59, based on 17 trades.
# TWAP value: 343.59
# Processing limit order: 666 shares on side ask at price 341.22.
# Order: 666 shares; Executed: 666, Remaining: 0
# TWAP: Period 9/10: Buying 10000 shares at $343.55 per share.
# Processing market order: 10000 shares on side bid at target price 343.55.
# Matching order: Price 343.55, Qty 10000, Executed price: 344.06, Liquidity: 62489
# TWAP: Executed 10000 shares at avg price 344.06. Remaining shares: 0.
# TWAP: Slippage: 0.0001, Market Impact: 0.0010
# TWAP Calculation: 343.56, based on 19 trades.
# TWAP value: 343.56
# Processing limit order: 710 shares on side ask at price 345.76.
# Processing limit order: 1395 shares on side ask at price 342.39.
# Order: 1395 shares; Executed: 589, Remaining: 806
# Processing limit order: 737 shares on side bid at price 339.47.
# Processing limit order: 1205 shares on side ask at price 345.31.
# Processing limit order: 1009 shares on side ask at price 346.5.
#
# [DEBUG] TWAP halted: No remaining shares to buy.
#
# [DEBUG] TWAP Execution Complete: Executed Volume = 100000, Avg Price = $343.95, Total Cost = $34395200.00, Remaining Shares = 0
#
# === Execution Results Comparison ===
#
# Metric                    VWAP            TWAP
# =======================================================
# Executed Volume (shares)  100000          100000
# Average Price ($)         344.19          343.95
# Total Cost ($)            34419062.21     34395200.0
# Transaction Cost ($)      41302.87        41274.24
# Slippage (avg %)          0.0002          0.0001
# Market Impact (avg %)     0.0015          0.0010
#
# =======================================================
#
#
# Simulation Results:
# VWAP Results: {'prices': [344.39, 344.72, 345.35, 344.63, 344.09, 343.76], 'volumes': [4746, 4928, 4928, 4928, 70359, 10111], 'slippage': [0.00025010820785302345, 0.0001, 0.0005450930415776198, 0.0001, 0.00016447753261068673, 0.0001], 'market_impact': [0.0013937624485621206, 0.001, 0.003313042903346344, 0.001, 0.001, 0.001], 'total_cost': 34419062.21, 'avg_price': 344.19, 'transaction_cost_total': 41302.87, 'volume': 100000}
# TWAP Results: {'prices': [344.16, 343.76, 343.85, 343.72, 343.66, 343.74, 343.94, 343.99, 344.06], 'volumes': [30000, 15000, 10000, 5000, 5000, 5000, 10000, 10000, 10000], 'slippage': [0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001310052572563718], 'market_impact': [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001], 'total_cost': 34395200.0, 'avg_price': 343.95, 'transaction_cost_total': 41274.24, 'volume': 100000}

# %%
'''# Function to run a single VWAP simulation with detailed logging for 100,000 shares
def _run_single_vwap_simulation(lob, total_shares):
    print(f"\n[DEBUG] Running VWAP simulation for {total_shares} shares", flush=True)

    # Debug print before VWAP function is called
    print("[DEBUG] Preparing to call VWAP function...", flush=True)

    try:
        # VWAP execution with detailed logging
        print("[DEBUG] Calling VWAP function now...", flush=True)
        vwap_volume, vwap_price, vwap_transaction_cost, vwap_slippage, vwap_market_impact = execute_vwap_order_with_shares(lob, total_shares)
        print(f"[DEBUG] VWAP completed. Executed volume: {vwap_volume} shares, Avg price: ${vwap_price:.2f}, Transaction cost: ${vwap_transaction_cost:.2f}", flush=True)
    except Exception as e:
        print(f"[DEBUG] Error during VWAP execution: {e}", flush=True)

    return {
        'VWAP': {
            'volume': vwap_volume,
            'avg_price': vwap_price,
            'slippage': vwap_slippage,
            'market_impact': vwap_market_impact,
            'transaction_cost': vwap_transaction_cost
        }
    }

# Updated VWAP function to buy a fixed number of shares (100,000) instead of a budget
def execute_vwap_order_with_shares(lob, total_shares):
    print(f"\n[DEBUG] VWAP function started to buy {total_shares} shares.", flush=True)

    if not lob.asks:
        print(f"[DEBUG] VWAP Exiting Early: No liquidity on the ask side.", flush=True)
        return 0, 0, 0, 0, 0

    executed_volume, total_cost = 0, 0
    transaction_cost_total = 0
    remaining_shares = total_shares
    lob.trades.clear()

    # Debugging before entering the loop
    print(f"[DEBUG] VWAP loop is starting with remaining shares to buy: {remaining_shares}.", flush=True)

    loop_counter = 0  # Add a counter for the VWAP loop
    while remaining_shares > 0:
        loop_counter += 1
        print(f"[DEBUG] VWAP Loop Iteration: {loop_counter}, Remaining Shares: {remaining_shares}", flush=True)

        price_range = sorted([p for p in lob.asks.keys() if p > 0])[:5]

        if not price_range:  # Halt if no valid prices remain
            print(f"[DEBUG] VWAP halted: No valid prices in the order book.", flush=True)
            break

        target_price = np.random.choice(price_range)
        liquidity = sum(order.quantity for order in lob.asks[target_price])

        # Debugging target price and liquidity
        print(f"[DEBUG] Target price: ${target_price:.2f}, Liquidity: {liquidity}, Remaining Shares: {remaining_shares}", flush=True)

        current_order_qty = min(remaining_shares, liquidity)

        if current_order_qty <= 0:
            print(f"[DEBUG] VWAP halted: Insufficient liquidity to buy at price {target_price}.", flush=True)
            break

        print(f"VWAP: Buying {current_order_qty} shares at ${target_price:.2f} per share. Liquidity: {liquidity}.", flush=True)

        market_order = {
            'type': 'market',
            'side': 'bid',
            'instrument': 'MSFT',
            'qty': current_order_qty,
            'tid': -1
        }

        # Process the market order
        exec_vol, avg_price, slippage_percentage, market_impact = lob._process_market_order(market_order)
        total_cost += exec_vol * avg_price
        executed_volume += exec_vol
        remaining_shares -= exec_vol
        transaction_cost = exec_vol * avg_price * lob.transaction_cost
        transaction_cost_total += transaction_cost

        print(f"[DEBUG] VWAP: Executed {exec_vol} shares at avg price ${avg_price:.2f}. Remaining shares: {remaining_shares}.", flush=True)

        vwap_value = lob.calculate_vwap(lob.trades)
        print(f"[DEBUG] VWAP value: {vwap_value}", flush=True)

        lob._generate_external_order()  # Simulate market dynamics
        time.sleep(0.3)

    avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
    transaction_cost_total = round(transaction_cost_total, 2)

    # Final debug output
    print(f"\n[DEBUG] VWAP Execution Complete: Executed Volume = {executed_volume}, Avg Price = ${avg_price:.2f}, Total Cost = ${total_cost:.2f}, Remaining Shares = {remaining_shares}", flush=True)

    return executed_volume, avg_price, transaction_cost_total, slippage_percentage, market_impact

# Additional debug function to check if order book is properly populated
def check_order_book_state(lob):
    print("[DEBUG] Checking order book state...", flush=True)

    print("[DEBUG] Bids in the order book (Top 5 Levels):", flush=True)
    for price, orders in list(lob.bids.items())[:5]:  # Print the top 5 levels of bids
        total_qty = sum(order.quantity for order in orders)
        print(f"Price: {price:.2f}, Total Quantity: {total_qty}", flush=True)

    print("[DEBUG] Asks in the order book (Top 5 Levels):", flush=True)
    for price, orders in list(lob.asks.items())[:5]:  # Print the top 5 levels of asks
        total_qty = sum(order.quantity for order in orders)
        print(f"Price: {price:.2f}, Total Quantity: {total_qty}", flush=True)

# Disable continuous order flow
def disable_continuous_order_flow():
    print("[DEBUG] Temporarily disabling continuous order flow to focus on VWAP simulation.", flush=True)

# Define and run the VWAP simulation for 100,000 shares
print("[DEBUG] Initializing OrderBook...", flush=True)

try:
    # Initialize the OrderBook instance
    lob = OrderBook(transaction_cost=0.001)
    print("[DEBUG] OrderBook successfully initialized.", flush=True)
except Exception as e:
    print(f"[DEBUG] Error during OrderBook initialization: {e}", flush=True)

try:
    # Initial population of the order book
    print("[DEBUG] Populating the order book...", flush=True)
    populate_order_book(lob)
    print("[DEBUG] Order book population complete.", flush=True)
except Exception as e:
    print(f"[DEBUG] Error populating order book: {e}", flush=True)

# Check the state of the order book before running VWAP
check_order_book_state(lob)

# Disable any other order processing while VWAP is running
disable_continuous_order_flow()

# Execute the VWAP simulation with 100,000 shares and log progress
try:
    # Debug print before simulation is executed
    print("[DEBUG] Starting VWAP simulation now...", flush=True)
    simulation_results = _run_single_vwap_simulation(lob, total_shares=100000)
    print(f"\n[DEBUG] Simulation Results: {simulation_results}", flush=True)
except Exception as e:
    print(f"[DEBUG] Error running VWAP simulation: {e}", flush=True)'''
# Out:
# '# Function to run a single VWAP simulation with detailed logging for 100,000 shares\ndef _run_single_vwap_simulation(lob, total_shares):\n    print(f"\n[DEBUG] Running VWAP simulation for {total_shares} shares", flush=True)\n\n    # Debug print before VWAP function is called\n    print("[DEBUG] Preparing to call VWAP function...", flush=True)\n\n    try:\n        # VWAP execution with detailed logging\n        print("[DEBUG] Calling VWAP function now...", flush=True)\n        vwap_volume, vwap_price, vwap_transaction_cost, vwap_slippage, vwap_market_impact = execute_vwap_order_with_shares(lob, total_shares)\n        print(f"[DEBUG] VWAP completed. Executed volume: {vwap_volume} shares, Avg price: ${vwap_price:.2f}, Transaction cost: ${vwap_transaction_cost:.2f}", flush=True)\n    except Exception as e:\n        print(f"[DEBUG] Error during VWAP execution: {e}", flush=True)\n\n    return {\n        \'VWAP\': {\n            \'volume\': vwap_volume,\n            \'avg_price\': vwap_price,\n            \'slippage\': vwap_slippage,\n            \'market_impact\': vwap_market_impact,\n            \'transaction_cost\': vwap_transaction_cost\n        }\n    }\n\n# Updated VWAP function to buy a fixed number of shares (100,000) instead of a budget\ndef execute_vwap_order_with_shares(lob, total_shares):\n    print(f"\n[DEBUG] VWAP function started to buy {total_shares} shares.", flush=True)\n\n    if not lob.asks:\n        print(f"[DEBUG] VWAP Exiting Early: No liquidity on the ask side.", flush=True)\n        return 0, 0, 0, 0, 0\n\n    executed_volume, total_cost = 0, 0\n    transaction_cost_total = 0\n    remaining_shares = total_shares\n    lob.trades.clear()\n\n    # Debugging before entering the loop\n    print(f"[DEBUG] VWAP loop is starting with remaining shares to buy: {remaining_shares}.", flush=True)\n\n    loop_counter = 0  # Add a counter for the VWAP loop\n    while remaining_shares > 0:\n        loop_counter += 1\n        print(f"[DEBUG] VWAP Loop Iteration: {loop_counter}, Remaining Shares: {remaining_shares}", flush=True)\n\n        price_range = sorted([p for p in lob.asks.keys() if p > 0])[:5]\n\n        if not price_range:  # Halt if no valid prices remain\n            print(f"[DEBUG] VWAP halted: No valid prices in the order book.", flush=True)\n            break\n\n        target_price = np.random.choice(price_range)\n        liquidity = sum(order.quantity for order in lob.asks[target_price])\n\n        # Debugging target price and liquidity\n        print(f"[DEBUG] Target price: ${target_price:.2f}, Liquidity: {liquidity}, Remaining Shares: {remaining_shares}", flush=True)\n\n        current_order_qty = min(remaining_shares, liquidity)\n\n        if current_order_qty <= 0:\n            print(f"[DEBUG] VWAP halted: Insufficient liquidity to buy at price {target_price}.", flush=True)\n            break\n\n        print(f"VWAP: Buying {current_order_qty} shares at ${target_price:.2f} per share. Liquidity: {liquidity}.", flush=True)\n\n        market_order = {\n            \'type\': \'market\',\n            \'side\': \'bid\',\n            \'instrument\': \'MSFT\',\n            \'qty\': current_order_qty,\n            \'tid\': -1\n        }\n\n        # Process the market order\n        exec_vol, avg_price, slippage_percentage, market_impact = lob._process_market_order(market_order)\n        total_cost += exec_vol * avg_price\n        executed_volume += exec_vol\n        remaining_shares -= exec_vol\n        transaction_cost = exec_vol * avg_price * lob.transaction_cost\n        transaction_cost_total += transaction_cost\n\n        print(f"[DEBUG] VWAP: Executed {exec_vol} shares at avg price ${avg_price:.2f}. Remaining shares: {remaining_shares}.", flush=True)\n\n        vwap_value = lob.calculate_vwap(lob.trades)\n        print(f"[DEBUG] VWAP value: {vwap_value}", flush=True)\n\n        lob._generate_external_order()  # Simulate market dynamics\n        time.sleep(0.3)\n\n    avg_price = round(total_cost / executed_ ...
