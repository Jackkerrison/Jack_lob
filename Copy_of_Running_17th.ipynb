# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackkerrison/Jack_lob/blob/main/Copy_of_Running_17th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Section 1: Environment Setup and Imports
# Install necessary packages
# %pip install arch --upgrade
# %pip install pathos
# !pip install bintrees
# %pip install yfinance
# %pip install sortedcontainers

# Import necessary modules
import sys
import logging
import psutil
from pathos.multiprocessing import ProcessingPool as Pool
import numpy as np
import pandas as pd
from collections import deque
import time
from sortedcontainers import SortedDict
import random
from arch import arch_model
from io import StringIO
import threading
import tracemalloc
import gc
import yfinance as yf
import matplotlib.pyplot as plt
from sortedcontainers import SortedDict
import seaborn as sns

# Adjust the CPU monitoring logic
MAX_CPU_PERCENT = 95  # Allow higher CPU usage before pausing
MAX_MEMORY_PERCENT = 90  # Allow higher memory usage
CHECK_INTERVAL = 5  # Check every 5 seconds

def monitor_resources():
    while True:
        cpu_percent = psutil.cpu_percent(interval=1)
        memory_percent = psutil.virtual_memory().percent

        if cpu_percent > MAX_CPU_PERCENT:
            logging.warning(f"High CPU usage: {cpu_percent}%. Pausing execution.")
            time.sleep(1)  # Shorter pause

        if memory_percent > MAX_MEMORY_PERCENT:
            logging.warning(f"High Memory usage: {memory_percent}%. Collecting garbage.")
            gc.collect()
            time.sleep(1)  # Shorter pause

        time.sleep(CHECK_INTERVAL)

# Start monitoring system resources in a separate thread
monitor_thread = threading.Thread(target=monitor_resources, daemon=True)
monitor_thread.start()
# Out:
# Requirement already satisfied: arch in /usr/local/lib/python3.10/dist-packages (7.0.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from arch) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from arch) (1.13.1)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from arch) (2.1.4)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.12->arch) (1.16.0)
# Requirement already satisfied: pathos in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: ppft>=1.7.6.8 in /usr/local/lib/python3.10/dist-packages (from pathos) (1.7.6.8)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.10/dist-packages (from pathos) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from pathos) (0.3.4)
# Requirement already satisfied: multiprocess>=0.70.16 in /usr/local/lib/python3.10/dist-packages (from pathos) (0.70.16)
# Collecting bintrees
#   Using cached bintrees-2.2.0.zip (108 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bintrees
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for bintrees (setup.py) ... error
#   ERROR: Failed building wheel for bintrees
#   Running setup.py clean for bintrees
# Failed to build bintrees
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (bintrees)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.43)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.8.30)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (2.4.0)

# %%
# Data Fetching and Preparation
try:
    # Fetch MSFT data for the specified date range
    msft_data = yf.download('MSFT', start='2023-05-01', end='2023-07-01', interval='60m', progress=False)
    initial_rows = msft_data.shape[0]

    # Handle missing data for 'Adj Close' and 'Volume'
    if msft_data.isnull().sum().sum() > 0:
        msft_data['Adj Close'] = msft_data['Adj Close'].fillna(method='ffill').fillna(method='bfill')
        msft_data['Volume'] = msft_data['Volume'].fillna(msft_data['Volume'].rolling(window=5, min_periods=1).mean())

    dropped_rows = initial_rows - msft_data.shape[0]
    print(f"Dropped {dropped_rows} rows due to missing data. ({(dropped_rows / initial_rows) * 100:.2f}% of the data)")
    print("Preview of the fetched data:")
    print(msft_data.head())

except Exception as e:
    print(f"Error fetching data: {e}")

# Rolling window for volatility calculation
rolling_window = 10
initial_volatility = msft_data['Adj Close'].rolling(window=rolling_window).std().dropna()

# Calculate Returns and GARCH Model Fitting
try:
    returns = msft_data['Adj Close'].pct_change().dropna()
    egarch_fitted = arch_model(returns * 100, vol='EGarch', p=1, q=1, o=1, dist='t').fit(disp='off')
    volatility = (egarch_fitted.conditional_volatility / 100).round(2)

    # Smooth transition of volatility
    if not initial_volatility.empty:
        volatility.iloc[:len(initial_volatility)] = initial_volatility.values
    # Plot the conditional volatility
    volatility.plot(title='Conditional Volatility from EGARCH Model', figsize=(10, 6))
    plt.show()

except Exception as e:
    print(f"Error in GARCH model fitting: {e}")

# Adjusted liquidity calculation
def time_weighted_liquidity(volume, timestamp):
    typical_liquidity_factor = np.random.uniform(0.6, 1.4)  # Tighten the bounds for normal liquidity
    if timestamp.hour < 10:
        return volume * typical_liquidity_factor * np.random.uniform(1.2, 1.6)  # Stronger early morning liquidity
    elif timestamp.hour >= 15:
        return volume * typical_liquidity_factor * np.random.uniform(1.4, 1.8)  # Higher liquidity at close
    else:
        return volume * typical_liquidity_factor * np.random.uniform(0.5, 0.8)  # Lower liquidity midday

# Adjust dynamic liquidity function to make liquidity decay more sensitive to large trades.
def dynamic_liquidity(volume, executed_order_size, base_liquidity, volatility=0.02):
    # Increase the liquidity adjustment to reflect higher liquidity for MSFT
    liquidity_adjustment = np.random.uniform(0.7, 1.2)  # Higher liquidity range
    volatility_impact = volatility * np.random.uniform(1.5, 2.0)  # Volatility impact remains but reduced

    remaining_liquidity = round(max(base_liquidity - (executed_order_size * liquidity_adjustment * volatility_impact), 0), 2)

    return max(remaining_liquidity, volume * 0.05)  # Increase the minimum liquidity threshold

# Align Data
aligned_data = pd.concat([msft_data['Adj Close'], msft_data['Volume'], volatility, msft_data['High'], msft_data['Low']], axis=1).ffill().bfill()
aligned_data.columns = ['Adj Close', 'Volume', 'Volatility', 'High', 'Low']

# Remove redundant volume adjustment logic and keep only the necessary part:
volume_multiplier = np.random.uniform(0.7, 1.3, len(aligned_data))  # More realistic range for liquidity adjustments
aligned_data['Adjusted_Volume'] = (aligned_data['Volume'] / aligned_data['Volume'].max()) * hourly_volume * volume_multiplier

# Initial Liquidity Calculation
aligned_data['Liquidity'] = aligned_data.apply(lambda row: time_weighted_liquidity(row['Adjusted_Volume'], row.name), axis=1)

# Apply dynamic liquidity adjustment in a simplified manner
aligned_data['Liquidity'] = aligned_data.apply(lambda row: dynamic_liquidity(row['Adjusted_Volume'], 100000, row['Liquidity']), axis=1)

# Ensure Liquidity is rounded to 2 decimal places for better readability
aligned_data['Liquidity'] = aligned_data['Liquidity'].round(2)

# Print volume and liquidity for verification
print("Sample Adjusted Volumes and Liquidity:")
print(aligned_data[['Adjusted_Volume', 'Liquidity']].head())

# More realistic transaction cost calculation based on liquidity, spread, and volatility
def calculate_transaction_cost(executed_volume, avg_price, liquidity, spread, volatility, base_cost=0.0015):
    spread_impact = round(spread / avg_price, 4)
    volatility_impact = round(volatility / avg_price, 4)

    transaction_cost_multiplier = round(1 + spread_impact * np.random.uniform(1.1, 1.3) + volatility_impact * np.random.uniform(1.5, 2.5), 4)
    transaction_cost = round(executed_volume * avg_price * (base_cost * transaction_cost_multiplier), 2)

    return transaction_cost

# Method to calculate volatility based on the recent trades
def calculate_volatility(self, window=10):
    prices = np.array([trade['price'] for trade in self.trades[-window:]])  # Last N trades
    if len(prices) < 2:
        return 0  # Not enough data to calculate volatility
    returns = np.diff(prices) / prices[:-1]
    return np.std(returns) * np.sqrt(len(returns))  # Annualized volatility

# Increase spread dynamically based on market conditions and liquidity
def dynamic_spread(adj_close, volatility, liquidity, base_spread_factor=0.0004, volatility_multiplier=0.7):
    # Increase the spread factor during low liquidity and high volatility
    base_spread = adj_close * base_spread_factor * (1 + volatility * volatility_multiplier)
    liquidity_adjustment = 1 + np.random.uniform(0.06, 0.15)  # Larger adjustment for more variability
    spread = base_spread * liquidity_adjustment
    return np.clip(spread, adj_close * 0.0003, adj_close * 0.002).round(4)  # Adjust the spread range

# Apply the updated spread calculation
aligned_data['Spread'] = aligned_data.apply(
    lambda row: dynamic_spread(row['Adj Close'], row['Volatility'], row['Liquidity']), axis=1)

# Modify the market response function to include a more dynamic market impact factor.
def market_response(price, order_size, daily_volume, liquidity, volatility, market_conditions='stable'):
    market_impact_factor = np.random.uniform(0.05, 0.15) if market_conditions == 'volatile' else np.random.uniform(0.05, 0.1)
    impact = price * (1 + market_impact_factor * ((order_size / liquidity) ** 1.5))  # More sensitive based on order size
    return np.clip(impact, price * 0.97, price * 1.03).round(2)  # Limit to a realistic range

# Use this function in VWAP and TWAP executions
aligned_data['Mid_Price'] = aligned_data.apply(lambda row: market_response(row['Adj Close'], row['Volume'], 20000000, row['Liquidity'], row['Volatility'], 'stable'), axis=1)

# VWAP Calculation
def calculate_vwap(prices, volumes):
    cumulative_price_volume = np.cumsum(prices * volumes)
    cumulative_volume = np.cumsum(volumes)
    vwap = cumulative_price_volume / cumulative_volume
    return vwap.round(2)

aligned_data['VWAP'] = calculate_vwap(aligned_data['Adj Close'], aligned_data['Volume'])

# Calculate Typical Price and TWAP
aligned_data['Typical Price'] = ((aligned_data['Adj Close'] + aligned_data['High'] + aligned_data['Low']) / 3).round(2)

# Refined TWAP Calculation using exponentially weighted moving average (EWMA)
def calculate_twap(prices, alpha=0.05):
    # Further reduce alpha for a smoother TWAP
    return prices.ewm(alpha=alpha, adjust=False).mean().round(2)

aligned_data['TWAP'] = calculate_twap(aligned_data['Typical Price'])

# Distribute bid/ask liquidity across levels with realistic differences
def distribute_liquidity_across_levels(mid_price, liquidity, num_levels):
    level_multipliers = np.exp(-np.arange(num_levels) / 2)
    total_liquidity = liquidity * level_multipliers / level_multipliers.sum()
    return total_liquidity

# Adjust bid/ask prices using increasing spread for each level, with dynamic adjustment for available levels
def generate_bid_ask_prices(aligned_data, num_levels=10):
    # Ensure num_levels does not exceed the number of available data points
    actual_num_levels = min(num_levels, len(aligned_data))  # Ensure levels do not exceed available data points

    # Initialize bid and ask prices arrays with NaN values
    bid_prices = np.full((len(aligned_data), actual_num_levels), np.nan)
    ask_prices = np.full((len(aligned_data), actual_num_levels), np.nan)

    for i in range(actual_num_levels):  # Generate bid/ask prices for each level
        spread_multiplier = 1 + i * 0.5  # Adjust spread by increasing the multiplier
        liquidity_impact = aligned_data['Liquidity'].values / aligned_data['Liquidity'].mean()

        # Generate bid and ask prices by adjusting Mid_Price with spread and liquidity impact
        bid_prices[:, i] = aligned_data['Mid_Price'].values - (aligned_data['Spread'].values * spread_multiplier * liquidity_impact)
        ask_prices[:, i] = aligned_data['Mid_Price'].values + (aligned_data['Spread'].values * spread_multiplier * liquidity_impact)

    # Create DataFrames for bid and ask prices with column names for each level
    bid_prices_df = pd.DataFrame(bid_prices, index=aligned_data.index, columns=[f'Bid_Price_{i+1}' for i in range(num_levels)])
    ask_prices_df = pd.DataFrame(ask_prices, index=aligned_data.index, columns=[f'Ask_Price_{i+1}' for i in range(num_levels)])

    return bid_prices_df, ask_prices_df

# Generate bid and ask prices
df_bid_prices, df_ask_prices = generate_bid_ask_prices(aligned_data, num_levels=10)

# Ensure that bid/ask prices are not empty and aligned_data contains valid data before concatenating
if not df_bid_prices.empty and not df_ask_prices.empty:
    aligned_data = pd.concat([aligned_data, df_bid_prices, df_ask_prices], axis=1)
else:
    print("[DEBUG] Bid or Ask prices DataFrames are empty. Check the data generation logic.")

# Print bid and ask prices for verification
print("Sample Bid Prices at different levels:")
print(df_bid_prices.head())

print("Sample Ask Prices at different levels:")
print(df_ask_prices.head())

# Display order book summary with adjusted format
pd.options.display.float_format = '{:.2f}'.format
print("Order book summary:\n", aligned_data.describe().transpose())
# Out:
# Dropped 0 rows due to missing data. (0.00% of the data)
# Preview of the fetched data:
#                       Open   High    Low  Close  Adj Close   Volume
# Datetime
# 2023-05-01 09:30:00 306.97 308.60 306.17 306.32     306.32  4971460
# 2023-05-01 10:30:00 306.30 307.55 305.77 306.30     306.30  3529718
# 2023-05-01 11:30:00 306.33 307.46 306.10 307.10     307.10  1811533
# 2023-05-01 12:30:00 307.10 308.05 307.10 307.58     307.58  1998664
# 2023-05-01 13:30:00 307.62 307.98 306.40 306.55     306.55  1522938
# /usr/local/lib/python3.10/dist-packages/arch/univariate/base.py:766: ConvergenceWarning: The optimizer returned code 4. The message is:
# Inequality constraints incompatible
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   warnings.warn(
# Sample Adjusted Volumes and Liquidity:
#                      Adjusted_Volume  Liquidity
# Datetime
# 2023-05-01 09:30:00        850827.03 1285024.45
# 2023-05-01 10:30:00        674440.65  255819.52
# 2023-05-01 11:30:00        370089.16  239103.38
# 2023-05-01 12:30:00        243024.62  122811.19
# 2023-05-01 13:30:00        259273.36  133815.92
# Sample Bid Prices at different levels:
#                      Bid_Price_1  Bid_Price_2  Bid_Price_3  Bid_Price_4  \
# Datetime
# 2023-05-01 09:30:00       314.90       314.60       314.30       314.00
# 2023-05-01 10:30:00       315.38       315.32       315.27       315.21
# 2023-05-01 11:30:00       316.21       316.15       316.10       316.05
# 2023-05-01 12:30:00       316.76       316.73       316.70       316.68
# 2023-05-01 13:30:00       315.69       315.66       315.63       315.60
#
#                      Bid_Price_5  Bid_Price_6  Bid_Price_7  Bid_Price_8  \
# Datetime
# 2023-05-01 09:30:00       313.70       313.40       313.10       312.81
# 2023-05-01 10:30:00       315.15       315.10       315.04       314.98
# 2023-05-01 11:30:00       316.00       315.94       315.89       315.84
# 2023-05-01 12:30:00       316.65       316.62       316.59       316.57
# 2023-05-01 13:30:00       315.57       315.54       315.51       315.49
#
#                      Bid_Price_9  Bid_Price_10
# Datetime
# 2023-05-01 09:30:00       312.51        312.21
# 2023-05-01 10:30:00       314.93        314.87
# 2023-05-01 11:30:00       315.79        315.73
# 2023-05-01 12:30:00       316.54        316.51
# 2023-05-01 13:30:00       315.46        315.43
# Sample Ask Prices at different levels:
#                      Ask_Price_1  Ask_Price_2  Ask_Price_3  Ask_Price_4  \
# Datetime
# 2023-05-01 09:30:00       316.10       316.40       316.70       317.00
# 2023-05-01 10:30:00       315.60       315.66       315.71       315.77
# 2023-05-01 11:30:00       316.41       316.47       316.52       316.57
# 2023-05-01 12:30:00       316.86       316.89       316.92       316.94
# 2023-05-01 13:30:00       315.81       315.84       315.87       315.90
#
#                      Ask_Price_5  Ask_Price_6  Ask_Price_7  Ask_Price_8  \
# Datetime
# 2023-05-01 09:30:00       317.30       317.60       317.90       318.19
# 2023-05-01 10:30:00       315.83       315.88       315.94       316.00
# 2023-05-01 11:30:00       316.62       316.68       316.73       316.78
# 2023-05-01 12:30:00       316.97       317.00       317.03       317.05
# 2023-05-01 13:30:00       315.93       315.96       315.99       316.01
#
#                      Ask_Price_9  Ask_Price_10
# Datetime
# 2023-05-01 09:30:00       318.49        318.79
# 2023-05-01 10:30:00       316.05        316.11
# 2023-05-01 11:30:00       316.83        316.89
# 2023-05-01 12:30:00       317.08        317.11
# 2023-05-01 13:30:00       316.04        316.07
# Order book summary:
#                   count       mean        std        min        25%        50%  \
# Adj Close       301.00     324.28      12.37     303.75     311.50     326.81
# Volume          301.00 3019221.65 1778438.89 1140403.00 1961121.00 2518807.00
# Volatility      301.00       1.85       1.09       0.08       1.16       1.58
# High            301.00     325.24      12.47     305.17     312.13     328.15
# Low             301.00     323.27      12.22     303.40     310.66     325.60
# Adjusted_Volume 301.00  506925.72  351121.93  155863.70  312630.04  405947.06
# Liquidity       301.00  481090.71  523970.06   69157.75  188639.98  285928.51
# Spread          301.00       0.33       0.11       0.16       0.25       0.30
# Mid_Price       301.00     334.01      12.74     312.86     320.85     336.61
# VWAP            301.00     314.79       6.55     305.72     307.90     315.27
# Typical Price   301.00     324.26      12.34     304.55     311.47     326.97
# TWAP            301.00     322.40      11.72     306.23     308.86     326.31
# Bid_Price_1     301.00     333.67      12.67     312.43     320.55     336.17
# Bid_Price_2     301.00     333.50      12.65     312.21     320.27     336.08
# Bid_Price_3     301.00     333.33      12.63     311.79     320.00     335.82
# Bid_Price_4     301.00     333.16      12.61     311.38     319.72     335.64
# Bid_Price_5     301.00     332.99      12.60     310.96     319.63     335.45
# Bid_Price_6     301.00     332.82      12.60     310.55     319.42     335.10
# Bid_Price_7     301.00     332.65      12.60     310.13     319.26     334.86
# Bid_Price_8     301.00     332.48      12.61     309.72     319.07     334.77
# Bid_Price_9     301.00     332.31      12.62     309.29     318.98     334.47
# Bid_Price_10    301.00     332.14      12.63     308.40     318.89     334.31
# Ask_Price_1     301.00     334.35      12.82     313.29     321.04     337.24
# Ask_Price_2     301.00     334.52      12.87     313.50     321.18     337.59
# Ask_Price_3     301.00     334.69      12.92     313.71     321.39     337.68
# Ask_Price_4     301.00     334.86      12.98     313.93     321.59     338.05
# Ask_Price_5     301.00     335.03      13.04     314.14     321.79     338.24
# Ask_Price_6     301.00     335.20      13.11     314.25     322.00     338.37
# Ask_Price_7     301.00     335.37      13.18     314.32     322.21     338.44
# Ask_Price_8     301.00     335.54      13.26     314.38     322.41     338.49
# Ask_Price_9     301.00     335.71      13.34     314.45     322.62     338.54
# Ask_Price_10    301.00     335.88      13.42     314.51     322.71     338.59
#
#                        75%         max
# Adj Close           334.53      348.73
# Volume          3320773.00 16931400.00
# Volatility            2.18        5.88
# High                335.78      351.47
# Low                 333.45      347.40
# Adjusted_Volume  567167.76  3700396.21
# Liquidity        547651.83  5165647.02
# Spread                0.37        0.67
# Mid_Price           344.57      359.19
# VWAP                320.58      324.74
# Typical Price       334.60      348.46
# TWAP                333.02      338.97
# Bid_Price_1         344.23      358.83
# Bid_Price_2         344.13      358.65
# Bid_Price_3         343.85      358.47
# Bid_Price_4         343.64      358.29
# Bid_Price_5         343.54      358.11
# Bid_Price_6         343.43      357.93
# Bid_Price_7         343.27      357.75
# Bid_Price_8         343.18      357.57
# Bid_Price_9         343.10      357.39
# Bid_Price_10        343.01      357.21
# Ask_Price_1         344.90      364.82
# Ask_Price_2         345.06      368.16
# Ask_Price_3         345.25      371.50
# Ask_Price_4         345.43      374.84
# Ask_Price_5         345.60      378.18
# Ask_Price_6         345.76      381.52
# Ask_Price_7         345.82      384.86
# Ask_Price_8         345.98      388.20
# Ask_Price_9         346.03      391.54
# Ask_Price_10        346.13      394.88

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure the index is a datetime object
aligned_data.index = pd.to_datetime(aligned_data.index)

# Grouping the data by time-of-day to observe intraday patterns
aligned_data['Time_of_Day'] = aligned_data.index.time

# Convert Time_of_Day to a string representation of time (HH:MM)
aligned_data['Time_of_Day'] = aligned_data['Time_of_Day'].apply(lambda x: x.strftime('%H:%M'))

# Set the style and palette for the plots
sns.set(style="whitegrid")
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10

# Create a figure with multiple subplots
fig, axes = plt.subplots(5, 3, figsize=(18, 20))  # Adjusted to fit 15 plots (5 rows, 3 columns)

# 1. Spread over the day
sns.lineplot(x='Time_of_Day', y='Spread', data=aligned_data, ax=axes[0, 0], color='red')
axes[0, 0].set_title('Intraday Seasonality of Spread')
axes[0, 0].set_xlabel('Time of Day')
axes[0, 0].set_ylabel('Spread')

# 2. Volume over the day
sns.lineplot(x='Time_of_Day', y='Volume', data=aligned_data, ax=axes[0, 1], color='blue')
axes[0, 1].set_title('Intraday Seasonality of Volume')
axes[0, 1].set_xlabel('Time of Day')
axes[0, 1].set_ylabel('Volume')

# 3. Volatility over the day
sns.lineplot(x='Time_of_Day', y='Volatility', data=aligned_data, ax=axes[0, 2], color='green')
axes[0, 2].set_title('Intraday Seasonality of Volatility')
axes[0, 2].set_xlabel('Time of Day')
axes[0, 2].set_ylabel('Volatility')

# Order Imbalance Calculation
# Dynamically check the number of bid/ask price levels available in the DataFrame
available_bid_levels = [col for col in aligned_data.columns if col.startswith('Bid_Price_')]
available_ask_levels = [col for col in aligned_data.columns if col.startswith('Ask_Price_')]

# Calculate the total volume by summing the available bid and ask price levels
aligned_data['Total_Volume'] = aligned_data[available_bid_levels].sum(axis=1) + aligned_data[available_ask_levels].sum(axis=1)

# Ensure we are only accessing available columns
bid_volumes = aligned_data[available_bid_levels].sum(axis=1)
ask_volumes = aligned_data[available_ask_levels].sum(axis=1)
# Apply smoothing and clipping to the order imbalance calculation
aligned_data['Order_Imbalance'] = (bid_volumes - ask_volumes).rolling(window=5).mean().fillna(method='bfill')
aligned_data['Order_Imbalance'] = aligned_data['Order_Imbalance'].clip(lower=-5000, upper=5000)
sns.lineplot(x=aligned_data.index, y=aligned_data['Order_Imbalance'], ax=axes[1, 0], color='blue')
axes[1, 0].set_title('Order Imbalance Over Time')
axes[1, 0].set_xlabel('Time')
axes[1, 0].set_ylabel('Amplified Order Imbalance')

# 5. Price vs Adjusted Volume (Decoupled)
sns.scatterplot(x=aligned_data['Mid_Price'], y=aligned_data['Adjusted_Volume'], ax=axes[1, 1], color='magenta', alpha=0.6)
axes[1, 1].set_title('Price vs. Adjusted Volume (Decoupled)')
axes[1, 1].set_xlabel('Mid Price')
axes[1, 1].set_ylabel('Adjusted Volume')

# 6. Volatility vs Spread Scatter Plot
sns.scatterplot(x=aligned_data['Volatility'], y=aligned_data['Spread'], ax=axes[1, 2], color='red', alpha=0.6)
axes[1, 2].set_title('Volatility vs. Spread')
axes[1, 2].set_xlabel('Volatility')
axes[1, 2].set_ylabel('Spread')

# 7. Adjusted Close Prices Over Time
sns.lineplot(x=aligned_data.index, y='Adj Close', data=aligned_data, ax=axes[2, 0], color='blue')
axes[2, 0].set_title('Adjusted Close Prices')
axes[2, 0].set_xlabel('Time')
axes[2, 0].set_ylabel('Price')

# 8. Spread Over Time
sns.lineplot(x=aligned_data.index, y='Spread', data=aligned_data, ax=axes[2, 1], color='red')
axes[2, 1].set_title('Spread Over Time')
axes[2, 1].set_xlabel('Time')
axes[2, 1].set_ylabel('Spread')

# 9. VWAP vs TWAP
sns.lineplot(x=aligned_data.index, y='VWAP', data=aligned_data, ax=axes[2, 2], color='purple', label='VWAP')
sns.lineplot(x=aligned_data.index, y='TWAP', data=aligned_data, ax=axes[2, 2], color='orange', label='TWAP')
axes[2, 2].set_title('VWAP vs. TWAP')
axes[2, 2].set_xlabel('Time')
axes[2, 2].set_ylabel('Price')
axes[2, 2].legend()

# 10. Bid Price 1 Over Time
# Check if 'Bid_Price_1' exists before plotting
if 'Bid_Price_1' in aligned_data.columns:
    sns.lineplot(x=aligned_data.index, y='Bid_Price_1', data=aligned_data, ax=axes[3, 0], color='blue')
    axes[3, 0].set_title('Bid Price 1 Over Time')
    axes[3, 0].set_xlabel('Time')
else:
    print("[DEBUG] 'Bid_Price_1' column not found in aligned_data. Check the bid price generation.")

# 11. Ask Price 1 Over Time
sns.lineplot(x=aligned_data.index, y='Ask_Price_1', data=aligned_data, ax=axes[3, 1], color='red')
axes[3, 1].set_title('Ask Price 1 Over Time')
axes[3, 1].set_xlabel('Time')
axes[3, 1].set_ylabel('Price')

# 12. Bid-Ask Spread Over Time
bid_ask_spread = aligned_data['Ask_Price_1'] - aligned_data['Bid_Price_1']
sns.lineplot(x=aligned_data.index, y=bid_ask_spread, ax=axes[3, 2], color='black')
axes[3, 2].set_title('Bid-Ask Spread Over Time')
axes[3, 2].set_xlabel('Time')
axes[3, 2].set_ylabel('Spread')

# 13. Total Volume (Bid + Ask) Over Time
# Calculate Total Volume (Bid + Ask)
aligned_data['Total_Volume'] = aligned_data[[f'Bid_Price_{i+1}' for i in range(10)]].sum(axis=1) + aligned_data[[f'Ask_Price_{i+1}' for i in range(10)]].sum(axis=1)
aligned_data['Smoothed_Total_Volume'] = aligned_data['Total_Volume'].rolling(window=5).mean()
sns.lineplot(x=aligned_data.index, y=aligned_data['Smoothed_Total_Volume'], ax=axes[4, 0], color='magenta')
axes[4, 0].set_xticklabels(axes[4, 0].get_xticklabels(), rotation=45)
axes[4, 0].set_title('Total Volume Over Time')
axes[4, 0].set_xlabel('Time')
axes[4, 0].set_ylabel('Volume')

# 14. Distribution of Mid Prices
sns.histplot(aligned_data['Mid_Price'], bins=30, kde=False, color='grey', ax=axes[4, 1], edgecolor='black')
axes[4, 1].set_title('Distribution of Mid Prices')
axes[4, 1].set_xlabel('Mid Price')
axes[4, 1].set_ylabel('Frequency')

# 15. Volatility Over Time
sns.lineplot(x=aligned_data.index, y='Volatility', data=aligned_data, ax=axes[4, 2], color='green')
axes[4, 2].set_title('Volatility Over Time')
axes[4, 2].set_xlabel('Time')
axes[4, 2].set_ylabel('Volatility')

# Rotating x-axis labels for all subplots that require it
for ax in axes.flat:  # This iterates through each subplot in the figure
    if len(ax.get_xticklabels()) > 0:  # Check if the subplot has x-axis labels
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Adjust layout and show all plots
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-f197f8e66a2e>:53: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aligned_data['Order_Imbalance'] = (bid_volumes - ask_volumes).rolling(window=5).mean().fillna(method='bfill')
# <ipython-input-19-f197f8e66a2e>:119: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[4, 0].set_xticklabels(axes[4, 0].get_xticklabels(), rotation=45)
# <ipython-input-19-f197f8e66a2e>:139: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# WARNING:root:High CPU usage: 99.5%. Pausing execution.
# WARNING:root:High CPU usage: 100.0%. Pausing execution.

# %%
class Order:
    def __init__(self, price, quantity, tid):
        self.price = round(price, 2)
        self.quantity = round(quantity, 2)
        self.tid = tid  # Store the tid (transaction ID)

class OrderBook:
    def __init__(self, transaction_cost=0.001):
        self.bids = SortedDict(lambda x: -x)  # Sorted descending
        self.asks = SortedDict()  # Sorted ascending
        self.trades = []
        self.transaction_cost = transaction_cost
        self.liquidity_fluctuation_factor = 0.1
        self.external_order_probability = 0.2
        self.mean_reversion_strength = 0.1

        # Initialize the order book with market maker orders and simulate continuous order flow
        self.reset_order_book()

    def reset_order_book(self):
        self.mid_price = 335  # You may set this to any realistic initial value or calculate it dynamically
        self._generate_market_maker_orders()  # Generate the initial market maker orders
        #self._simulate_continuous_order_flow()  # Start the continuous order flow simulation

    # Method to calculate volatility based on recent trades
    def calculate_volatility(self, window=10):
        # If there are not enough trades, return zero volatility
        if len(self.trades) < window:
            return 0

        # Extract the prices from the last 'window' number of trades
        prices = np.array([trade['price'] for trade in self.trades[-window:]])

        # If there is only one unique price, volatility is zero
        if len(np.unique(prices)) == 1:
            return 0

        # Calculate percentage returns
        returns = np.diff(prices) / prices[:-1]

        # Calculate the standard deviation of returns (volatility)
        volatility = np.std(returns) * np.sqrt(len(returns))  # Annualized volatility adjustment (optional)

        return volatility

    def _generate_new_price_levels(self):
        # Ensure there are always at least 10 levels on the bid side
        if len(self.bids) < 10:
            for i in range(len(self.bids), 10):  # Adjust to ensure valid levels
                new_bid_price = self.get_mid_price() - (i * 0.1)
                self.bids[new_bid_price] = deque([Order(new_bid_price, np.random.randint(500, 2000), f'bid-{i}')])
                print(f"[DEBUG] Added bid price level: {new_bid_price}")

        # Ensure there are always at least 10 levels on the ask side
        if len(self.asks) < 10:
            for i in range(len(self.asks), 10):  # Adjust to ensure valid levels
                new_ask_price = self.get_mid_price() + (i * 0.1)
                self.asks[new_ask_price] = deque([Order(new_ask_price, np.random.randint(500, 2000), f'ask-{i}')])
                print(f"[DEBUG] Added ask price level: {new_ask_price}")

    # Adjust slippage to reflect more realistic values
    def _calculate_slippage(self, executed_qty, liquidity, market_conditions='stable', volatility=0.02):
        base_slippage = 0.03  # Higher base slippage for large executions
        liquidity_impact = (executed_qty / liquidity) ** 1.25 if liquidity > 0 else 0  # Adjusted sensitivity
        volatility_impact = np.random.uniform(2.0, 3.0) * volatility  # Increase volatility impact
        slippage = base_slippage * (1 + liquidity_impact * volatility_impact * 10)  # Amplified result
        return slippage

    def _process_market_order(self, order):
        opposite_side = self.asks if order['side'] == 'bid' else self.bids
        remaining_qty = order['qty']
        total_cost = 0
        executed_volume = 0
        slippage_total = 0  # Initialize slippage total

        if not opposite_side:
            print("No available liquidity on the opposite side.")
            return 0, 0, 0, 0  # Early exit if no liquidity

        initial_price = next(iter(opposite_side))

        print(f"Processing market order: {order['qty']} shares on side {order['side']} at target price {initial_price}.")

        while remaining_qty > 0 and opposite_side:
            best_price = next(iter(opposite_side))
            best_order = opposite_side[best_price][0]
            trade_qty = min(best_order.quantity, remaining_qty)
            liquidity = sum(order.quantity for order in opposite_side[best_price])

            # Calculate slippage dynamically based on trade size, liquidity, and market conditions
            volatility = self.calculate_volatility()  # Use the calculated volatility from your model
            slippage = round(self._calculate_slippage(trade_qty, liquidity, 'volatile', volatility), 4)
            slippage_total += slippage * trade_qty  # Accumulate total slippage

            # Adjust the executed price based on slippage
            executed_price = round(best_price * (1 + slippage), 2)

            print(f"Matching order: Price {best_price:.2f}, Qty {trade_qty}, Executed price: {executed_price:.2f}, Liquidity: {liquidity}")

            # Append trade to trade history
            self.trades.append({'price': executed_price, 'qty': trade_qty})
            remaining_qty -= trade_qty
            best_order.quantity -= trade_qty
            executed_volume += trade_qty  # Accumulate executed volume
            total_cost += trade_qty * executed_price  # Accumulate total cost

            # Remove the best order if fully filled
            if best_order.quantity == 0:
                opposite_side[best_price].popleft()
                if not opposite_side[best_price]:
                    del opposite_side[best_price]

            # Stop if no more orders are available on the opposite side
            if not opposite_side:
                break

        # Calculate average price and other metrics
        avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
        market_impact = self._simulate_market_impact(executed_volume, liquidity, volatility)  # Pass volatility
        slippage_percentage = self._calculate_slippage(executed_volume, liquidity, 'volatile', volatility)

        return executed_volume, avg_price, slippage_percentage, market_impact

    # Replace the previous order book generation method with this
    def _generate_market_maker_orders(self):
        spread = 0.25
        liquidity_range = (1000, 5000)
        for i in range(15):
            bid_price = self.mid_price - i * spread
            ask_price = self.mid_price + i * spread
            self.bids[bid_price] = deque([Order(bid_price, np.random.randint(*liquidity_range), f'bid-{i}')])
            self.asks[ask_price] = deque([Order(ask_price, np.random.randint(*liquidity_range), f'ask-{i}')])

    def calculate_vwap(self, trades):
        if not trades:
            return 0
        prices = np.array([trade['price'] for trade in trades])
        quantities = np.array([trade['qty'] for trade in trades])
        cumulative_price_volume = np.cumsum(prices * quantities)
        cumulative_volume = np.cumsum(quantities)
        vwap = cumulative_price_volume / cumulative_volume
        vwap_value = round(vwap[-1], 2)

        # Add logging
        vwap_value = round(vwap_value, 2)
        print(f"VWAP Calculation: {vwap_value}, based on {len(trades)} trades.")

        return vwap_value

    def calculate_twap(self, trades):
        if not trades:
            return 0
        times = np.linspace(1, len(trades), len(trades))  # Time intervals, starting from 1
        weighted_prices = [trade['price'] for trade in trades]

        # Ensure no division by zero occurs if weights (times) are all zero
        if np.sum(times) == 0:
            return 0
        twap = np.average(weighted_prices, weights=times)
        twap_value = round(twap, 2)

        # Add logging
        print(f"TWAP Calculation: {twap_value}, based on {len(trades)} trades.")

        return twap_value

    def process_order(self, order):
        # Introduce randomness to simulate other market participants
        if np.random.rand() < self.external_order_probability:
            self._generate_external_order()

        if order['type'] == 'limit':
            self._process_limit_order(order)
        elif order['type'] == 'market':
            # Process the market order
            executed_volume, avg_price, slippage_percentage, market_impact = self._process_market_order(order)

            # Calculate VWAP and TWAP after processing the order
            vwap_value = self.calculate_vwap(self.trades)
            twap_value = self.calculate_twap(self.trades)

            # Add detailed logging of the execution
            total_order_qty = order['qty']
            remaining_qty = total_order_qty - executed_volume

            # Log the execution details with remaining quantity
            print(f"Order: {total_order_qty} shares; Executed: {executed_volume}, Remaining: {remaining_qty}")
            print(f"Average Price: {avg_price:.2f}, Slippage: {slippage_percentage:.2f}%, Market Impact: {market_impact:.4f}")
            print(f"VWAP: {vwap_value}, TWAP: {twap_value}")
        else:
            print(f"Unknown order type: {order['type']}")

    def _process_limit_order(self, order):
        side = self.bids if order['side'] == 'bid' else self.asks
        opposite = self.asks if order['side'] == 'bid' else self.bids
        price = round(order['price'], 2)  # Ensure prices are rounded
        qty = order['qty']

        # Add a print statement at the start of limit order processing for visibility
        print(f"Processing limit order: {qty} shares on side {order['side']} at price {price}.")

        # Attempt to match against opposite orders
        while qty > 0 and opposite:
            best_price = opposite.peekitem(0)[0]  # Get the best price from the opposite side

            if (order['side'] == 'bid' and price >= best_price) or (order['side'] == 'ask' and price <= best_price):
                best_orders = opposite[best_price]  # Get the best orders at the best price
                while qty > 0 and best_orders:
                    best_order = best_orders[0]
                    trade_qty = min(qty, best_order.quantity)  # Determine the trade quantity
                    executed_price = round(best_price * (1 + self.transaction_cost * (-1 if order['side'] == 'bid' else 1)), 2)  # Adjust price with transaction cost

                    # Append trade details to the trade history
                    self.trades.append({'price': executed_price, 'qty': trade_qty})
                    qty -= trade_qty  # Reduce the remaining quantity to be matched
                    best_order.quantity -= trade_qty  # Reduce the quantity of the matched order

                    # Log executed and remaining quantities
                    print(f"Order: {order['qty']} shares; Executed: {order['qty'] - qty}, Remaining: {qty}")

                    # Remove the order if fully executed
                    if best_order.quantity == 0:
                        best_orders.popleft()
                    if not best_orders:
                        del opposite[best_price]
            else:
                break  # Exit the loop if no more matching is possible

        # Add the remaining quantity to the book if it's not fully matched
        if qty > 0:
            if price in side:
                side[price].append(Order(price, qty, order['tid']))
            else:
                side[price] = deque([Order(price, qty, order['tid'])])

    def _fluctuate_liquidity(self, side):
        # Apply random adjustments to the remaining liquidity in the order book
        for price, orders in list(side.items()):
            for order in orders:
                # Adjust the quantity slightly to simulate changing liquidity
                fluctuation_factor = np.random.uniform(0.8, 1.2)  # Small random variation in liquidity
                order.quantity = max(1, int(order.quantity * fluctuation_factor))  # Ensure the quantity is at least 1

        # Optionally, you could remove prices with extremely low liquidity
        for price in list(side.keys()):
            if sum(order.quantity for order in side[price]) <= 1:  # If liquidity is very low, remove the price level
                del side[price]

    def _generate_external_order(self):
        side = 'bid' if np.random.rand() > 0.5 else 'ask'
        price = self._get_random_price(side)
        qty = np.random.randint(500, 2000)  # Generate larger random orders to keep the order book liquid
        order = {
            'type': 'limit',
            'side': side,
            'price': price,
            'qty': qty,
            'tid': 'external'
        }
        self.process_order(order)
        print(f"[DEBUG] Generated external {side} order at price {price} for {qty} shares.")

    # Add this new function within the OrderBook class
    def _generate_incoming_order(self):
        side = 'bid' if np.random.rand() > 0.5 else 'ask'
        price = self._get_random_price(side)
        qty = np.random.randint(500, 2000)
        order_type = np.random.choice(['limit', 'market'])
        order = {
            'type': order_type,
            'side': side,
            'price': price,
            'qty': qty,
            'tid': 'external'
        }
        self.process_order(order)

    def _simulate_continuous_order_flow(self):
        while True:
            if np.random.rand() < self.external_order_probability:
                self._generate_incoming_order()
                self._adjust_liquidity()
            time.sleep(np.random.uniform(0.2, 1.0))  # Adjust the timing to simulate realistic order flow

    def _ensure_residual_liquidity(self, side):
        # Make sure there is a minimum liquidity at each price level
        for price, orders in side.items():
            total_quantity = sum(order.quantity for order in orders)
            if total_quantity < 100:  # Arbitrary threshold for residual liquidity
                orders[-1].quantity += 100  # Ensure at least 100 units remain at each price level

    def get_mid_price(self):
        if self.asks and self.bids:
            return (min(self.asks.keys()) + max(self.bids.keys())) / 2  # Simple average of best bid and ask
        else:
            return 100.0  # Fallback mid-price if the book is empty

    def _initialize_market_maker(self):
        # Generate market maker orders
        self._generate_market_maker_orders()

        # Start simulating continuous order flow
        self._simulate_continuous_order_flow()

    # Update market impact calculation to scale more aggressively based on order size and liquidity
    def _simulate_market_impact(self, executed_qty, liquidity, volatility=0.01, base_impact=0.001):
        if liquidity == 0:
            return base_impact  # Prevent division by zero

        # Market impact should increase with order size relative to liquidity and volatility
        impact_factor = (executed_qty / liquidity) * (1 + volatility * np.random.uniform(1.5, 3.0))  # Add volatility sensitivity

        market_impact = base_impact * (1 + impact_factor)

        # Clip the market impact to ensure it's within realistic bounds (e.g., 0.1% to 1%)
        return np.clip(market_impact, 0.001, 0.01)

    def _mean_reversion(self):
        for side in [self.bids, self.asks]:
            for price in list(side.keys()):
                reverted_price = price * (1 - self.mean_reversion_strength * 0.5)
                if reverted_price in side:
                    side[reverted_price].extend(side[price])
                else:
                    side[reverted_price] = side[price]
                del side[price]

    def _get_random_price(self, side):
        # Assume realistic prices are around the mid-price range of the data, e.g., 300-350.
        realistic_price_range = (300, 350)

        if side == 'bid' and self.bids:
            return round(max(self.bids.keys()) * np.random.uniform(0.99, 1.01), 2)
        elif side == 'ask' and self.asks:
            return round(min(self.asks.keys()) * np.random.uniform(0.99, 1.01), 2)
        else:
            mid_price = np.random.uniform(*realistic_price_range)
            return round(mid_price * np.random.uniform(0.99, 1.01), 2)

    # Adjust the rate at which liquidity replenishes after orders are executed
    def _adjust_liquidity(self):
        for price in list(self.bids.keys()):
            for order in self.bids[price]:
                # Reduce replenishment rate, making liquidity decay more significant
                order.quantity = max(100, int(order.quantity * np.random.uniform(0.7, 1.1)))
        for price in list(self.asks.keys()):
            for order in self.asks[price]:
                order.quantity = max(100, int(order.quantity * np.random.uniform(0.7, 1.1)))

    def _adjust_spread(self):
        for price in list(self.bids.keys()):
            self.bids[price] *= np.random.uniform(1.01, 1.05)  # Widen spread slightly on bids
        for price in list(self.asks.keys()):
            self.asks[price] *= np.random.uniform(1.01, 1.05)  # Widen spread slightly on asks

    def print_book(self, levels=5):
        print("\nOrder Book Snapshot:")
        print("Asks:")
        for price, orders in list(self.asks.items())[:levels]:
            total_qty = sum(order.quantity for order in orders)
            print(f"Price: {price:.2f}, Total Quantity: {round(total_qty, 2)}")
        print("Bids:")
        for price, orders in list(self.bids.items())[:levels]:
            total_qty = sum(order.quantity for order in orders)
            print(f"Price: {price:.2f}, Total Quantity: {round(total_qty, 2)}")

    def print_trades(self):
        print("\nTrades:")
        for trade in self.trades:
            print(f"Traded {trade['qty']} @ {trade['price']:.2f}")

# %%
# Function to check the current state of the order book
def check_order_book_state(lob):
    print("[DEBUG] Checking order book state...")

    print("[DEBUG] Bids in the order book (Top 5 Levels):")
    for price, orders in list(lob.bids.items())[:5]:  # Print the top 5 levels of bids
        total_qty = sum(order.quantity for order in orders)
        print(f"Price: {price:.2f}, Total Quantity: {total_qty}")

    print("[DEBUG] Asks in the order book (Top 5 Levels):")
    for price, orders in list(lob.asks.items())[:5]:  # Print the top 5 levels of asks
        total_qty = sum(order.quantity for order in orders)
        print(f"Price: {price:.2f}, Total Quantity: {total_qty}")

def populate_order_book(lob, aligned_data):
    print("\n[DEBUG] Populating the order book with initial data...")

    for index, row in aligned_data.iterrows():
        mid_price = row['Mid_Price']
        liquidity = liq = round(row['Liquidity'] / 10, 2)

        # Dynamically handle max levels based on the available columns
        bid_cols = [col for col in row.index if 'Bid_Price_' in col and not pd.isna(row[col])]
        ask_cols = [col for col in row.index if 'Ask_Price_' in col and not pd.isna(row[col])]

        # Set max levels based on the smaller of bid/ask levels or 10
        max_levels = min(10, len([col for col in aligned_data.columns if 'Bid_Price_' in col]),
                 len([col for col in aligned_data.columns if 'Ask_Price_' in col]))

        if max_levels == 0:
            print(f"[DEBUG] No valid bid/ask levels for row {index}. Skipping this entry.")
            continue

        available_levels = min(num_levels, len([col for col in row.index if 'Bid_Price_' in col]))

        for level in range(1, available_levels + 1):  # Adjust based on available levels
            bid_price_col = 'Bid_Price_{}'.format(level)
            ask_price_col = 'Ask_Price_{}'.format(level)


            # Check for valid bid prices and process bid orders
            if bid_price_col in row and not pd.isna(row[bid_price_col]):
                bid_order = {
                    'type': 'limit',
                    'side': 'bid',
                    'price': row[bid_price_col],
                    'qty': liquidity,
                    'tid': 'bid-{}-{}'.format(index, level)  # Create unique tid
                }
                lob.process_order(bid_order)

            # Check for valid ask prices and process ask orders
            if ask_price_col in row and not pd.isna(row[ask_price_col]):
                ask_order = {
                    'type': 'limit',
                    'side': 'ask',
                    'price': row[ask_price_col],
                    'qty': liquidity,
                    'tid': 'ask-{}-{}'.format(index, level)  # Create unique tid
                }
                lob.process_order(ask_order)

    print("\n[DEBUG] Initial Order Book Snapshot (Top 5 Levels):")
    lob.print_book(levels=5)  # Display the top 5 levels

def execute_vwap_order_with_shares(lob, total_shares):
    executed_volume, total_cost = 0, 0
    remaining_shares = total_shares
    lob.trades.clear()

    vwap_prices, vwap_volumes, vwap_slippage, vwap_market_impact = [], [], [], []

    print(f"\n[DEBUG] VWAP function started to buy {total_shares} shares.", flush=True)
    lob.print_book(levels=5)  # Print the top 5 levels of the order book before execution

    while remaining_shares > 0:
        print(f"\n[DEBUG] VWAP loop - remaining shares: {remaining_shares}.", flush=True)

        # Ensure enough levels are available
        price_range = sorted([p for p in lob.asks.keys() if p > 0])
        target_levels = min(10, len(price_range))  # Limit to available levels

        if target_levels == 0:
            print(f"[DEBUG] No valid price levels to choose from.")
            break

        target_price = np.random.choice(price_range[:target_levels])

        liquidity = sum(order.quantity for order in lob.asks[target_price])

        if liquidity <= 0:
            print(f"[DEBUG] Insufficient liquidity at {target_price}. Skipping.")
            continue

        current_order_qty = min(remaining_shares, int(liquidity * 0.3))  # Use 30% of liquidity at this level

        market_order = {
            'type': 'market',
            'side': 'bid',
            'instrument': 'MSFT',
            'qty': current_order_qty,
            'tid': -1
        }

        exec_vol, avg_price, slippage_percentage, market_impact = lob._process_market_order(market_order)

        if exec_vol == 0:
            print(f"[DEBUG] VWAP halted: Unable to execute at {target_price} due to liquidity constraints.")
            break

        vwap_volumes.append(exec_vol)
        vwap_prices.append(avg_price)
        vwap_slippage.append(slippage_percentage)
        vwap_market_impact.append(market_impact)

        remaining_shares -= exec_vol
        executed_volume += exec_vol
        total_cost += exec_vol * avg_price

        print(f"VWAP: Executed {exec_vol} shares at avg price {avg_price:.2f}. Remaining shares: {remaining_shares}.", flush=True)
        print(f"VWAP: Slippage: {slippage_percentage:.4f}, Market Impact: {market_impact:.4f}", flush=True)

        # Calculate VWAP based on executed trades so far
        vwap_value = lob.calculate_vwap(lob.trades)
        print(f"VWAP value: {vwap_value}", flush=True)

        # Simulate market dynamics with new orders
        lob._generate_external_order()
        time.sleep(0.3)

    avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
    transaction_cost_total = executed_volume * avg_price * lob.transaction_cost

    print(f"\n[DEBUG] VWAP Execution Complete: Executed Volume = {executed_volume}, Avg Price = ${avg_price:.2f}, Remaining Shares = {remaining_shares}", flush=True)

    return {
        'prices': vwap_prices,
        'volumes': vwap_volumes,
        'slippage': vwap_slippage,
        'market_impact': vwap_market_impact,
        'avg_price': avg_price,
        'volume': executed_volume,
        'total_cost': total_cost,
        'transaction_cost_total': transaction_cost_total
    }


# Adapt the share distribution to follow intraday volume patterns (higher at open/close)
def twap_share_distribution(periods, total_shares):
    # More volume at the open and close of the market
    volume_profile = [0.3, 0.15, 0.1, 0.05, 0.05, 0.05, 0.1, 0.1, 0.1]  # Realistic intraday liquidity profile
    volume_profile = np.array(volume_profile[:periods]) / np.sum(volume_profile[:periods])  # Normalize the profile
    return (total_shares * volume_profile).astype(int)  # Distribute shares based on the profile

def execute_twap_order(lob, total_shares, periods):
    executed_volume, total_cost = 0, 0
    remaining_shares = total_shares
    shares_per_period = twap_share_distribution(periods, total_shares)
    lob.trades.clear()

    twap_prices, twap_volumes, twap_slippage, twap_market_impact = [], [], [], []

    print(f"\n[DEBUG] TWAP function started to buy {total_shares} shares over {periods} periods.", flush=True)
    lob.print_book(levels=5)

    for period in range(periods):
        if remaining_shares <= 0:
            print(f"\n[DEBUG] TWAP halted: No remaining shares to buy.", flush=True)
            break

        price_range = sorted([p for p in lob.asks.keys() if p > 0])
        target_levels = min(10, len(price_range))

        if target_levels == 0:
            print(f"[DEBUG] No valid price levels to choose from.")
            break

        target_price = np.random.choice(price_range[:target_levels])

        liquidity = sum(order.quantity for order in lob.asks[target_price])

        current_order_qty = min(shares_per_period[period], remaining_shares, liquidity)

        if current_order_qty <= 0:
            print(f"[DEBUG] TWAP halted: Insufficient liquidity at price {target_price}.", flush=True)
            break

        market_order = {
            'type': 'market',
            'side': 'bid',
            'instrument': 'MSFT',
            'qty': current_order_qty,
            'tid': -1
        }

        exec_vol, avg_price, slippage_percentage, market_impact = lob._process_market_order(market_order)

        if exec_vol == 0:
            print(f"[DEBUG] TWAP execution stopped: No volume executed this period.")
            break

        twap_prices.append(avg_price)
        twap_volumes.append(exec_vol)
        twap_slippage.append(slippage_percentage)
        twap_market_impact.append(market_impact)

        remaining_shares -= exec_vol
        executed_volume += exec_vol
        total_cost += exec_vol * avg_price

        print(f"TWAP: Executed {exec_vol} shares at avg price {avg_price:.2f}. Remaining shares: {remaining_shares}.", flush=True)
        print(f"TWAP: Slippage: {slippage_percentage:.4f}, Market Impact: {market_impact:.4f}", flush=True)

        twap_value = lob.calculate_twap(lob.trades)
        print(f"TWAP value: {twap_value}", flush=True)

        lob._generate_external_order()  # Simulate market dynamics
        time.sleep(0.3)

    avg_price = round(total_cost / executed_volume, 2) if executed_volume > 0 else 0
    transaction_cost_total = executed_volume * avg_price * lob.transaction_cost

    print(f"\n[DEBUG] TWAP Execution Complete: Executed Volume = {executed_volume}, Avg Price = ${avg_price:.2f}, Remaining Shares = {remaining_shares}", flush=True)

    return {
        'prices': twap_prices,
        'volumes': twap_volumes,
        'slippage': twap_slippage,
        'market_impact': twap_market_impact,
        'avg_price': avg_price,
        'volume': executed_volume,
        'total_cost': total_cost,
        'transaction_cost_total': transaction_cost_total
    }


    # Return collected data for plotting
    return {
        'prices': twap_prices,
        'volumes': twap_volumes,
        'slippage': twap_slippage,
        'market_impact': twap_market_impact,
        'total_cost': total_cost,
        'avg_price': avg_price,
        'transaction_cost_total': transaction_cost_total,
        'volume': executed_volume  # Ensure executed_volume is correctly returned
    }

def present_execution_results(vwap_results, twap_results):
    print("\n=== Execution Results Comparison ===\n")
    print(f"{'Metric':<25} {'VWAP':<15} {'TWAP':<15}")
    print("="*55)

    # Present Total Executed Volume
    print(f"{'Executed Volume (shares)':<25} {vwap_results['volume']:<15} {twap_results['volume']:<15}")

    # Present Average Price
    print(f"{'Average Price ($)':<25} {vwap_results['avg_price']:<15} {twap_results['avg_price']:<15}")

    # Present Total Cost
    print(f"{'Total Cost ($)':<25} {round(vwap_results['total_cost'], 2):<15} {round(twap_results['total_cost'], 2):<15}")

    # Present Transaction Cost
    print(f"{'Transaction Cost ($)':<25} {round(vwap_results['transaction_cost_total'], 2):<15} {round(twap_results['transaction_cost_total'], 2):<15}")

    # Present Slippage
    print(f"{'Slippage (avg %)':<25} {np.mean(vwap_results['slippage']):<15.4f} {np.mean(twap_results['slippage']):<15.4f}")

    # Present Market Impact
    print(f"{'Market Impact (avg %)':<25} {np.mean(vwap_results['market_impact']):<15.4f} {np.mean(twap_results['market_impact']):<15.4f}")

    print("\n=======================================================\n")


# Run both VWAP and TWAP simulations and return structured data for neat presentation
def _run_single_simulation_with_shares(lob, total_shares, twap_periods=10):
    print(f"\n[DEBUG] Running simulation to buy {total_shares} shares", flush=True)

    # Initialize the results to avoid NameError, even if an error occurs later
    vwap_results = {
        'volume': 0, 'avg_price': 0, 'transaction_cost_total': 0,
        'slippage': [], 'market_impact': [], 'total_cost': 0
    }
    twap_results = {
        'volume': 0, 'avg_price': 0, 'transaction_cost_total': 0,
        'slippage': [], 'market_impact': [], 'total_cost': 0
    }

    # VWAP execution
    try:
        print("[DEBUG] Calling VWAP function to buy shares...", flush=True)
        vwap_results = execute_vwap_order_with_shares(lob, total_shares)
        print(f"[DEBUG] VWAP completed. Executed volume: {vwap_results['volume']} shares, "
              f"Avg price: ${vwap_results['avg_price']:.2f}, Transaction cost: ${vwap_results['transaction_cost_total']:.2f}", flush=True)
    except Exception as e:
        print(f"[DEBUG] Error during VWAP execution: {e}", flush=True)

    # TWAP execution with proper handling
    try:
        print("[DEBUG] Calling TWAP function to buy shares...", flush=True)
        twap_results = execute_twap_order(lob, total_shares, twap_periods)
        print(f"[DEBUG] TWAP completed. Executed volume: {twap_results['volume']} shares, "
              f"Avg price: ${twap_results['avg_price']:.2f}, Transaction cost: ${twap_results['transaction_cost_total']:.2f}", flush=True)
    except Exception as e:
        print(f"[DEBUG] Error during TWAP execution: {e}", flush=True)

    # Present the results neatly
    present_execution_results(vwap_results, twap_results)

    # Return results for further use if needed
    return {
        'VWAP': {
            'volume': vwap_results['volume'],
            'avg_price': vwap_results['avg_price'],
            'total_cost': vwap_results['total_cost'],
            'transaction_cost': vwap_results['transaction_cost_total'],
            'slippage': vwap_results['slippage'],
            'market_impact': vwap_results['market_impact']
        },
        'TWAP': {
            'volume': twap_results['volume'],
            'avg_price': twap_results['avg_price'],
            'total_cost': twap_results['total_cost'],
            'transaction_cost': twap_results['transaction_cost_total'],
            'slippage': twap_results['slippage'],
            'market_impact': twap_results['market_impact']
        }
    }

# Define and run the simulation for 100,000 shares
print("[DEBUG] Initializing OrderBook...", flush=True)
lob = OrderBook(transaction_cost=0.001)

# Generate the order book from the previously defined aligned_data
try:
    populate_order_book(lob, aligned_data)
except Exception as e:
    print(f"[DEBUG] Error populating order book: {e}", flush=True)

# Check the order book state
check_order_book_state(lob)

# Run VWAP and TWAP simulation
try:
    print("[DEBUG] Starting the VWAP and TWAP simulations...", flush=True)

    # Run VWAP simulation and capture the results
    vwap_results = execute_vwap_order_with_shares(lob, total_shares=100000)

    # Run TWAP simulation and capture the results
    twap_results = execute_twap_order(lob, total_shares=100000, periods=10)

    # Present the execution results neatly
    present_execution_results(vwap_results, twap_results)

except Exception as e:
    print(f"[DEBUG] Error running simulation: {e}", flush=True)

# Output the simulation results
print("\nSimulation Results:")
print(f"VWAP Results: {vwap_results}")
print(f"TWAP Results: {twap_results}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Order: 15351.75 shares; Executed: 15351.75, Remaining: 0.0
# Processing limit order: 590 shares on side ask at price 338.84.
# [DEBUG] Generated external ask order at price 338.84 for 590 shares.
# Processing limit order: 738 shares on side bid at price 333.44.
# [DEBUG] Generated external bid order at price 333.44 for 738 shares.
# Processing limit order: 15351.75 shares on side ask at price 338.45.
# Processing limit order: 15351.75 shares on side bid at price 337.47.
# Order: 15351.75 shares; Executed: 15351.75, Remaining: 0.0
# Processing limit order: 15351.75 shares on side ask at price 338.49.
# Processing limit order: 17412.32 shares on side bid at price 337.32.
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 337.56.
# Processing limit order: 1433 shares on side ask at price 338.61.
# [DEBUG] Generated external ask order at price 338.61 for 1433 shares.
# Processing limit order: 17412.32 shares on side bid at price 337.26.
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 337.62.
# Processing limit order: 17412.32 shares on side bid at price 337.2.
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 1152 shares on side ask at price 334.84.
# Order: 1152 shares; Executed: 1152, Remaining: 0
# [DEBUG] Generated external ask order at price 334.84 for 1152 shares.
# Processing limit order: 17412.32 shares on side ask at price 337.68.
# Processing limit order: 768 shares on side ask at price 336.39.
# [DEBUG] Generated external ask order at price 336.39 for 768 shares.
# Processing limit order: 17412.32 shares on side bid at price 337.14.
# Order: 17412.32 shares; Executed: 16415.380000000012, Remaining: 996.9399999999878
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 1552 shares on side ask at price 337.74.
# [DEBUG] Generated external ask order at price 337.74 for 1552 shares.
# Processing limit order: 17412.32 shares on side ask at price 337.74.
# Processing limit order: 17412.32 shares on side bid at price 337.08.
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 337.8.
# Processing limit order: 17412.32 shares on side bid at price 337.02.
# Order: 17412.32 shares; Executed: 4616.430000000011, Remaining: 12795.889999999989
# Order: 17412.32 shares; Executed: 5555.430000000011, Remaining: 11856.889999999989
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 337.86.
# Processing limit order: 17412.32 shares on side bid at price 336.96.
# Order: 17412.32 shares; Executed: 11168.80000000001, Remaining: 6243.5199999999895
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 337.92.
# Processing limit order: 17412.32 shares on side bid at price 336.9.
# Order: 17412.32 shares; Executed: 17311.20000000001, Remaining: 101.11999999998807
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 641 shares on side bid at price 338.14.
# Order: 641 shares; Executed: 641, Remaining: 0
# [DEBUG] Generated external bid order at price 338.14 for 641 shares.
# Processing limit order: 17412.32 shares on side ask at price 337.98.
# Processing limit order: 17412.32 shares on side bid at price 336.84.
# Order: 17412.32 shares; Executed: 15934.340000000011, Remaining: 1477.9799999999886
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 338.04.
# Processing limit order: 17412.32 shares on side bid at price 336.78.
# Order: 17412.32 shares; Executed: 17412.32, Remaining: 0.0
# Processing limit order: 17412.32 shares on side ask at price 338.1.
# Processing limit order: 83288.6 shares on side bid at price 335.98.
# Processing limit order: 83288.6 shares on side ask at price 337.24.
# Processing limit order: 83288.6 shares on side bid at price 335.67.
# Processing limit order: 83288.6 shares on side ask at price 337.55.
# Processing limit order: 83288.6 shares on side bid at price 335.35.
# Processing limit order: 83288.6 shares on side ask at price 337.87.
# Processing limit order: 83288.6 shares on side bid at price 335.04.
# Processing limit order: 1167 shares on side ask at price 336.37.
# [DEBUG] Generated external ask order at price 336.37 for 1167 shares.
# Processing limit order: 83288.6 shares on side ask at price 338.18.
# Processing limit order: 83288.6 shares on side bid at price 334.72.
# Processing limit order: 830 shares on side bid at price 336.49.
# Order: 830 shares; Executed: 830, Remaining: 0
# [DEBUG] Generated external bid order at price 336.49 for 830 shares.
# Processing limit order: 83288.6 shares on side ask at price 338.5.
# Processing limit order: 630 shares on side ask at price 335.03.
# Order: 630 shares; Executed: 630, Remaining: 0
# [DEBUG] Generated external ask order at price 335.03 for 630 shares.
# Processing limit order: 83288.6 shares on side bid at price 334.41.
# Processing limit order: 83288.6 shares on side ask at price 338.81.
# Processing limit order: 83288.6 shares on side bid at price 334.09.
# Processing limit order: 83288.6 shares on side ask at price 339.13.
# Processing limit order: 83288.6 shares on side bid at price 333.78.
# Processing limit order: 83288.6 shares on side ask at price 339.44.
# Processing limit order: 83288.6 shares on side bid at price 333.46.
# Processing limit order: 83288.6 shares on side ask at price 339.76.
# Processing limit order: 607 shares on side ask at price 336.41.
# [DEBUG] Generated external ask order at price 336.41 for 607 shares.
# Processing limit order: 83288.6 shares on side bid at price 333.15.
# Processing limit order: 83288.6 shares on side ask at price 340.07.
# Processing limit order: 142006.63 shares on side bid at price 334.92.
# Processing limit order: 142006.63 shares on side ask at price 337.18.
# Processing limit order: 142006.63 shares on side bid at price 334.35.
# Processing limit order: 142006.63 shares on side ask at price 337.75.
# Processing limit order: 142006.63 shares on side bid at price 333.78.
# Processing limit order: 142006.63 shares on side ask at price 338.32.
# Processing limit order: 142006.63 shares on side bid at price 333.22.
# Processing limit order: 142006.63 shares on side ask at price 338.88.
# Processing limit order: 142006.63 shares on side bid at price 332.65.
# Processing limit order: 142006.63 shares on side ask at price 339.45.
# Processing limit order: 142006.63 shares on side bid at price 332.08.
# Processing limit order: 142006.63 shares on side ask at price 340.02.
# Processing limit order: 142006.63 shares on side bid at price 331.52.
# Processing limit order: 142006.63 shares on side ask at price 340.58.
# Processing limit order: 142006.63 shares on side bid at price 330.95.
# Processing limit order: 142006.63 shares on side ask at price 341.15.
# Processing limit order: 142006.63 shares on side bid at price 330.39.
# Processing limit order: 142006.63 shares on side ask at price 341.71.
# Processing limit order: 142006.63 shares on side bid at price 329.82.
# Processing limit order: 142006.63 shares on side ask at price 342.28.
# Processing limit order: 38786.66 shares on side bid at price 335.9.
# Processing limit order: 571 shares on side bid at price 337.29.
# Order: 571 shares; Executed: 571, Remaining: 0
# [DEBUG] Generated external bid order at price 337.29 for 571 shares.
# Processing limit order: 38786.66 shares on side ask at price 336.54.
# Processing limit order: 38786.66 shares on side bid at price 335.74.
# Processing limit order: 38786.66 shares on side ask at price 336.7.
# Processing limit order: 38786.66 shares on side bid at price 335.58.
# Processing limit order: 38786.66 shares on side ask at price 336.86.
# Processing limit order: 38786.66 shares on side bid at price 335.42.
# Processing limit order: 38786.66 shares on side ask at price 337.02.
# Processing limit order: 623 shares on side ask at price 334.05.
# Order: 623 shares; Executed: 623, Remaining: 0
# [DEBUG] Generated external ask order at price 334.05 for 623 shares.
# Processing limit order: 38786.66 shares on side bid at price 335.26.
# Processing limit order: 38786.66 shares on side ask at price 337.18.
# Processing limit order: 38786.66 shares on side bid at price 335.1.
# Processing limit order: 872 shares on side ask at price 334.1.
# Order: 872 shares; Executed: 872, Remaining: 0
# [DEBUG] Generated external ask order at price 334.1 for 872 shares.
# Processing limit order: 38786.66 shares on side ask at price 337.34.
# Processing limit order: 855 shares on side bid at price 333.97.
# [DEBUG] Generated external bid order at price 333.97 for 855 shares.
# Processing limit order: 1585 shares on side ask at price 334.01.
# Order: 1585 shares; Executed: 1585, Remaining: 0
# [DEBUG] Generated external ask order at price 334.01 for 1585 shares.
# Processing limit order: 38786.66 shares on side bid at price 334.94.
# Processing limit order: 1245 shares on side ask at price 337.04.
# [DEBUG] Generated external ask order at price 337.04 for 1245 shares.
# Processing limit order: 1795 shares on side ask at price 334.6.
# Order: 1795 shares; Executed: 1795, Remaining: 0
# [DEBUG] Generated external ask order at price 334.6 for 1795 shares.
# Processing limit order: 38786.66 shares on side ask at price 337.5.
# Processing limit order: 38786.66 shares on side bid at price 334.77.
# Processing limit order: 38786.66 shares on side ask at price 337.67.
# Processing limit order: 38786.66 shares on side bid at price 334.61.
# Processing limit order: 38786.66 shares on side ask at price 337.83.
# Processing limit order: 977 shares on side ask at price 334.67.
# Order: 977 shares; Executed: 977, Remaining: 0
# [DEBUG] Generated external ask order at price 334.67 for 977 shares.
# Processing limit order: 38786.66 shares on side bid at price 334.45.
# Processing limit order: 682 shares on side ask at price 339.13.
# [DEBUG] Generated external ask order at price 339.13 for 682 shares.
# Processing limit order: 38786.66 shares on side ask at price 337.99.
# Processing limit order: 30618.46 shares on side bid at price 337.27.
# Order: 30618.46 shares; Executed: 2734.3900000000103, Remaining: 27884.06999999999
# Order: 30618.46 shares; Executed: 26289.11000000001, Remaining: 4329.349999999988
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 337.75.
# Processing limit order: 30618.46 shares on side bid at price 337.14.
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 1997 shares on side ask at price 333.76.
# Order: 1997 shares; Executed: 1997, Remaining: 0
# [DEBUG] Generated external ask order at price 333.76 for 1997 shares.
# Processing limit order: 30618.46 shares on side ask at price 337.88.
# Processing limit order: 746 shares on side ask at price 333.5.
# Order: 746 shares; Executed: 746, Remaining: 0
# [DEBUG] Generated external ask order at price 333.5 for 746 shares.
# Processing limit order: 30618.46 shares on side bid at price 337.02.
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.0.
# Processing limit order: 30618.46 shares on side bid at price 336.9.
# Order: 30618.46 shares; Executed: 10503.180000000008, Remaining: 20115.27999999999
# Order: 30618.46 shares; Executed: 27179.640000000007, Remaining: 3438.8199999999924
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.12.
# Processing limit order: 30618.46 shares on side bid at price 336.78.
# Order: 30618.46 shares; Executed: 19586.870000000006, Remaining: 11031.589999999993
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.24.
# Processing limit order: 30618.46 shares on side bid at price 336.65.
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.37.
# Processing limit order: 1545 shares on side bid at price 337.71.
# Order: 1545 shares; Executed: 1545, Remaining: 0
# [DEBUG] Generated external bid order at price 337.71 for 1545 shares.
# Processing limit order: 30618.46 shares on side bid at price 336.53.
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.49.
# Processing limit order: 30618.46 shares on side bid at price 336.41.
# Order: 30618.46 shares; Executed: 20696.48000000001, Remaining: 9921.979999999989
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.61.
# Processing limit order: 30618.46 shares on side bid at price 336.29.
# Order: 30618.46 shares; Executed: 6754.4800000000105, Remaining: 23863.97999999999
# Order: 30618.46 shares; Executed: 8729.48000000001, Remaining: 21888.97999999999
# Order: 30618.46 shares; Executed: 30618.46, Remaining: 0.0
# Processing limit order: 30618.46 shares on side ask at price 338.73.
# Processing limit order: 1753 shares on side ask at price 336.64.
# [DEBUG] Generated external ask order at price 336.64 for 1753 shares.
# Processing limit order: 30618.46 shares on side bid at price 336.16.
# Processing limit order: 30618.46 shares on side ask at price 338.86.
# Processing limit order: 12893.01 shares on side bid at price 337.98.
# Order: 12893.01 shares; Executed: 1665.7400000000125, Remaining: 11227.269999999988
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.16.
# Processing limit order: 12893.01 shares on side bid at price 337.93.
# Order: 12893.01 shares; Executed: 11798.420000000011, Remaining: 1094.5899999999892
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.21.
# Processing limit order: 12893.01 shares on side bid at price 337.88.
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 1233 shares on side bid at price 337.71.
# Order: 1233 shares; Executed: 1233, Remaining: 0
# [DEBUG] Generated external bid order at price 337.71 for 1233 shares.
# Processing limit order: 12893.01 shares on side ask at price 338.26.
# Processing limit order: 12893.01 shares on side bid at price 337.84.
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.3.
# Processing limit order: 12893.01 shares on side bid at price 337.79.
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.35.
# Processing limit order: 12893.01 shares on side bid at price 337.74.
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 983 shares on side bid at price 335.5.
# [DEBUG] Generated external bid order at price 335.5 for 983 shares.
# Processing limit order: 1343 shares on side ask at price 335.71.
# Order: 1343 shares; Executed: 1343, Remaining: 0
# [DEBUG] Generated external ask order at price 335.71 for 1343 shares.
# Processing limit order: 12893.01 shares on side ask at price 338.4.
# Processing limit order: 12893.01 shares on side bid at price 337.7.
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.44.
# Processing limit order: 12893.01 shares on side bid at price 337.65.
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.49.
# Processing limit order: 12893.01 shares on side bid at price 337.6.
# Order: 12893.01 shares; Executed: 6501.180000000017, Remaining: 6391.829999999984
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.54.
# Processing limit order: 1812 shares on side bid at price 334.23.
# [DEBUG] Generated external bid order at price 334.23 for 1812 shares.
# Processing limit order: 12893.01 shares on side bid at price 337.55.
# Order: 12893.01 shares; Executed: 10284.630000000016, Remaining: 2608.3799999999846
# Order: 12893.01 shares; Executed: 11677.630000000016, Remaining: 1215.3799999999846
# Order: 12893.01 shares; Executed: 12893.01, Remaining: 0.0
# Processing limit order: 12893.01 shares on side ask at price 338.59.
# Processing limit order: 15642.31 shares on side bid at price 339.27.
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 15642.31 shares on side ask at price 339.49.
# Processing limit order: 944 shares on side ask at price 333.5.
# Order: 944 shares; Executed: 944, Remaining: 0
# [DEBUG] Generated external ask order at price 333.5 for 944 shares.
# Processing limit order: 15642.31 shares on side bid at price 339.22.
# Order: 15642.31 shares; Executed: 6697.030000000019, Remaining: 8945.27999999998
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 15642.31 shares on side ask at price 339.54.
# Processing limit order: 15642.31 shares on side bid at price 339.16.
# Order: 15642.31 shares; Executed: 7731.1800000000185, Remaining: 7911.129999999981
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 1301 shares on side ask at price 335.73.
# Order: 1301 shares; Executed: 1301, Remaining: 0
# [DEBUG] Generated external ask order at price 335.73 for 1301 shares.
# Processing limit order: 15642.31 shares on side ask at price 339.6.
# Processing limit order: 15642.31 shares on side bid at price 339.11.
# Order: 15642.31 shares; Executed: 8765.330000000018, Remaining: 6876.979999999981
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 15642.31 shares on side ask at price 339.65.
# Processing limit order: 15642.31 shares on side bid at price 339.05.
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 1994 shares on side bid at price 339.05.
# Order: 1994 shares; Executed: 1035.4300000000203, Remaining: 958.5699999999797
# Order: 1994 shares; Executed: 1994.0, Remaining: 0.0
# [DEBUG] Generated external bid order at price 339.05 for 1994 shares.
# Processing limit order: 15642.31 shares on side ask at price 339.71.
# Processing limit order: 15642.31 shares on side bid at price 339.0.
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 15642.31 shares on side ask at price 339.76.
# Processing limit order: 15642.31 shares on side bid at price 338.94.
# Order: 15642.31 shares; Executed: 75.58000000001994, Remaining: 15566.72999999998
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 1302 shares on side ask at price 334.13.
# Order: 1302 shares; Executed: 1302, Remaining: 0
# [DEBUG] Generated external ask order at price 334.13 for 1302 shares.
# Processing limit order: 15642.31 shares on side ask at price 339.82.
# Processing limit order: 15642.31 shares on side bid at price 338.89.
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 15642.31 shares on side ask at price 339.87.
# Processing limit order: 15642.31 shares on side bid at price 338.83.
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 15642.31 shares on side ask at price 339.93.
# Processing limit order: 15642.31 shares on side bid at price 338.78.
# Order: 15642.31 shares; Executed: 15642.31, Remaining: 0.0
# Processing limit order: 1498 shares on side ask at price 333.56.
# Order: 1498 shares; Executed: 1498, Remaining: 0
# [DEBUG] Generated external ask order at price 333.56 for 1498 shares.
# Processing limit order: 15642.31 shares on side ask at price 339.98.
# Processing limit order: 1645 shares on side ask at price 337.33.
# [DEBUG] Generated external ask order at price 337.33 for 1645 shares.
# Processing limit order: 41736.36 shares on side bid at price 340.7.
# Order: 41736.36 shares; Executed: 13575.790000000023, Remaining: 28160.569999999978
# Order: 41736.36 shares; Executed: 37130.510000000024, Remaining: 4605.849999999977
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 341.24.
# Processing limit order: 41736.36 shares on side bid at price 340.57.
# Order: 41736.36 shares; Executed: 12070.610000000022, Remaining: 29665.749999999978
# Order: 41736.36 shares; Executed: 13237.610000000022, Remaining: 28498.749999999978
# Order: 41736.36 shares; Executed: 14005.610000000022, Remaining: 27730.749999999978
# Order: 41736.36 shares; Executed: 30682.07000000002, Remaining: 11054.289999999979
# Order: 41736.36 shares; Executed: 31289.07000000002, Remaining: 10447.289999999979
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 341.37.
# Processing limit order: 41736.36 shares on side bid at price 340.43.
# Order: 41736.36 shares; Executed: 13107.430000000022, Remaining: 28628.92999999998
# Order: 41736.36 shares; Executed: 14066.430000000022, Remaining: 27669.92999999998
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 341.51.
# Processing limit order: 1690 shares on side ask at price 335.12.
# Order: 1690 shares; Executed: 1690, Remaining: 0
# [DEBUG] Generated external ask order at price 335.12 for 1690 shares.
# Processing limit order: 945 shares on side ask at price 336.53.
# [DEBUG] Generated external ask order at price 336.53 for 945 shares.
# Processing limit order: 41736.36 shares on side bid at price 340.3.
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 341.64.
# Processing limit order: 1682 shares on side ask at price 334.62.
# Order: 1682 shares; Executed: 1682, Remaining: 0
# [DEBUG] Generated external ask order at price 334.62 for 1682 shares.
# Processing limit order: 1157 shares on side ask at price 337.37.
# [DEBUG] Generated external ask order at price 337.37 for 1157 shares.
# Processing limit order: 41736.36 shares on side bid at price 340.17.
# Order: 41736.36 shares; Executed: 25103.700000000026, Remaining: 16632.659999999974
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 341.77.
# Processing limit order: 41736.36 shares on side bid at price 340.03.
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 341.91.
# Processing limit order: 1672 shares on side bid at price 335.7.
# [DEBUG] Generated external bid order at price 335.7 for 1672 shares.
# Processing limit order: 1243 shares on side ask at price 338.45.
# [DEBUG] Generated external ask order at price 338.45 for 1243 shares.
# Processing limit order: 1638 shares on side bid at price 334.3.
# [DEBUG] Generated external bid order at price 334.3 for 1638 shares.
# Processing limit order: 41736.36 shares on side bid at price 339.9.
# Order: 41736.36 shares; Executed: 27817.810000000027, Remaining: 13918.549999999974
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 342.04.
# Processing limit order: 41736.36 shares on side bid at price 339.76.
# Order: 41736.36 shares; Executed: 2757.9100000000253, Remaining: 38978.449999999975
# Order: 41736.36 shares; Executed: 26312.630000000026, Remaining: 15423.729999999974
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 342.18.
# Processing limit order: 41736.36 shares on side bid at price 339.63.
# Order: 41736.36 shares; Executed: 13043.150000000027, Remaining: 28693.209999999974
# Order: 41736.36 shares; Executed: 14320.150000000027, Remaining: 27416.209999999974
# Order: 41736.36 shares; Executed: 15265.150000000027, Remaining: 26471.209999999974
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 342.31.
# Processing limit order: 41736.36 shares on side bid at price 339.5.
# Order: 41736.36 shares; Executed: 12315.45000000003, Remaining: 29420.90999999997
# Order: 41736.36 shares; Executed: 35870.17000000003, Remaining: 5866.18999999997
# Order: 41736.36 shares; Executed: 41736.36, Remaining: 0.0
# Processing limit order: 41736.36 shares on side ask at price 342.44.
# Processing limit order: 56940.15 shares on side bid at price 341.51.
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 342.23.
# Processing limit order: 56940.15 shares on side bid at price 341.33.
# Order: 56940.15 shares; Executed: 13263.110000000022, Remaining: 43677.03999999998
# Order: 56940.15 shares; Executed: 41729.99000000002, Remaining: 15210.159999999978
# Order: 56940.15 shares; Executed: 43079.99000000002, Remaining: 13860.159999999978
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 1648 shares on side ask at price 335.16.
# Order: 1648 shares; Executed: 1648, Remaining: 0
# [DEBUG] Generated external ask order at price 335.16 for 1648 shares.
# Processing limit order: 56940.15 shares on side ask at price 342.41.
# Processing limit order: 1265 shares on side ask at price 338.7.
# [DEBUG] Generated external ask order at price 338.7 for 1265 shares.
# Processing limit order: 56940.15 shares on side bid at price 341.15.
# Order: 56940.15 shares; Executed: 9694.56000000002, Remaining: 47245.58999999998
# Order: 56940.15 shares; Executed: 11447.56000000002, Remaining: 45492.58999999998
# Order: 56940.15 shares; Executed: 39914.44000000002, Remaining: 17025.70999999998
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 342.59.
# Processing limit order: 56940.15 shares on side bid at price 340.97.
# Order: 56940.15 shares; Executed: 463.0800000000236, Remaining: 56477.06999999998
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 342.77.
# Processing limit order: 56940.15 shares on side bid at price 340.79.
# Order: 56940.15 shares; Executed: 29709.760000000024, Remaining: 27230.389999999978
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 342.95.
# Processing limit order: 56940.15 shares on side bid at price 340.61.
# Order: 56940.15 shares; Executed: 11556.270000000026, Remaining: 45383.879999999976
# Order: 56940.15 shares; Executed: 40023.15000000002, Remaining: 16916.999999999975
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 343.13.
# Processing limit order: 56940.15 shares on side bid at price 340.43.
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 343.31.
# Processing limit order: 56940.15 shares on side bid at price 340.25.
# Order: 56940.15 shares; Executed: 2212.3000000000247, Remaining: 54727.84999999998
# Order: 56940.15 shares; Executed: 30679.180000000026, Remaining: 26260.969999999976
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 343.49.
# Processing limit order: 56940.15 shares on side bid at price 340.07.
# Order: 56940.15 shares; Executed: 19785.800000000025, Remaining: 37154.34999999998
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 343.67.
# Processing limit order: 56940.15 shares on side bid at price 339.89.
# Order: 56940.15 shares; Executed: 1632.3100000000268, Remaining: 55307.839999999975
# Order: 56940.15 shares; Executed: 30099.190000000028, Remaining: 26840.959999999974
# Order: 56940.15 shares; Executed: 56940.15, Remaining: 0.0
# Processing limit order: 56940.15 shares on side ask at price 343.85.
# Processing limit order: 1721 shares on side bid at price 338.18.
# Order: 1721 shares; Executed: 1721, Remaining: 0
# [DEBUG] Generated external bid order at price 338.18 for 1721 shares.
# Processing limit order: 82948.07 shares on side bid at price 340.55.
# Order: 82948.07 shares; Executed: 57624.870000000024, Remaining: 25323.199999999983
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 1080 shares on side ask at price 338.72.
# [DEBUG] Generated external ask order at price 338.72 for 1080 shares.
# Processing limit order: 1132 shares on side ask at price 334.98.
# Order: 1132 shares; Executed: 1132, Remaining: 0
# [DEBUG] Generated external ask order at price 334.98 for 1132 shares.
# Processing limit order: 82948.07 shares on side ask at price 341.77.
# Processing limit order: 82948.07 shares on side bid at price 340.25.
# Order: 82948.07 shares; Executed: 3143.680000000022, Remaining: 79804.38999999998
# Order: 82948.07 shares; Executed: 49190.45000000002, Remaining: 33757.61999999999
# Order: 82948.07 shares; Executed: 50404.45000000002, Remaining: 32543.619999999988
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 82948.07 shares on side ask at price 342.07.
# Processing limit order: 82948.07 shares on side bid at price 339.94.
# Order: 82948.07 shares; Executed: 6243.040000000008, Remaining: 76705.03
# Order: 82948.07 shares; Executed: 7488.040000000008, Remaining: 75460.03
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 82948.07 shares on side ask at price 342.38.
# Processing limit order: 82948.07 shares on side bid at price 339.64.
# Order: 82948.07 shares; Executed: 609.4199999999983, Remaining: 82338.65000000001
# Order: 82948.07 shares; Executed: 29076.300000000003, Remaining: 53871.770000000004
# Order: 82948.07 shares; Executed: 29800.300000000003, Remaining: 53147.770000000004
# Order: 82948.07 shares; Executed: 58267.18000000001, Remaining: 24680.890000000003
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 1760 shares on side ask at price 336.07.
# Order: 1760 shares; Executed: 1760, Remaining: 0
# [DEBUG] Generated external ask order at price 336.07 for 1760 shares.
# Processing limit order: 82948.07 shares on side ask at price 342.68.
# Processing limit order: 82948.07 shares on side bid at price 339.33.
# Order: 82948.07 shares; Executed: 21365.87999999999, Remaining: 61582.19000000002
# Order: 82948.07 shares; Executed: 23337.87999999999, Remaining: 59610.19000000002
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 1810 shares on side ask at price 338.53.
# [DEBUG] Generated external ask order at price 338.53 for 1810 shares.
# Processing limit order: 82948.07 shares on side ask at price 342.99.
# Processing limit order: 1895 shares on side bid at price 333.06.
# [DEBUG] Generated external bid order at price 333.06 for 1895 shares.
# Processing limit order: 82948.07 shares on side bid at price 339.03.
# Order: 82948.07 shares; Executed: 26576.639999999985, Remaining: 56371.43000000002
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 82948.07 shares on side ask at price 343.29.
# Processing limit order: 82948.07 shares on side bid at price 338.72.
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 82948.07 shares on side ask at price 343.6.
# Processing limit order: 82948.07 shares on side bid at price 338.42.
# Order: 82948.07 shares; Executed: 2687.1299999999756, Remaining: 80260.94000000003
# Order: 82948.07 shares; Executed: 41473.78999999998, Remaining: 41474.28000000003
# Order: 82948.07 shares; Executed: 69940.66999999998, Remaining: 13007.400000000027
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 82948.07 shares on side ask at price 343.9.
# Processing limit order: 82948.07 shares on side bid at price 338.11.
# Order: 82948.07 shares; Executed: 70281.19999999998, Remaining: 12666.870000000024
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 1890 shares on side ask at price 333.98.
# Order: 1890 shares; Executed: 1890, Remaining: 0
# [DEBUG] Generated external ask order at price 333.98 for 1890 shares.
# Processing limit order: 82948.07 shares on side ask at price 344.21.
# Processing limit order: 82948.07 shares on side bid at price 337.81.
# Order: 82948.07 shares; Executed: 63402.57999999997, Remaining: 19545.490000000034
# Order: 82948.07 shares; Executed: 64861.57999999997, Remaining: 18086.490000000034
# Order: 82948.07 shares; Executed: 82948.07, Remaining: 0.0
# Processing limit order: 82948.07 shares on side ask at price 344.51.
# Processing limit order: 1798 shares on side ask at price 335.27.
# Order: 1798 shares; Executed: 1798, Remaining: 0
# [DEBUG] Generated external ask order at price 335.27 for 1798 shares.
# Processing limit order: 1489 shares on side bid at price 334.22.
# [DEBUG] Generated external bid order at price 334.22 for 1489 shares.
# Processing limit order: 1699 shares on side bid at price 335.43.
# [DEBUG] Generated external bid order at price 335.43 for 1699 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.9.
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 343.3.
# Processing limit order: 1052 shares on side ask at price 339.73.
# [DEBUG] Generated external ask order at price 339.73 for 1052 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.8.
# Order: 24700.17 shares; Executed: 3260.109999999964, Remaining: 21440.060000000034
# Order: 24700.17 shares; Executed: 4905.109999999964, Remaining: 19795.060000000034
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 343.4.
# Processing limit order: 687 shares on side bid at price 336.47.
# [DEBUG] Generated external bid order at price 336.47 for 687 shares.
# Processing limit order: 863 shares on side ask at price 336.99.
# [DEBUG] Generated external ask order at price 336.99 for 863 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.69.
# Order: 24700.17 shares; Executed: 863.0, Remaining: 23837.17
# Order: 24700.17 shares; Executed: 19854.59999999997, Remaining: 4845.570000000029
# Order: 24700.17 shares; Executed: 20965.59999999997, Remaining: 3734.570000000029
# Order: 24700.17 shares; Executed: 22122.59999999997, Remaining: 2577.570000000029
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 1242 shares on side ask at price 340.32.
# [DEBUG] Generated external ask order at price 340.32 for 1242 shares.
# Processing limit order: 24700.17 shares on side ask at price 343.51.
# Processing limit order: 24700.17 shares on side bid at price 342.59.
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 343.61.
# Processing limit order: 802 shares on side bid at price 338.43.
# Order: 802 shares; Executed: 802, Remaining: 0
# [DEBUG] Generated external bid order at price 338.43 for 802 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.49.
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 343.71.
# Processing limit order: 1097 shares on side bid at price 334.96.
# [DEBUG] Generated external bid order at price 334.96 for 1097 shares.
# Processing limit order: 1810 shares on side bid at price 337.02.
# [DEBUG] Generated external bid order at price 337.02 for 1810 shares.
# Processing limit order: 1650 shares on side ask at price 335.22.
# Order: 1650 shares; Executed: 1650, Remaining: 0
# [DEBUG] Generated external ask order at price 335.22 for 1650 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.39.
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 343.81.
# Processing limit order: 708 shares on side ask at price 337.47.
# [DEBUG] Generated external ask order at price 337.47 for 708 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.29.
# Order: 24700.17 shares; Executed: 8706.749999999985, Remaining: 15993.420000000013
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 343.91.
# Processing limit order: 1547 shares on side ask at price 338.83.
# [DEBUG] Generated external ask order at price 338.83 for 1547 shares.
# Processing limit order: 24700.17 shares on side bid at price 342.19.
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 344.01.
# Processing limit order: 24700.17 shares on side bid at price 342.09.
# Order: 24700.17 shares; Executed: 5353.179999999986, Remaining: 19346.990000000013
# Order: 24700.17 shares; Executed: 5929.179999999986, Remaining: 18770.990000000013
# Order: 24700.17 shares; Executed: 6637.179999999986, Remaining: 18062.990000000013
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 344.11.
# Processing limit order: 24700.17 shares on side bid at price 341.98.
# Order: 24700.17 shares; Executed: 20723.66999999999, Remaining: 3976.5000000000073
# Order: 24700.17 shares; Executed: 24700.17, Remaining: 0.0
# Processing limit order: 24700.17 shares on side ask at price 344.22.
# Processing limit order: 19842.33 shares on side bid at price 342.18.
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 19842.33 shares on side ask at price 342.48.
# Processing limit order: 19842.33 shares on side bid at price 342.1.
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 19842.33 shares on side ask at price 342.56.
# Processing limit order: 19842.33 shares on side bid at price 342.03.
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 19842.33 shares on side ask at price 342.63.
# Processing limit order: 19842.33 shares on side bid at price 341.95.
# Order: 19842.33 shares; Executed: 12565.959999999977, Remaining: 7276.370000000024
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 1610 shares on side ask at price 335.61.
# Order: 1610 shares; Executed: 160, Remaining: 1450
# Order: 1610 shares; Executed: 847, Remaining: 763
# Order: 1610 shares; Executed: 1610, Remaining: 0
# [DEBUG] Generated external ask order at price 335.61 for 1610 shares.
# Processing limit order: 1412 shares on side bid at price 339.85.
# Order: 1412 shares; Executed: 1412, Remaining: 0
# [DEBUG] Generated external bid order at price 339.85 for 1412 shares.
# Processing limit order: 19842.33 shares on side ask at price 342.71.
# Processing limit order: 19842.33 shares on side bid at price 341.88.
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 1592 shares on side bid at price 336.66.
# [DEBUG] Generated external bid order at price 336.66 for 1592 shares.
# Processing limit order: 19842.33 shares on side ask at price 342.78.
# Processing limit order: 19842.33 shares on side bid at price 341.8.
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 804 shares on side bid at price 338.79.
# Order: 804 shares; Executed: 804, Remaining: 0
# [DEBUG] Generated external bid order at price 338.79 for 804 shares.
# Processing limit order: 715 shares on side bid at price 333.57.
# [DEBUG] Generated external bid order at price 333.57 for 715 shares.
# Processing limit order: 19842.33 shares on side ask at price 342.86.
# Processing limit order: 1245 shares on side ask at price 335.06.
# Order: 1245 shares; Executed: 1245, Remaining: 0
# [DEBUG] Generated external ask order at price 335.06 for 1245 shares.
# Processing limit order: 1041 shares on side bid at price 336.43.
# [DEBUG] Generated external bid order at price 336.43 for 1041 shares.
# Processing limit order: 19842.33 shares on side bid at price 341.73.
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 729 shares on side bid at price 334.95.
# [DEBUG] Generated external bid order at price 334.95 for 729 shares.
# Processing limit order: 19842.33 shares on side ask at price 342.93.
# Processing limit order: 19842.33 shares on side bid at price 341.65.
# Order: 19842.33 shares; Executed: 14269.239999999976, Remaining: 5573.090000000026
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 602 shares on side ask at price 339.64.
# [DEBUG] Generated external ask order at price 339.64 for 602 shares.
# Processing limit order: 19842.33 shares on side ask at price 343.01.
# Processing limit order: 19842.33 shares on side bid at price 341.58.
# Order: 19842.33 shares; Executed: 11839.229999999974, Remaining: 8003.100000000028
# Order: 19842.33 shares; Executed: 19788.269999999975, Remaining: 54.060000000027685
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 19842.33 shares on side ask at price 343.08.
# Processing limit order: 19842.33 shares on side bid at price 341.5.
# Order: 19842.33 shares; Executed: 7894.979999999972, Remaining: 11947.35000000003
# Order: 19842.33 shares; Executed: 19842.33, Remaining: 0.0
# Processing limit order: 19842.33 shares on side ask at price 343.16.
# Processing limit order: 21837.27 shares on side bid at price 343.78.
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.12.
# Processing limit order: 21837.27 shares on side bid at price 343.69.
# Order: 21837.27 shares; Executed: 12262.149999999969, Remaining: 9575.120000000032
# Order: 21837.27 shares; Executed: 20211.18999999997, Remaining: 1626.0800000000318
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.21.
# Processing limit order: 21837.27 shares on side bid at price 343.61.
# Order: 21837.27 shares; Executed: 15786.239999999969, Remaining: 6051.030000000032
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.29.
# Processing limit order: 21837.27 shares on side bid at price 343.52.
# Order: 21837.27 shares; Executed: 1898.0099999999693, Remaining: 19939.26000000003
# Order: 21837.27 shares; Executed: 9847.04999999997, Remaining: 11990.22000000003
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 1695 shares on side bid at price 334.69.
# [DEBUG] Generated external bid order at price 334.69 for 1695 shares.
# Processing limit order: 21837.27 shares on side ask at price 344.38.
# Processing limit order: 21837.27 shares on side bid at price 343.44.
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.46.
# Processing limit order: 21837.27 shares on side bid at price 343.35.
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.55.
# Processing limit order: 21837.27 shares on side bid at price 343.27.
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.63.
# Processing limit order: 21837.27 shares on side bid at price 343.18.
# Order: 21837.27 shares; Executed: 8684.799999999967, Remaining: 13152.470000000034
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.72.
# Processing limit order: 21837.27 shares on side bid at price 343.1.
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.8.
# Processing limit order: 21837.27 shares on side bid at price 343.01.
# Order: 21837.27 shares; Executed: 3796.919999999969, Remaining: 18040.35000000003
# Order: 21837.27 shares; Executed: 11745.95999999997, Remaining: 10091.31000000003
# Order: 21837.27 shares; Executed: 21837.27, Remaining: 0.0
# Processing limit order: 21837.27 shares on side ask at price 344.89.
# Processing limit order: 1900 shares on side ask at price 335.55.
# Order: 1900 shares; Executed: 347, Remaining: 1553
# Order: 1900 shares; Executed: 1388, Remaining: 512
# Order: 1900 shares; Executed: 1900, Remaining: 0
# [DEBUG] Generated external ask order at price 335.55 for 1900 shares.
# Processing limit order: 7950.8 shares on side bid at price 343.07.
# Order: 7950.8 shares; Executed: 7321.009999999969, Remaining: 629.7900000000309
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.19.
# Processing limit order: 7950.8 shares on side bid at price 343.04.
# Order: 7950.8 shares; Executed: 7319.249999999969, Remaining: 631.5500000000311
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.22.
# Processing limit order: 7950.8 shares on side bid at price 343.01.
# Order: 7950.8 shares; Executed: 7317.489999999969, Remaining: 633.3100000000313
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 1184 shares on side bid at price 339.37.
# Order: 1184 shares; Executed: 918.6899999999687, Remaining: 265.3100000000313
# Order: 1184 shares; Executed: 1184.0, Remaining: 0.0
# [DEBUG] Generated external bid order at price 339.37 for 1184 shares.
# Processing limit order: 7950.8 shares on side ask at price 343.25.
# Processing limit order: 7950.8 shares on side bid at price 342.99.
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.27.
# Processing limit order: 7950.8 shares on side bid at price 342.96.
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 1346 shares on side ask at price 340.34.
# [DEBUG] Generated external ask order at price 340.34 for 1346 shares.
# Processing limit order: 7950.8 shares on side ask at price 343.3.
# Processing limit order: 1776 shares on side ask at price 337.78.
# [DEBUG] Generated external ask order at price 337.78 for 1776 shares.
# Processing limit order: 7950.8 shares on side bid at price 342.93.
# Order: 7950.8 shares; Executed: 1245.4099999999698, Remaining: 6705.39000000003
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.33.
# Processing limit order: 766 shares on side bid at price 339.32.
# Order: 766 shares; Executed: 766, Remaining: 0
# [DEBUG] Generated external bid order at price 339.32 for 766 shares.
# Processing limit order: 7950.8 shares on side bid at price 342.9.
# Order: 7950.8 shares; Executed: 477.6499999999696, Remaining: 7473.150000000031
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.36.
# Processing limit order: 7950.8 shares on side bid at price 342.87.
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.39.
# Processing limit order: 7950.8 shares on side bid at price 342.84.
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.42.
# Processing limit order: 1125 shares on side bid at price 339.06.
# Order: 1125 shares; Executed: 1125, Remaining: 0
# [DEBUG] Generated external bid order at price 339.06 for 1125 shares.
# Processing limit order: 7950.8 shares on side bid at price 342.81.
# Order: 7950.8 shares; Executed: 7950.8, Remaining: 0.0
# Processing limit order: 7950.8 shares on side ask at price 343.45.
# Processing limit order: 27450.97 shares on side bid at price 343.19.
# Order: 27450.97 shares; Executed: 27450.97, Remaining: 0.0
# Processing limit order: 27450.97 shares on side ask at price 343.57.
# Processing limit order: 27450.97 shares on side bid at price 343.1.
# Order: 27450.97 shares; Executed: 27450.97, Remaining: 0.0
# Processing limit order: 27450.97 shares on side ask at price 343.66.
# Processing limit order: 27450.97 shares on side bid at price 343.0.
# Order: 27450.97 shares; Executed: 27450.97, Remaining: 0.0
# Processing limit order: 27450.97 shares on side ask at price 343.76.
# ...
# Order: 86495.24 shares; Executed: 56275.73999999991, Remaining: 30219.500000000095
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 351.63.
# Processing limit order: 86495.24 shares on side bid at price 349.15.
# Order: 86495.24 shares; Executed: 15444.039999999906, Remaining: 71051.2000000001
# Order: 86495.24 shares; Executed: 16505.039999999906, Remaining: 69990.2000000001
# Order: 86495.24 shares; Executed: 26886.789999999906, Remaining: 59608.4500000001
# Order: 86495.24 shares; Executed: 49606.789999999906, Remaining: 36888.4500000001
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 351.85.
# Processing limit order: 86495.24 shares on side bid at price 348.92.
# Order: 86495.24 shares; Executed: 60915.6099999999, Remaining: 25579.630000000107
# Order: 86495.24 shares; Executed: 62271.6099999999, Remaining: 24223.630000000107
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 352.08.
# Processing limit order: 86495.24 shares on side bid at price 348.7.
# Order: 86495.24 shares; Executed: 27686.299999999894, Remaining: 58808.94000000011
# Order: 86495.24 shares; Executed: 47439.2799999999, Remaining: 39055.96000000011
# Order: 86495.24 shares; Executed: 64673.629999999896, Remaining: 21821.61000000011
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 352.3.
# Processing limit order: 997 shares on side ask at price 346.75.
# [DEBUG] Generated external ask order at price 346.75 for 997 shares.
# Processing limit order: 86495.24 shares on side bid at price 348.47.
# Order: 86495.24 shares; Executed: 63455.30999999989, Remaining: 23039.930000000117
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 352.53.
# Processing limit order: 86495.24 shares on side bid at price 348.25.
# Order: 86495.24 shares; Executed: 11209.329999999885, Remaining: 75285.91000000012
# Order: 86495.24 shares; Executed: 21591.079999999885, Remaining: 64904.16000000012
# Order: 86495.24 shares; Executed: 39238.20999999989, Remaining: 47257.030000000115
# Order: 86495.24 shares; Executed: 63649.48999999989, Remaining: 22845.750000000116
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 352.75.
# Processing limit order: 86495.24 shares on side bid at price 348.02.
# Order: 86495.24 shares; Executed: 41641.19999999988, Remaining: 44854.040000000125
# Order: 86495.24 shares; Executed: 61394.17999999988, Remaining: 25101.060000000125
# Order: 86495.24 shares; Executed: 63346.17999999988, Remaining: 23149.060000000125
# Order: 86495.24 shares; Executed: 80580.52999999988, Remaining: 5914.7100000001265
# Order: 86495.24 shares; Executed: 81389.52999999988, Remaining: 5105.7100000001265
# Order: 86495.24 shares; Executed: 82888.52999999988, Remaining: 3606.7100000001265
# Order: 86495.24 shares; Executed: 86495.24, Remaining: 0.0
# Processing limit order: 86495.24 shares on side ask at price 352.98.
#
# [DEBUG] Initial Order Book Snapshot (Top 5 Levels):
#
# Order Book Snapshot:
# Asks:
# Price: 345.12, Total Quantity: 6775.04
# Price: 345.13, Total Quantity: 21134.98
# Price: 345.15, Total Quantity: 152267.25
# Price: 345.16, Total Quantity: 60499.05
# Price: 345.17, Total Quantity: 34249.26
# Bids:
# Price: 344.77, Total Quantity: 601
# Price: 344.47, Total Quantity: 15257.77
# Price: 344.38, Total Quantity: 54765.18
# Price: 344.35, Total Quantity: 1172
# Price: 344.34, Total Quantity: 7102.75
# [DEBUG] Checking order book state...
# [DEBUG] Bids in the order book (Top 5 Levels):
# Price: 344.77, Total Quantity: 601
# Price: 344.47, Total Quantity: 15257.77
# Price: 344.38, Total Quantity: 54765.18
# Price: 344.35, Total Quantity: 1172
# Price: 344.34, Total Quantity: 7102.75
# [DEBUG] Asks in the order book (Top 5 Levels):
# Price: 345.12, Total Quantity: 6775.0399999998735
# Price: 345.13, Total Quantity: 21134.98
# Price: 345.15, Total Quantity: 152267.25
# Price: 345.16, Total Quantity: 60499.049999999996
# Price: 345.17, Total Quantity: 34249.26
# [DEBUG] Starting the VWAP and TWAP simulations...
#
# [DEBUG] VWAP function started to buy 100000 shares.
#
# Order Book Snapshot:
# Asks:
# Price: 345.12, Total Quantity: 6775.04
# Price: 345.13, Total Quantity: 21134.98
# Price: 345.15, Total Quantity: 152267.25
# Price: 345.16, Total Quantity: 60499.05
# Price: 345.17, Total Quantity: 34249.26
# Bids:
# Price: 344.77, Total Quantity: 601
# Price: 344.47, Total Quantity: 15257.77
# Price: 344.38, Total Quantity: 54765.18
# Price: 344.35, Total Quantity: 1172
# Price: 344.34, Total Quantity: 7102.75
#
# [DEBUG] VWAP loop - remaining shares: 100000.
# Processing market order: 27160 shares on side bid at target price 345.12.
# Matching order: Price 345.12, Qty 6775.0399999998735, Executed price: 355.47, Liquidity: 6775.0399999998735
# Matching order: Price 345.13, Qty 1382, Executed price: 355.48, Liquidity: 21134.98
# Matching order: Price 345.13, Qty 19002.960000000126, Executed price: 355.48, Liquidity: 19752.98
# VWAP: Executed 27160.0 shares at avg price 355.48. Remaining shares: 72840.0.
# VWAP: Slippage: 0.0300, Market Impact: 0.0024
# VWAP Calculation: 355.48, based on 3 trades.
# VWAP value: 355.48
# Processing limit order: 1688 shares on side ask at price 346.78.
# [DEBUG] Generated external ask order at price 346.78 for 1688 shares.
#
# [DEBUG] VWAP loop - remaining shares: 72840.0.
# Processing market order: 10274 shares on side bid at target price 345.13.
# Matching order: Price 345.13, Qty 750.0199999998731, Executed price: 355.48, Liquidity: 750.0199999998731
# Matching order: Price 345.15, Qty 9523.980000000127, Executed price: 355.50, Liquidity: 152267.25
# VWAP: Executed 10274.0 shares at avg price 355.50. Remaining shares: 62566.0.
# VWAP: Slippage: 0.0300, Market Impact: 0.0011
# VWAP Calculation: 355.48, based on 5 trades.
# VWAP value: 355.48
# Processing limit order: 1427 shares on side ask at price 347.44.
# [DEBUG] Generated external ask order at price 347.44 for 1427 shares.
#
# [DEBUG] VWAP loop - remaining shares: 62566.0.
# Processing market order: 18149 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 18149, Executed price: 355.50, Liquidity: 142743.26999999987
# VWAP: Executed 18149 shares at avg price 355.50. Remaining shares: 44417.0.
# VWAP: Slippage: 0.0300, Market Impact: 0.0011
# VWAP Calculation: 355.49, based on 6 trades.
# VWAP value: 355.49
# WARNING:root:High CPU usage: 100.0%. Pausing execution.
# Processing limit order: 511 shares on side bid at price 348.02.
# Order: 511 shares; Executed: 511, Remaining: 0
# [DEBUG] Generated external bid order at price 348.02 for 511 shares.
#
# [DEBUG] VWAP loop - remaining shares: 44417.0.
# Processing market order: 10274 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 10274, Executed price: 355.50, Liquidity: 124083.26999999987
# VWAP: Executed 10274 shares at avg price 355.50. Remaining shares: 34143.0.
# VWAP: Slippage: 0.0300, Market Impact: 0.0011
# VWAP Calculation: 355.41, based on 8 trades.
# VWAP value: 355.41
# Processing limit order: 848 shares on side bid at price 341.9.
# [DEBUG] Generated external bid order at price 341.9 for 848 shares.
#
# [DEBUG] VWAP loop - remaining shares: 34143.0.
# Processing market order: 30128 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 30128, Executed price: 355.50, Liquidity: 113809.26999999987
# VWAP: Executed 30128 shares at avg price 355.50. Remaining shares: 4015.0.
# VWAP: Slippage: 0.0300, Market Impact: 0.0013
# VWAP Calculation: 355.44, based on 9 trades.
# VWAP value: 355.44
# Processing limit order: 579 shares on side bid at price 344.94.
# [DEBUG] Generated external bid order at price 344.94 for 579 shares.
#
# [DEBUG] VWAP loop - remaining shares: 4015.0.
# Processing market order: 4015.0 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 4015.0, Executed price: 355.50, Liquidity: 83681.26999999987
# VWAP: Executed 4015.0 shares at avg price 355.50. Remaining shares: 0.0.
# VWAP: Slippage: 0.0300, Market Impact: 0.0010
# VWAP Calculation: 355.44, based on 10 trades.
# VWAP value: 355.44
# Processing limit order: 1115 shares on side ask at price 348.47.
# [DEBUG] Generated external ask order at price 348.47 for 1115 shares.
#
# [DEBUG] VWAP Execution Complete: Executed Volume = 100000.0, Avg Price = $355.49, Remaining Shares = 0.0
#
# [DEBUG] TWAP function started to buy 100000 shares over 10 periods.
#
# Order Book Snapshot:
# Asks:
# Price: 345.15, Total Quantity: 79666.27
# Price: 345.16, Total Quantity: 60499.05
# Price: 345.17, Total Quantity: 34249.26
# Price: 345.18, Total Quantity: 90534.89
# Price: 345.22, Total Quantity: 51909.93
# Bids:
# Price: 344.94, Total Quantity: 579
# Price: 344.77, Total Quantity: 601
# Price: 344.47, Total Quantity: 15257.77
# Price: 344.38, Total Quantity: 54765.18
# Price: 344.35, Total Quantity: 1172
# Processing market order: 30000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 30000, Executed price: 355.50, Liquidity: 79666.26999999987
# TWAP: Executed 30000 shares at avg price 355.50. Remaining shares: 70000.
# TWAP: Slippage: 0.0300, Market Impact: 0.0014
# TWAP Calculation: 355.5, based on 1 trades.
# TWAP value: 355.5
# Processing limit order: 1389 shares on side bid at price 342.55.
# [DEBUG] Generated external bid order at price 342.55 for 1389 shares.
# Processing market order: 15000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 15000, Executed price: 355.50, Liquidity: 49666.26999999987
# TWAP: Executed 15000 shares at avg price 355.50. Remaining shares: 55000.
# TWAP: Slippage: 0.0300, Market Impact: 0.0013
# TWAP Calculation: 355.5, based on 2 trades.
# TWAP value: 355.5
# Processing limit order: 1801 shares on side ask at price 346.24.
# [DEBUG] Generated external ask order at price 346.24 for 1801 shares.
# Processing market order: 10000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 10000, Executed price: 355.50, Liquidity: 34666.26999999987
# TWAP: Executed 10000 shares at avg price 355.50. Remaining shares: 45000.
# TWAP: Slippage: 0.0300, Market Impact: 0.0013
# TWAP Calculation: 355.5, based on 3 trades.
# TWAP value: 355.5
# Processing limit order: 1471 shares on side bid at price 342.32.
# [DEBUG] Generated external bid order at price 342.32 for 1471 shares.
# Processing market order: 5000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 254.98999999987427, Executed price: 355.50, Liquidity: 24666.269999999873
# Matching order: Price 345.15, Qty 4745.010000000126, Executed price: 355.50, Liquidity: 24411.28
# TWAP: Executed 5000.0 shares at avg price 355.50. Remaining shares: 40000.0.
# TWAP: Slippage: 0.0300, Market Impact: 0.0012
# TWAP Calculation: 355.5, based on 5 trades.
# TWAP value: 355.5
# Processing limit order: 1733 shares on side bid at price 342.63.
# [DEBUG] Generated external bid order at price 342.63 for 1733 shares.
# Processing market order: 5000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 5000, Executed price: 355.50, Liquidity: 19666.269999999873
# TWAP: Executed 5000 shares at avg price 355.50. Remaining shares: 35000.0.
# TWAP: Slippage: 0.0300, Market Impact: 0.0013
# TWAP Calculation: 355.5, based on 6 trades.
# TWAP value: 355.5
# Processing limit order: 1844 shares on side ask at price 343.89.
# Order: 1844 shares; Executed: 579, Remaining: 1265
# Order: 1844 shares; Executed: 1180, Remaining: 664
# Order: 1844 shares; Executed: 1844, Remaining: 0
# [DEBUG] Generated external ask order at price 343.89 for 1844 shares.
# Processing market order: 5000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 5000, Executed price: 355.50, Liquidity: 14666.269999999873
# TWAP: Executed 5000 shares at avg price 355.50. Remaining shares: 30000.0.
# TWAP: Slippage: 0.0300, Market Impact: 0.0013
# TWAP Calculation: 350.94, based on 10 trades.
# TWAP value: 350.94
# Processing limit order: 1634 shares on side bid at price 341.16.
# [DEBUG] Generated external bid order at price 341.16 for 1634 shares.
# Processing market order: 10000 shares on side bid at target price 345.15.
# Matching order: Price 345.15, Qty 9666.269999999873, Executed price: 365.58, Liquidity: 9666.269999999873
# Matching order: Price 345.16, Qty 333.7300000001269, Executed price: 355.55, Liquidity: 60499.049999999996
# TWAP: Executed 10000.0 shares at avg price 365.25. Remaining shares: 20000.0.
# TWAP: Slippage: 0.0340, Market Impact: 0.0012
# TWAP Calculation: 353.71, based on 12 trades.
# TWAP value: 353.71
# Processing limit order: 527 shares on side ask at price 343.54.
# Order: 527 shares; Executed: 527, Remaining: 0
# [DEBUG] Generated external ask order at price 343.54 for 527 shares.
# Processing market order: 10000 shares on side bid at target price 345.16.
# Matching order: Price 345.16, Qty 10000, Executed price: 357.31, Liquidity: 60165.31999999987
# TWAP: Executed 10000 shares at avg price 357.31. Remaining shares: 10000.0.
# TWAP: Slippage: 0.0356, Market Impact: 0.0012
# TWAP Calculation: 353.09, based on 14 trades.
# TWAP value: 353.09
# Processing limit order: 1520 shares on side ask at price 345.01.
# [DEBUG] Generated external ask order at price 345.01 for 1520 shares.
# Processing limit order: 821 shares on side bid at price 347.91.
# Order: 821 shares; Executed: 821, Remaining: 0
# [DEBUG] Generated external bid order at price 347.91 for 821 shares.
# Processing market order: 10000 shares on side bid at target price 345.01.
# Matching order: Price 345.01, Qty 699, Executed price: 377.65, Liquidity: 699
# Matching order: Price 345.16, Qty 6900.619999999872, Executed price: 357.62, Liquidity: 50165.31999999987
# Matching order: Price 345.16, Qty 2400.3800000001283, Executed price: 356.55, Liquidity: 43264.7
# TWAP: Executed 10000.0 shares at avg price 358.76. Remaining shares: 0.0.
# TWAP: Slippage: 0.0484, Market Impact: 0.0013
# TWAP Calculation: 355.46, based on 18 trades.
# TWAP value: 355.46
# Processing limit order: 1799 shares on side ask at price 344.22.
# Order: 1799 shares; Executed: 1799, Remaining: 0
# [DEBUG] Generated external ask order at price 344.22 for 1799 shares.
#
# [DEBUG] TWAP halted: No remaining shares to buy.
#
# [DEBUG] TWAP Execution Complete: Executed Volume = 100000.0, Avg Price = $356.98, Remaining Shares = 0.0
#
# === Execution Results Comparison ===
#
# Metric                    VWAP            TWAP
# =======================================================
# Executed Volume (shares)  100000.0        100000.0
# Average Price ($)         355.49          356.98
# Total Cost ($)            35549456.8      35698200.0
# Transaction Cost ($)      35549.0         35698.0
# Slippage (avg %)          0.0300          0.0331
# Market Impact (avg %)     0.0013          0.0013
#
# =======================================================
#
#
# Simulation Results:
# VWAP Results: {'prices': [355.48, 355.5, 355.5, 355.5, 355.5, 355.5], 'volumes': [27160.0, 10274.0, 18149, 10274, 30128, 4015.0], 'slippage': [0.03, 0.03, 0.03, 0.03, 0.03, 0.03], 'market_impact': [0.0023749824077177214, 0.0010674734718069709, 0.0011271443480312593, 0.0010827992363515245, 0.0012647236029191648, 0.001047979673348648], 'avg_price': 355.49, 'volume': 100000.0, 'total_cost': 35549456.8, 'transaction_cost_total': 35549.0}
# TWAP Results: {'prices': [355.5, 355.5, 355.5, 355.5, 355.5, 355.5, 365.25, 357.31, 358.76], 'volumes': [30000, 15000, 10000, 5000.0, 5000, 5000, 10000.0, 10000, 10000.0], 'slippage': [0.03, 0.03, 0.03, 0.03, 0.03, 0.03, 0.03400788894242936, 0.035592746468718385, 0.04843612590143371], 'market_impact': [0.001376570912633415, 0.001302015834891568, 0.0012884648391649875, 0.0012048233439622992, 0.001254242416075851, 0.0013409183111997831, 0.0011879699917500483, 0.001188653623445287, 0.0013180206041734945], 'avg_price': 356.98, 'volume': 100000.0, 'total_cost': 35698200.0, 'transaction_cost_total': 35698.0}
